# %%
import pandas as pd 

df = pd.read_csv("../../data/CSV/ML_Datasets/dataset_ML.csv")

# %%
df.head(5)
# Out:
#                                               lyrics  ...  Hit
# 0  look into my eyes  you will seewhat you mean t...  ...  Yes
# 1  i can't get no satisfactioni can't get no sati...  ...  Yes
# 2  our life together is so precious togetherwe ha...  ...  Yes
# 3  love is higher than a mountain love is thicker...  ...  Yes
# 4  sittin' in the morning suni'll be sittin' when...  ...  Yes
#
# [5 rows x 45 columns]

# %%
df.shape
# Out:
# (1801, 45)

# %%
df.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'key', 'mode', 'duration_ms', 'Popularity', 'values', 'pred', 'label',
#        'score', 'emotion_label', 'Hit'],
#       dtype='object')

# %%
from collections import Counter 

Counter(df.Hit)
# Out:
# Counter({'Yes': 912, 'No': 889})

# %%
df1 = pd.read_csv("../../data/CSV/ML_Datasets/big_dataset_with_decades.csv")

# %%
df1.head(5)
# Out:
#                    track            artist  ... target  decades
# 0  Jealous Kind Of Fella     Garland Green  ...      1   1960er
# 1          Initials B.B.  Serge Gainsbourg  ...      0   1960er
# 2           Melody Twist       Lord Melody  ...      0   1960er
# 3          Mi Bomba Sonó        Celia Cruz  ...      0   1960er
# 4            Uravu Solla       P. Susheela  ...      0   1960er
#
# [5 rows x 20 columns]

# %%
df1.columns
# Out:
# Index(['track', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
#        'sections', 'target', 'decades'],
#       dtype='object')

# %%
import pandas as pd 

test = pd.read_csv("../../../../../Downloads/data/songs_complete_data.csv")

# %%
test.head(5)
# Out:
#    Unnamed: 0                 Artist              Title  Top100  \
# 0           1            linkin park         in the end       0
# 1           2      the white stripes  seven nation army       0
# 2           3  red hot chili peppers         by the way       0
# 3           5            evanescence   bring me to life       0
# 4           6             papa roach        last resort       0
#
#                       URI  Danceability  Energy  Key  Loudness  Mode  ...  \
# 0  60a0Rd6pjrkxjPbaKzXjfq         0.556   0.864    3    -5.870     0  ...
# 1  7i6r9KotUPQg3ozKKgEPIN         0.737   0.463    0    -7.828     1  ...
# 2  3ZOEytgrvLwQaqXreDs2Jx         0.618   0.938    9    -3.442     1  ...
# 3  0COqiPhxzoWICwFCS4eZcp         0.331   0.943    4    -3.188     0  ...
# 4  5W8YXBz9MTIDyrpYaCg2Ky         0.589   0.890    4    -3.719     0  ...
#
#    Instrumentalness  Liveness  Valence    Tempo  Duration  Time_Signature  \
# ...

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Title', 'Top100', 'URI', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness', 'Acousticness',
#        'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration',
#        'Time_Signature', 'lyrics', 'explicit', 'Release_Year', 'Genre'],
#       dtype='object')

# %%
from collections import Counter 

Counter(test.Top100)
# Out:
# Counter({0: 7725, 1: 1501})
