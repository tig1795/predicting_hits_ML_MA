# %% [markdown]
# # Import dataset

# %%
import pandas as pd 

data = pd.read_csv('../../data/CSV/dataset_complete_without_two.csv')

# %%
data.head(5)
# Out:
#                                               lyrics  ...   Hit
# 0   here she comes  mmm  just like an angelseems ...  ...  None
# 1  look into my eyes  you will seewhat you mean t...  ...   Yes
# 2  i can't get no satisfactioni can't get no sati...  ...   Yes
# 3  oh  i  i just died in your arms tonightit must...  ...  None
# 4  your love is fadin'  i feel it fadeah  your lo...  ...  None
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (3667, 26)

# %% [markdown]
# # Dataset with just hits

# %%
dhit = data[data['Hit'] == 'Yes']

# %%
dhit
# Out:
#                                                  lyrics  ...  Hit
# 1     look into my eyes  you will seewhat you mean t...  ...  Yes
# 2     i can't get no satisfactioni can't get no sati...  ...  Yes
# 7     our life together is so precious togetherwe ha...  ...  Yes
# 9     love is higher than a mountain love is thicker...  ...  Yes
# 15    sittin' in the morning suni'll be sittin' when...  ...  Yes
# ...                                                 ...  ...  ...
# 3636  my life is brilliantmy life is brilliantmy lov...  ...  Yes
# 3644  son of a gunyou walked into the partylike you ...  ...  Yes
# 3645  looks like we made itlook how far we've come m...  ...  Yes
# 3649  i got chills  they're multiplyin'and i'm losin...  ...  Yes
# 3651  when you're down and troubledand you need a he...  ...  Yes
#
# [912 rows x 26 columns]

# %%
dhit = dhit.reset_index(drop=True)

# %%
dhit
# Out:
#                                                 lyrics  ...  Hit
# 0    look into my eyes  you will seewhat you mean t...  ...  Yes
# 1    i can't get no satisfactioni can't get no sati...  ...  Yes
# 2    our life together is so precious togetherwe ha...  ...  Yes
# 3    love is higher than a mountain love is thicker...  ...  Yes
# 4    sittin' in the morning suni'll be sittin' when...  ...  Yes
# ..                                                 ...  ...  ...
# 907  my life is brilliantmy life is brilliantmy lov...  ...  Yes
# 908  son of a gunyou walked into the partylike you ...  ...  Yes
# 909  looks like we made itlook how far we've come m...  ...  Yes
# 910  i got chills  they're multiplyin'and i'm losin...  ...  Yes
# 911  when you're down and troubledand you need a he...  ...  Yes
#
# [912 rows x 26 columns]

# %% [markdown]
# # Dataset with just no hits

# %%
dnohit = data[data['Hit'] == 'No']

# %%
dnohit
# Out:
#                                                  lyrics  ... Hit
# 6     it ain't the clothes that you wearit ain't the...  ...  No
# 11    woohpretty woman  walking down the streetprett...  ...  No
# 14    hey  man  i don't feel like goin' to school no...  ...  No
# 19    kick it!you wake up late for school  man  you ...  ...  No
# 28    i saw star wars at least 8 timeshad the pac-ma...  ...  No
# ...                                                 ...  ...  ..
# 3652  you never close your eyes anymore when i kiss ...  ...  No
# 3654  young emotions are mixed emotionsfor it's a wo...  ...  No
# 3656  what's the sense in sharing this one and only ...  ...  No
# 3661  i don't mindwhen you act your ageit suits me f...  ...  No
# 3665  once upon a timeonce when you were minei remem...  ...  No
#
# [889 rows x 26 columns]

# %%
dnohit = dnohit.reset_index(drop=True)

# %%
dnohit
# Out:
#                                                 lyrics  ... Hit
# 0    it ain't the clothes that you wearit ain't the...  ...  No
# 1    woohpretty woman  walking down the streetprett...  ...  No
# 2    hey  man  i don't feel like goin' to school no...  ...  No
# 3    kick it!you wake up late for school  man  you ...  ...  No
# 4    i saw star wars at least 8 timeshad the pac-ma...  ...  No
# ..                                                 ...  ...  ..
# 884  you never close your eyes anymore when i kiss ...  ...  No
# 885  young emotions are mixed emotionsfor it's a wo...  ...  No
# 886  what's the sense in sharing this one and only ...  ...  No
# 887  i don't mindwhen you act your ageit suits me f...  ...  No
# 888  once upon a timeonce when you were minei remem...  ...  No
#
# [889 rows x 26 columns]

# %%
dnohit.iloc[743:747]
# Out:
#                                                 lyrics  ... Hit
# 743  there goes my baby oo girl look at you you don...  ...  No
# 744  i love you  there's nothing to hideit's better...  ...  No
# 745  these words are my own threw some chords toget...  ...  No
# 746  bum stiggedy bum stiggedy bum  hon  i got the ...  ...  No
#
# [4 rows x 26 columns]

# %%
dnohit[dnohit['title'] == 'These Words']
# Out:
#                                                 lyrics  ... Hit
# 745  these words are my own threw some chords toget...  ...  No
#
# [1 rows x 26 columns]

# %% [markdown]
# # Pickles to CSV

# %% [markdown]
# ## hit pickle

# %%
hitsaf = pd.read_pickle(r'../1_audio_features/Playlists/hits.pkl')

# %%
hitsaf
# Out:
#                  playlistID  ... Popularity
# 0    2A4YfptOVIqtSvTQ6d32sm  ...       77.0
# 1    2A4YfptOVIqtSvTQ6d32sm  ...       78.0
# 2    2A4YfptOVIqtSvTQ6d32sm  ...       61.0
# 3    2A4YfptOVIqtSvTQ6d32sm  ...       47.0
# 4    2A4YfptOVIqtSvTQ6d32sm  ...       80.0
# ..                      ...  ...        ...
# 907  2A4YfptOVIqtSvTQ6d32sm  ...       78.0
# 908  2A4YfptOVIqtSvTQ6d32sm  ...       78.0
# 909  2A4YfptOVIqtSvTQ6d32sm  ...       79.0
# 910  2A4YfptOVIqtSvTQ6d32sm  ...       74.0
# 911  2A4YfptOVIqtSvTQ6d32sm  ...        0.0
#
# [912 rows x 19 columns]

# %% [markdown]
# ## merge hit data

# %%
result = dhit.merge(hitsaf, left_index=True, right_index=True)

# %%
result.shape
# Out:
# (912, 45)

# %%
result
# Out:
#                                                 lyrics  ... Popularity
# 0    look into my eyes  you will seewhat you mean t...  ...       77.0
# 1    i can't get no satisfactioni can't get no sati...  ...       78.0
# 2    our life together is so precious togetherwe ha...  ...       61.0
# 3    love is higher than a mountain love is thicker...  ...       47.0
# 4    sittin' in the morning suni'll be sittin' when...  ...       80.0
# ..                                                 ...  ...        ...
# 907  my life is brilliantmy life is brilliantmy lov...  ...       78.0
# 908  son of a gunyou walked into the partylike you ...  ...       78.0
# 909  looks like we made itlook how far we've come m...  ...       79.0
# 910  i got chills  they're multiplyin'and i'm losin...  ...       74.0
# 911  when you're down and troubledand you need a he...  ...        0.0
#
# [912 rows x 45 columns]

# %%
result.to_csv('../../data/CSV/hits_with_af.csv', index=False)

# %% [markdown]
# ## no hits pickle

# %%
no_hitsaf = pd.read_pickle('../1_audio_features/Playlists/no_hits.pkl')

# %%
no_hitsaf
# Out:
#                  playlistID  ... Popularity
# 0    1tNtUBpfQnVkCUHpWPMxpW  ...       38.0
# 1    1tNtUBpfQnVkCUHpWPMxpW  ...       63.0
# 2    1tNtUBpfQnVkCUHpWPMxpW  ...       45.0
# 3    1tNtUBpfQnVkCUHpWPMxpW  ...       39.0
# 4    1tNtUBpfQnVkCUHpWPMxpW  ...       62.0
# ..                      ...  ...        ...
# 884  1tNtUBpfQnVkCUHpWPMxpW  ...       51.0
# 885  1tNtUBpfQnVkCUHpWPMxpW  ...       23.0
# 886  1tNtUBpfQnVkCUHpWPMxpW  ...       72.0
# 887  1tNtUBpfQnVkCUHpWPMxpW  ...       54.0
# 888  1tNtUBpfQnVkCUHpWPMxpW  ...       56.0
#
# [889 rows x 19 columns]

# %%
no_hitsaf[no_hitsaf['TrackName']  == 'These Words']
# Out:
#                  playlistID    TrackName  ... duration_ms Popularity
# 745  1tNtUBpfQnVkCUHpWPMxpW  These Words  ...      215840       23.0
#
# [1 rows x 19 columns]

# %% [markdown]
# ## merge no hit data

# %%
result2 = dnohit.merge(no_hitsaf, left_index=True, right_index=True)

# %%
result2.shape
# Out:
# (889, 45)

# %%
result2
# Out:
#                                                 lyrics  ... Popularity
# 0    it ain't the clothes that you wearit ain't the...  ...       38.0
# 1    woohpretty woman  walking down the streetprett...  ...       63.0
# 2    hey  man  i don't feel like goin' to school no...  ...       45.0
# 3    kick it!you wake up late for school  man  you ...  ...       39.0
# 4    i saw star wars at least 8 timeshad the pac-ma...  ...       62.0
# ..                                                 ...  ...        ...
# 884  you never close your eyes anymore when i kiss ...  ...       51.0
# 885  young emotions are mixed emotionsfor it's a wo...  ...       23.0
# 886  what's the sense in sharing this one and only ...  ...       72.0
# 887  i don't mindwhen you act your ageit suits me f...  ...       54.0
# 888  once upon a timeonce when you were minei remem...  ...       56.0
#
# [889 rows x 45 columns]

# %%
result2.to_csv('../../data/CSV/nohits_with_af.csv', index=False)

# %% [markdown]
# # concat to one big dataset

# %%
import pandas as pd

df1 = pd.read_csv('../../data/CSV/hits_with_af.csv')
df2 = pd.read_csv('../../data/CSV/nohits_with_af.csv')

# %%
df1
# Out:
#                                                 lyrics  \
# 0    look into my eyes  you will seewhat you mean t...
# 1    i can't get no satisfactioni can't get no sati...
# 2    our life together is so precious togetherwe ha...
# 3    love is higher than a mountain love is thicker...
# 4    sittin' in the morning suni'll be sittin' when...
# ..                                                 ...
# 907  my life is brilliantmy life is brilliantmy lov...
# 908  son of a gunyou walked into the partylike you ...
# 909  looks like we made itlook how far we've come m...
# 910  i got chills  they're multiplyin'and i'm losin...
# 911  when you're down and troubledand you need a he...
#
#                                                  genre  num_syllables  pos  \
# 0    ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1    ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2    ['britannique', 'british', 'classic pop and ro...          288.0    4
# ...

# %%
df2
# Out:
#                                                 lyrics  \
# 0    it ain't the clothes that you wearit ain't the...
# 1    woohpretty woman  walking down the streetprett...
# 2    hey  man  i don't feel like goin' to school no...
# 3    kick it!you wake up late for school  man  you ...
# 4    i saw star wars at least 8 timeshad the pac-ma...
# ..                                                 ...
# 884  you never close your eyes anymore when i kiss ...
# 885  young emotions are mixed emotionsfor it's a wo...
# 886  what's the sense in sharing this one and only ...
# 887  i don't mindwhen you act your ageit suits me f...
# 888  once upon a timeonce when you were minei remem...
#
#                                                  genre  num_syllables  pos  \
# 0                                                  pop          448.2   86
# 1    ['aor', 'classic pop and rock', 'glam metal', ...          198.0   88
# 2    ['american', 'classic pop and rock', 'neo rock...          423.0   84
# ...

# %%
# Concatenate dataframes row-wise
merged_df = pd.concat([df1, df2], axis=0)

# Reset the index of the merged dataframe
merged_df = merged_df.reset_index(drop=True)

# Print the merged dataframe
merged_df
# Out:
#                                                  lyrics  \
# 0     look into my eyes  you will seewhat you mean t...
# 1     i can't get no satisfactioni can't get no sati...
# 2     our life together is so precious togetherwe ha...
# 3     love is higher than a mountain love is thicker...
# 4     sittin' in the morning suni'll be sittin' when...
# ...                                                 ...
# 1796  you never close your eyes anymore when i kiss ...
# 1797  young emotions are mixed emotionsfor it's a wo...
# 1798  what's the sense in sharing this one and only ...
# 1799  i don't mindwhen you act your ageit suits me f...
# 1800  once upon a timeonce when you were minei remem...
#
#                                                   genre  num_syllables  pos  \
# 0     ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1     ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# ...

# %%
from collections import Counter

Counter(merged_df.Hit)
# Out:
# Counter({'Yes': 912, 'No': 889})

# %% [markdown]
# ## change the positions of the columns

# %%
merged_df.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'values', 'pred', 'label', 'score', 'emotion_label', 'Hit',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'key', 'mode', 'duration_ms', 'Popularity'],
#       dtype='object')

# %%
merged_df.pred
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1796    0
# 1797    1
# 1798    1
# 1799    1
# 1800    1
# Name: pred, Length: 1801, dtype: int64

# %%
import pandas as pd

# Specify the desired order of columns
desired_columns_order = ['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
       'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
       'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
       'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
       'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
       'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'key', 'mode', 'duration_ms', 'Popularity', 'values', 'pred', 'label', 'score', 'emotion_label',              'Hit']

# Reorder columns in the DataFrame
merged_df = merged_df.reindex(columns=desired_columns_order)

# Print the modified DataFrame
merged_df
# Out:
#                                                  lyrics  \
# 0     look into my eyes  you will seewhat you mean t...
# 1     i can't get no satisfactioni can't get no sati...
# 2     our life together is so precious togetherwe ha...
# 3     love is higher than a mountain love is thicker...
# 4     sittin' in the morning suni'll be sittin' when...
# ...                                                 ...
# 1796  you never close your eyes anymore when i kiss ...
# 1797  young emotions are mixed emotionsfor it's a wo...
# 1798  what's the sense in sharing this one and only ...
# 1799  i don't mindwhen you act your ageit suits me f...
# 1800  once upon a timeonce when you were minei remem...
#
#                                                   genre  num_syllables  pos  \
# 0     ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1     ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# ...

# %%
merged_df.to_csv('../../data/CSV/dataset_ML.csv', index=False)
