# %% [markdown]
# # Konvertierung JSON to CSV

# %%
import pandas as pd

# %%
with open('../../data/json/2015.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

# %%
df.head(5)
# Out:
#                                               lyrics  \
# 0  Aw, ow!\n\nThis hit, that ice cold\nMichelle P...
# 1  When your legs don't work like they used to be...
# 2  It's been a long day without you my friend\nAn...
# 3  Remy Boyz, yeah\n1738\n\nI'm like "hey, what's...
# 4  I'm hurting, babe, I'm broken down\nI need you...
#
#                                                 tags  num_syllables  pos  \
# 0  [alternative rock, dance, electropop, english,...          693.9    1
# 1  [dance-pop, folk pop, guitarist, pop, pop rap,...          381.6    2
# 2  [hip hop, hip hop rnb and dance hall, pop rap,...          468.9    3
# 3              [contemporary r&b, pop rap, trap rap]          589.5    4
# 4  [adult contemporary, automod ng, dance, dance-...          549.9    5
#
#    year  fog_index  flesch_index  num_words  num_lines  \
# 0  2015        4.0        100.24        591         99
# 1  2015        4.8         98.21        316         40
# 2  2015        4.8         98.21        406         53
# 3  2015        5.6        104.64        528         56
# 4  2015        4.8         98.21        447         59
#
#                                            sentiment              title  \
# 0  {'neg': 0.02, 'neu': 0.896, 'pos': 0.084, 'com...       Uptown Funk!
# 1  {'neg': 0.049, 'neu': 0.727, 'pos': 0.224, 'co...  Thinking Out Loud
# 2  {'neg': 0.029, 'neu': 0.882, 'pos': 0.089, 'co...      See You Again
# 3  {'neg': 0.09, 'neu': 0.812, 'pos': 0.098, 'com...         Trap Queen
# 4  {'neg': 0.07100000000000001, 'neu': 0.634, 'po...              Sugar
#
#    f_k_grade       artist  difficult_words  num_dupes
# 0        0.5  Mark Ronson               31         64
# 1        1.3   Ed Sheeran               18         15
# 2        1.3  Wiz Khalifa               19         26
# 3        0.9    Fetty Wap               38         32
# 4        1.3     Maroon 5               23         39

# %%
df.shape
# Out:
# (76, 15)

# %%
df.to_csv('../../data/CSV/2015.csv', encoding='utf-8', index=False)

# %%
df1 = pd.read_csv('../../data/CSV/2015.csv')

# %%
df1.shape
# Out:
# (76, 15)

# %% [markdown]
# # CSV-Files in eine CSV-File zusammenführen

# %%
#import modules
import os
import glob
#list all csv files only
csv_files = glob.glob('../../data/CSV/*.{}'.format('csv'))
sorted(csv_files)
# Out:
# ['../../data/CSV/1950.csv',
#  '../../data/CSV/1951.csv',
#  '../../data/CSV/1952.csv',
#  '../../data/CSV/1953.csv',
#  '../../data/CSV/1954.csv',
#  '../../data/CSV/1955.csv',
#  '../../data/CSV/1956.csv',
#  '../../data/CSV/1957.csv',
#  '../../data/CSV/1958.csv',
#  '../../data/CSV/1959.csv',
#  '../../data/CSV/1960.csv',
#  '../../data/CSV/1961.csv',
#  '../../data/CSV/1962.csv',
#  '../../data/CSV/1963.csv',
#  '../../data/CSV/1964.csv',
#  '../../data/CSV/1965.csv',
#  '../../data/CSV/1966.csv',
#  '../../data/CSV/1967.csv',
#  '../../data/CSV/1968.csv',
#  '../../data/CSV/1969.csv',
#  '../../data/CSV/1970.csv',
#  '../../data/CSV/1971.csv',
#  '../../data/CSV/1972.csv',
#  '../../data/CSV/1973.csv',
#  '../../data/CSV/1974.csv',
#  '../../data/CSV/1975.csv',
#  '../../data/CSV/1976.csv',
#  '../../data/CSV/1977.csv',
#  '../../data/CSV/1978.csv',
#  '../../data/CSV/1979.csv',
#  '../../data/CSV/1980.csv',
#  '../../data/CSV/1981.csv',
#  '../../data/CSV/1982.csv',
#  '../../data/CSV/1983.csv',
#  '../../data/CSV/1984.csv',
#  '../../data/CSV/1985.csv',
#  '../../data/CSV/1986.csv',
#  '../../data/CSV/1987.csv',
#  '../../data/CSV/1988.csv',
#  '../../data/CSV/1989.csv',
#  '../../data/CSV/1990.csv',
#  '../../data/CSV/1991.csv',
#  '../../data/CSV/1992.csv',
#  '../../data/CSV/1993.csv',
#  '../../data/CSV/1994.csv',
#  '../../data/CSV/1995.csv',
#  '../../data/CSV/1996.csv',
#  '../../data/CSV/1997.csv',
#  '../../data/CSV/1998.csv',
#  '../../data/CSV/1999.csv',
#  '../../data/CSV/2000.csv',
#  '../../data/CSV/2001.csv',
#  '../../data/CSV/2002.csv',
#  '../../data/CSV/2003.csv',
#  '../../data/CSV/2004.csv',
#  '../../data/CSV/2005.csv',
#  '../../data/CSV/2006.csv',
#  '../../data/CSV/2007.csv',
#  '../../data/CSV/2008.csv',
#  '../../data/CSV/2009.csv',
#  '../../data/CSV/2010.csv',
#  '../../data/CSV/2011.csv',
#  '../../data/CSV/2012.csv',
#  '../../data/CSV/2013.csv',
#  '../../data/CSV/2014.csv',
#  '../../data/CSV/2015.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#                                                  lyrics  \
# 0     No other love have I\nOnly my love for you! \n...
# 1     (Pa pa pa pia)\n(Pa pa pa pia)\n\nDon't let th...
# 2     I believe for every drop of rain that falls \n...
# 3     First the tide rushes in\nPlants a kiss on the...
# 4     Pretend you're happy when you're blue\nIt isn'...
# ...                                                 ...
# 4023  Doctor, my woman is comin' back home late toda...
# 4024  You show us everything you've got\nYou keep on...
# 4025  Guess who just got back today\nThem wild-eyed ...
# 4026  This here's a story 'bout Billy Joe and Bobbie...
# 4027  Living in the city\nAin't never been my idea\n...
#
#                                                    tags  num_syllables  pos  \
# 0     ['adult contemporary', 'american', 'big band',...          153.9    8
# 1     ['adult contemporary', 'american', 'big band',...          337.5    9
# 2                            ['death by heart failure']          179.1   10
# 3                                  ['production music']          104.4   12
# 4     ['american', 'death by lung cancer', 'easy lis...          119.7   13
# ...                                                 ...            ...  ...
# 4023  ['american', 'easy listening soundtracks and m...          372.6   94
# 4024                                            ['pop']          349.2   95
# 4025  ['celtic rock', 'classic pop and rock', 'hard ...          423.0   97
# 4026  ['blues rock', 'country rock', 'pop', 'pop roc...          227.7   98
# 4027                           ['classic pop and rock']          333.9  100
#
#       year  fog_index  flesch_index  num_words  num_lines  \
# 0     1953        3.6        101.26        129         29
# 1     1953        4.4        107.69        297         48
# 2     1953        4.4         90.77        133         21
# 3     1953        4.0        100.24         89         15
# 4     1953        4.4         99.23         99         15
# ...    ...        ...           ...        ...        ...
# 4023  1976        5.2         88.74        294         36
# 4024  1976        5.6         87.72        275         29
# 4025  1976        5.2        105.66        383         44
# 4026  1976        5.2         97.20        184         22
# 4027  1976        4.0        100.24        286         52
#
#                                               sentiment  \
# 0     {'neg': 0.14, 'neu': 0.54, 'pos': 0.319, 'comp...
# 1     {'neg': 0.006, 'neu': 0.878, 'pos': 0.115, 'co...
# 2     {'neg': 0.152, 'neu': 0.769, 'pos': 0.079, 'co...
# 3     {'neg': 0.0, 'neu': 0.793, 'pos': 0.2070000000...
# 4     {'neg': 0.078, 'neu': 0.7000000000000001, 'pos...
# ...                                                 ...
# 4023  {'neg': 0.041, 'neu': 0.86, 'pos': 0.098, 'com...
# 4024  {'neg': 0.033, 'neu': 0.8180000000000001, 'pos...
# 4025  {'neg': 0.046, 'neu': 0.93, 'pos': 0.024, 'com...
# 4026  {'neg': 0.023, 'neu': 0.897, 'pos': 0.08, 'com...
# 4027  {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
#
#                                      title  f_k_grade             artist  \
# 0                            No Other Love        0.1         Perry Como
# 1     Don't Let The Stars Get In Your Eyes       -0.3         Perry Como
# 2                                I Believe        2.1      Frankie Laine
# 3                                 Ebb Tide        0.5  Frank Chacksfield
# 4                                  Pretend        0.9      Nat King Cole
# ...                                    ...        ...                ...
# 4023       Tryin' To Get The Feeling Again        2.9      Barry Manilow
# 4024                Rock And Roll All Nite        3.3               Kiss
# 4025             The Boys Are Back In Town        0.5         Thin Lizzy
# 4026                Take The Money And Run        1.7  Steve Miller Band
# 4027                           Country Boy        0.5      Glen Campbell
#
#       difficult_words  num_dupes
# 0                   9         16
# 1                  11         27
# 2                  12          1
# 3                   5          2
# 4                   9          0
# ...               ...        ...
# 4023               26         12
# 4024               12         24
# 4025               25         22
# 4026               23          8
# 4027               17         33
#
# [4028 rows x 15 columns]

# %%
df_concat.sort_values('year')
# Out:
#                                                  lyrics  \
# 392   My heart knows what the wild goose knows,\nI m...
# 391   i love those dear hearts and gentle people\nwh...
# 390   Hoop dee doo, hoop dee doo,  \nI hear a polka ...
# 388   Each time I hold someone new\nMy arms grow col...
# 387   I was dancing with my darling to the Tennessee...
# ...                                                 ...
# 1816  (What the heart wants...)\n(The heart wants......
# 1817  I've got a girl crush\nHate to admit it but,\n...
# 1818  I know you got all dressed up for the club\nWa...
# 1820  Drake\nUh, thinkin' out loud\nI must have a qu...
# 1835  This is my heartbeat song and I'm gonna play i...
#
#                                                    tags  num_syllables  pos  \
# 392                          ['death by heart failure']          350.1   30
# 391   ['american', 'christmas music', 'death by hear...          303.3   29
# 390   ['adult contemporary', 'american', 'big band',...          423.0   25
# 388             ['death by liver failure', 'spiritual']          135.9   20
# 387                                  ['country', 'pop']          174.6   18
# ...                                                 ...            ...  ...
# 1816  ['alternative r&b', 'brostep', 'contemporary r...          468.9   62
# 1817                                        ['country']          223.2   63
# 1818   ['hip hop', 'hip hop rnb and dance hall', 'r&b']          311.4   64
# 1820         ['a filk artist', 'hip-hop', 'pop', 'rap']          609.3   66
# 1835  ['a filk artist', 'american idol', 'dance-pop'...          471.6   91
#
#       year  fog_index  flesch_index  num_words  num_lines  \
# 392   1950        4.8        106.67        306         40
# 391   1950        4.4         90.77        239         39
# 390   1950        4.8        106.67        382         54
# 388   1950        4.4         99.23        117         18
# 387   1950        5.2         88.74        138         16
# ...    ...        ...           ...        ...        ...
# 1816  2015        4.4         99.23        399         61
# 1817  2015        4.0        108.70        201         39
# 1818  2015        5.2         97.20        261         32
# 1820  2015        5.2         97.20        497         62
# 1835  2015        4.8        106.67        433         56
#
#                                               sentiment  \
# 392   {'neg': 0.038, 'neu': 0.881, 'pos': 0.081, 'co...
# 391   {'neg': 0.0, 'neu': 0.588, 'pos': 0.4120000000...
# 390   {'neg': 0.04, 'neu': 0.779, 'pos': 0.182, 'com...
# 388   {'neg': 0.167, 'neu': 0.602, 'pos': 0.231, 'co...
# 387   {'neg': 0.053, 'neu': 0.596, 'pos': 0.35100000...
# ...                                                 ...
# 1816  {'neg': 0.112, 'neu': 0.793, 'pos': 0.095, 'co...
# 1817  {'neg': 0.116, 'neu': 0.711, 'pos': 0.17300000...
# 1818  {'neg': 0.0, 'neu': 0.9490000000000001, 'pos':...
# 1820  {'neg': 0.101, 'neu': 0.789, 'pos': 0.11, 'com...
# 1835  {'neg': 0.014, 'neu': 0.898, 'pos': 0.088, 'co...
#
#                               title  f_k_grade                artist  \
# 392           Cry Of The Wild Goose        0.1         Frankie Laine
# 391   Dear Hearts And Gentle People        2.1           Bing Crosby
# 390                    Hoop-Dee-Doo        0.1            Perry Como
# 388              I'll Never Be Free        0.9  Tennessee Ernie Ford
# 387                 Tennessee Waltz        2.9            Patti Page
# ...                             ...        ...                   ...
# 1816  The Heart Wants What It Wants        0.9          Selena Gomez
# 1817                     Girl Crush       -0.7       Little Big Town
# 1818                    Slow Motion        1.7            Trey Songz
# 1820                 Truffle Butter        1.7           Nicki Minaj
# 1835                 Heartbeat Song        0.1        Kelly Clarkson
#
#       difficult_words  num_dupes
# 392                15         18
# 391                12         17
# 390                22         22
# 388                10          3
# 387                 5         10
# ...               ...        ...
# 1816               39         32
# 1817                8         14
# 1818               22         20
# 1820               78          2
# 1835               16         38
#
# [4028 rows x 15 columns]

# %%
df_concat.shape
# Out:
# (4028, 15)

# %%
df_concat.to_csv('../../data/CSV/1950_2015.csv', encoding='utf-8', index=False)
