# %% [markdown]
# # Imports

# %% [markdown]
# # Add decades

# %% [markdown]
# ## 1960er

# %%
import pandas as pd 

df = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-60s.csv")

# %%
df.head(5)
# Out:
#                    track            artist  ... sections  target
# 0  Jealous Kind Of Fella     Garland Green  ...        9       1
# 1          Initials B.B.  Serge Gainsbourg  ...       10       0
# 2           Melody Twist       Lord Melody  ...       12       0
# 3          Mi Bomba Sonó        Celia Cruz  ...        8       0
# 4            Uravu Solla       P. Susheela  ...       14       0
#
# [5 rows x 19 columns]

# %%
df['decades'] = '1960er'
df.head(2)
# Out:
#                    track            artist  ... target  decades
# 0  Jealous Kind Of Fella     Garland Green  ...      1   1960er
# 1          Initials B.B.  Serge Gainsbourg  ...      0   1960er
#
# [2 rows x 20 columns]

# %%
df.shape
# Out:
# (8642, 20)

# %%
df.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-60s.csv")

# %% [markdown]
# ## 1970er

# %%
import pandas as pd 

df1 = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-70s.csv")

# %%
df1.head(5)
# Out:
#                track                artist  ... sections  target
# 0            Porque?       Reginaldo Rossi  ...        6       0
# 1          Free Jazz  Maria Teresa Luciani  ...        9       0
# 2  Reject of Society                 Crass  ...        6       0
# 3             Yeah !              The Jets  ...        7       0
# 4   Gotta Find A Way           The Moments  ...       12       1
#
# [5 rows x 19 columns]

# %%
df1.shape
# Out:
# (7766, 19)

# %%
df1['decades'] = '1970er'
df1.head(2)
# Out:
#        track                artist  ... target  decades
# 0    Porque?       Reginaldo Rossi  ...      0   1970er
# 1  Free Jazz  Maria Teresa Luciani  ...      0   1970er
#
# [2 rows x 20 columns]

# %%
df1.shape
# Out:
# (7766, 20)

# %%
df1.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-70s.csv")

# %% [markdown]
# ## 1980er

# %%
import pandas as pd 

df2 = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-80s.csv")

# %%
df2.head(5)
# Out:
#                   track            artist  ... sections  target
# 0         Walking Blues  Big Joe Williams  ...        7       0
# 1  Suddenly Last Summer        The Motels  ...       11       1
# 2             Sanctuary        Béla Fleck  ...       17       0
# 3        The Wild Rover        The Pogues  ...        7       0
# 4  In The Driver's Seat    John Schneider  ...        7       1
#
# [5 rows x 19 columns]

# %%
df2.shape
# Out:
# (6908, 19)

# %%
df2['decades'] = '1980er'
df2.head(2)
# Out:
#                   track            artist  ... target  decades
# 0         Walking Blues  Big Joe Williams  ...      0   1980er
# 1  Suddenly Last Summer        The Motels  ...      1   1980er
#
# [2 rows x 20 columns]

# %%
df2.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-80s.csv")

# %% [markdown]
# ## 1990er

# %%
import pandas as pd 

df3 = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-90s.csv")

# %%
df3.head(5)
# Out:
#                                             track  ... target
# 0                                     Misty Roses  ...      0
# 1                                      Never Ever  ...      1
# 2                                     Soul Sermon  ...      0
# 3                       Clarinet Marmalade - Live  ...      0
# 4  До смерті і довше - Drum & Base and Rock Remix  ...      0
#
# [5 rows x 19 columns]

# %%
df3.shape
# Out:
# (5520, 19)

# %%
df3['decades'] = '1990er'
df3.head(2)
# Out:
#          track           artist  ... target  decades
# 0  Misty Roses  Astrud Gilberto  ...      0   1990er
# 1   Never Ever       All Saints  ...      1   1990er
#
# [2 rows x 20 columns]

# %%
df3.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-90s.csv")

# %% [markdown]
# ## 2000er

# %%
import pandas as pd 

df4 = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-00s.csv")

# %%
df4.head(5)
# Out:
#                       track             artist  ... sections  target
# 0                 Lucky Man  Montgomery Gentry  ...       13       1
# 1            On The Hotline       Pretty Ricky  ...       10       1
# 2        Clouds Of Dementia         Candlemass  ...       13       0
# 3  Heavy Metal, Raise Hell!      Zwartketterij  ...        9       0
# 4           I Got A Feelin'   Billy Currington  ...       10       1
#
# [5 rows x 19 columns]

# %%
df4.shape
# Out:
# (5872, 19)

# %%
df4['decades'] = '2000er'
df4.head(2)
# Out:
#             track             artist  ... target  decades
# 0       Lucky Man  Montgomery Gentry  ...      1   2000er
# 1  On The Hotline       Pretty Ricky  ...      1   2000er
#
# [2 rows x 20 columns]

# %%
df4.shape
# Out:
# (5872, 20)

# %%
df4.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-00s.csv")

# %% [markdown]
# ## 2010er

# %%
import pandas as pd 

df5 = pd.read_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-10s.csv")

# %%
df5.head(5)
# Out:
#                                  track  ... target
# 0                          Wild Things  ...      1
# 1                            Surfboard  ...      0
# 2                         Love Someone  ...      1
# 3  Music To My Ears (feat. Tory Lanez)  ...      0
# 4        Juju On That Beat (TZ Anthem)  ...      1
#
# [5 rows x 19 columns]

# %%
df5.shape
# Out:
# (6398, 19)

# %%
df5['decades'] = '2010er'
df5.head(2)
# Out:
#          track        artist  ... target  decades
# 0  Wild Things  Alessia Cara  ...      1   2010er
# 1    Surfboard     Esquivel!  ...      0   2010er
#
# [2 rows x 20 columns]

# %%
df5.shape
# Out:
# (6398, 20)

# %%
df5.to_csv("../../../The-Spotify-Hit-Predictor-Dataset/dataset-of-10s.csv")

# %% [markdown]
# # Make one big datatset

# %%
# Concatenate dataframes row-wise
merged_df = pd.concat([df, df1, df2, df3, df4, df5], axis=0)

# Reset the index of the merged dataframe
merged_df = merged_df.reset_index(drop=True)

# Print the merged dataframe
merged_df
# Out:
#        Unnamed: 0                  track  ... target decades
# 0               0  Jealous Kind Of Fella  ...      1  1960er
# 1               1          Initials B.B.  ...      0  1960er
# 2               2           Melody Twist  ...      0  1960er
# 3               3          Mi Bomba Sonó  ...      0  1960er
# 4               4            Uravu Solla  ...      0  1960er
# ...           ...                    ...  ...    ...     ...
# 41101        6393          Lotus Flowers  ...      0  2010er
# 41102        6394      Calling My Spirit  ...      1  2010er
# 41103        6395          Teenage Dream  ...      1  2010er
# 41104        6396         Stormy Weather  ...      0  2010er
# 41105        6397                   Dust  ...      0  2010er
#
# [41106 rows x 21 columns]

# %%
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'track', 'artist', 'uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'chorus_hit', 'sections', 'target', 'decades'],
#       dtype='object')

# %%
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %%
merged_df.head(5)
# Out:
#                    track            artist  ... target  decades
# 0  Jealous Kind Of Fella     Garland Green  ...      1   1960er
# 1          Initials B.B.  Serge Gainsbourg  ...      0   1960er
# 2           Melody Twist       Lord Melody  ...      0   1960er
# 3          Mi Bomba Sonó        Celia Cruz  ...      0   1960er
# 4            Uravu Solla       P. Susheela  ...      0   1960er
#
# [5 rows x 20 columns]

# %%
merged_df.shape
# Out:
# (41106, 20)

# %%
merged_df.to_csv("../../data/CSV/ML_Datasets/big_dataset_with_decades.csv", index=False)

# %%
test.shape
# Out:
# (41106, 19)
