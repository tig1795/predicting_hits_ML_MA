# %% [markdown]
# # Vergleich der Lieder in der Spotify Playlist vs. in der urspünglichen CSV (Hits)

# %% [markdown]
# ## Beide Datasets einlesen

# %%
import pandas as pd 

hits = pd.read_csv("../../data/CSV/dataset_just_hits_new.csv")

# %%
hits.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
hits.shape
# Out:
# (939, 22)

# %%
import pandas as pd

hits_spotify = pd.read_csv("../../data/Spotify/hits_ma.csv")

# %%
hits_spotify.head(5)
# Out:
#                               Track URI  ...              Added At
# 0  spotify:track:1Eb90nmqTrxylKFhcUzW8P  ...  2023-03-17T09:16:20Z
# 1  spotify:track:2PzU4IB8Dr6mxV3lHuaG34  ...  2023-03-17T09:16:20Z
# 2  spotify:track:5y0YreEOnQiKFAnCrcFIXz  ...  2023-03-20T13:47:31Z
# 3  spotify:track:3jdBf1cJ2QmTzNUixplppA  ...  2023-03-17T09:16:20Z
# 4  spotify:track:3zBhihYUHBmGd2bcQIobrF  ...  2023-03-17T09:16:20Z
#
# [5 rows x 19 columns]

# %%
hits_spotify.shape
# Out:
# (939, 19)

# %% [markdown]
# ## Überflüssige Einträge entfernen

# %%
hits.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'value', 'Hit'],
#       dtype='object')

# %%
hits = hits.drop(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
       'flesch_index', 'num_lines', 'sentiment', 'f_k_grade',
       'difficult_words', 'num_dupes', 'number_of_tokens',
       'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
       'value', 'Hit'], axis=1)

# %%
hits.head(5)
# Out:
#                                title          artist
# 0  (Everything I Do) I Do It For You     Bryan Adams
# 1      (I Can't Get No) Satisfaction  Rolling Stones
# 2          (Just Like) Starting Over     John Lennon
# 3       (Love Is) Thicker Than Water       Andy Gibb
# 4   (Sittin' On) The Dock Of The Bay    Otis Redding

# %%
hits_spotify.columns
# Out:
# Index(['Track URI', 'Track Name', 'Artist URI(s)', 'Artist Name(s)',
#        'Album URI', 'Album Name', 'Album Artist URI(s)',
#        'Album Artist Name(s)', 'Album Release Date', 'Album Image URL',
#        'Disc Number', 'Track Number', 'Track Duration (ms)',
#        'Track Preview URL', 'Explicit', 'Popularity', 'ISRC', 'Added By',
#        'Added At'],
#       dtype='object')

# %%
hits_spotify = hits_spotify.drop(['Track URI', 'Artist URI(s)',
       'Album URI', 'Album Name', 'Album Artist URI(s)',
       'Album Artist Name(s)', 'Album Release Date', 'Album Image URL',
       'Disc Number', 'Track Number', 'Track Duration (ms)',
       'Track Preview URL', 'Explicit', 'Popularity', 'ISRC', 'Added By',
       'Added At'], axis=1)

# %%
hits_spotify.head(5)
# Out:
#                                      Track Name      Artist Name(s)
# 0             (Everything I Do) I Do It For You         Bryan Adams
# 1  (I Can't Get No) Satisfaction - Mono Version  The Rolling Stones
# 2   (Just Like) Starting Over - Remastered 2010         John Lennon
# 3                  (Love Is) Thicker Than Water           Andy Gibb
# 4              (Sittin' On) the Dock of the Bay        Otis Redding

# %%
hits_spotify.shape
# Out:
# (939, 2)

# %% [markdown]
# ## Beide Dataframes zusammenführen

# %%
checkup_hits = pd.concat([hits, hits_spotify], axis=1)

# %%
checkup_hits.head(5)
# Out:
#                                title          artist  \
# 0  (Everything I Do) I Do It For You     Bryan Adams
# 1      (I Can't Get No) Satisfaction  Rolling Stones
# 2          (Just Like) Starting Over     John Lennon
# 3       (Love Is) Thicker Than Water       Andy Gibb
# 4   (Sittin' On) The Dock Of The Bay    Otis Redding
#
#                                      Track Name      Artist Name(s)
# 0             (Everything I Do) I Do It For You         Bryan Adams
# 1  (I Can't Get No) Satisfaction - Mono Version  The Rolling Stones
# 2   (Just Like) Starting Over - Remastered 2010         John Lennon
# 3                  (Love Is) Thicker Than Water           Andy Gibb
# 4              (Sittin' On) the Dock of the Bay        Otis Redding

# %%
checkup_hits.to_csv("../../data/CSV/checkup_hits.csv", index=False)

# %% [markdown]
# ## Vergleich

# %%
import pandas as pd

checkup_hits = pd.read_csv("../../data/CSV/checkup_hits.csv")

# %%
# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
checkup_hits
# Out:
#                                            title  \
# 0              (Everything I Do) I Do It For You
# 1                  (I Can't Get No) Satisfaction
# 2                      (Just Like) Starting Over
# 3                   (Love Is) Thicker Than Water
# 4               (Sittin' On) The Dock Of The Bay
# 5                 (They Long To Be) Close To You
# 6    (Your Love Has Lifted Me) Higher And Higher
# 7                          ...Baby One More Time
# 8                                      1, 2 Step
# 9                                   21 Questions
# 10                                     4 Minutes
# 11                   50 Ways To Leave Your Lover
# 12                                           679
# 13                                        9 To 5
# 14                            A Hard Day's Night
# 15                            A Little More Love
# 16                              A Thousand Miles
# 17                             A Whole New World
# ...

# %%
# create a function to color multiple rows in red
def color_rows_red(row, red_rows=[109, 111, 112, 152, 167, 172, 173, 174, 182, 194, 215, 224, 227, 258, 287, 292, 301, 303, 305, 306, 313, 317, 329, 338, 352, 377, 390, 400, 408, 415, 423, 433, 467, 471, 492, 496, 508, 510, 516, 518, 519, 530, 533, 535, 575, 580, 589, 591, 602, 603, 619, 620, 628, 635, 638, 641, 643, 651, 654, 685, 690, 691, 722, 724, 725, 730, 738, 740, 772, 790, 791, 796, 797, 802, 817, 827, 861, 877, 902, 909, 911, 915, 919, 925, ]):
    color = 'red' if row.name in red_rows else 'black'
    return ['color: %s' % color] * len(row)

# apply the function to the DataFrame using Styler.apply()
styled_df = checkup_hits.style.apply(color_rows_red, axis=1)

# display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # Vergleich der Lieder in der Spotify Playlist vs. in der urspünglichen CSV (No Hits)

# %%
import pandas as pd 

no_hits = pd.read_csv("../../data/CSV/dataset_just_no_hits_new.csv")

# %%
no_hits.head(5)
# Out:
#                                               lyrics  ... Hit
# 0  it ain't the clothes that you wearit ain't the...  ...  No
# 1  woohpretty woman  walking down the streetprett...  ...  No
# 2  hey  man  i don't feel like goin' to school no...  ...  No
# 3  kick it!you wake up late for school  man  you ...  ...  No
# 4  i saw star wars at least 8 timeshad the pac-ma...  ...  No
#
# [5 rows x 22 columns]

# %%
no_hits.shape
# Out:
# (905, 22)

# %%
no_hits_spotify = pd.read_csv("../../data/Spotify/no_hits_ma.csv")

# %%
no_hits_spotify.head(5)
# Out:
#                               Track URI  ...              Added At
# 0  spotify:track:57ysLbmFhxX9WL9e5QTAmz  ...  2023-03-17T09:25:21Z
# 1  spotify:track:7ptv3yXdBWwzO7rVA62rwy  ...  2023-03-17T09:25:21Z
# 2  spotify:track:3kijKl7Er0lhgJsGAsNs1w  ...  2023-03-17T09:25:21Z
# 3  spotify:track:5NLuC70kZQv8q34QyQa1DP  ...  2023-03-17T09:25:21Z
# 4  spotify:track:0fwYreBOZKkfhmUWEf2vyB  ...  2023-03-17T09:25:21Z
#
# [5 rows x 19 columns]

# %%
no_hits_spotify.shape
# Out:
# (905, 19)

# %% [markdown]
# ## Überflüssige Einträge entfernen

# %%
no_hits.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'value', 'Hit'],
#       dtype='object')

# %%
no_hits = no_hits.drop(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
       'flesch_index', 'num_lines', 'sentiment', 'f_k_grade',
       'difficult_words', 'num_dupes', 'number_of_tokens',
       'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
       'value', 'Hit'], axis=1)

# %%
no_hits.head(5)
# Out:
#                                   title        artist
# 0  (It's Just) The Way That You Love Me   Paula Abdul
# 1                     (Oh) Pretty Woman     Van Halen
# 2                     (She's) Sexy + 17    Stray Cats
# 3      (You Gotta) Fight For Your Right  Beastie Boys
# 4                          19 Somethin'    Mark Wills

# %%
no_hits_spotify.columns
# Out:
# Index(['Track URI', 'Track Name', 'Artist URI(s)', 'Artist Name(s)',
#        'Album URI', 'Album Name', 'Album Artist URI(s)',
#        'Album Artist Name(s)', 'Album Release Date', 'Album Image URL',
#        'Disc Number', 'Track Number', 'Track Duration (ms)',
#        'Track Preview URL', 'Explicit', 'Popularity', 'ISRC', 'Added By',
#        'Added At'],
#       dtype='object')

# %%
no_hits_spotify = no_hits_spotify.drop(['Track URI', 'Artist URI(s)',
       'Album URI', 'Album Name', 'Album Artist URI(s)',
       'Album Artist Name(s)', 'Album Release Date', 'Album Image URL',
       'Disc Number', 'Track Number', 'Track Duration (ms)',
       'Track Preview URL', 'Explicit', 'Popularity', 'ISRC', 'Added By',
       'Added At'], axis=1)

# %%
no_hits_spotify.head(5)
# Out:
#                           Track Name Artist Name(s)
# 0           The Way That You Love Me    Paula Abdul
# 1  (Oh) Pretty Woman - 2015 Remaster      Van Halen
# 2                (She's) Sexy and 17     Stray Cats
# 3               Fight For Your Right   Beastie Boys
# 4                       19 Somethin'     Mark Wills

# %%
no_hits_spotify.shape
# Out:
# (905, 2)

# %% [markdown]
# ## Beide Dataframes zusammenführen

# %%
checkup_no_hits = pd.concat([no_hits, no_hits_spotify], axis=1)

# %%
checkup_no_hits.head(5)
# Out:
#                                   title        artist  \
# 0  (It's Just) The Way That You Love Me   Paula Abdul
# 1                     (Oh) Pretty Woman     Van Halen
# 2                     (She's) Sexy + 17    Stray Cats
# 3      (You Gotta) Fight For Your Right  Beastie Boys
# 4                          19 Somethin'    Mark Wills
#
#                           Track Name Artist Name(s)
# 0           The Way That You Love Me    Paula Abdul
# 1  (Oh) Pretty Woman - 2015 Remaster      Van Halen
# 2                (She's) Sexy and 17     Stray Cats
# 3               Fight For Your Right   Beastie Boys
# 4                       19 Somethin'     Mark Wills

# %%
checkup_no_hits.shape
# Out:
# (905, 4)

# %%
checkup_no_hits.to_csv("../../data/CSV/checkup_no_hits.csv", index=False)

# %% [markdown]
# ## Vergleich

# %%
import pandas as pd

checkup_no_hits = pd.read_csv("../../data/CSV/checkup_no_hits.csv")

# %%
# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
checkup_no_hits
# Out:
#                                              title  \
# 0             (It's Just) The Way That You Love Me
# 1                                (Oh) Pretty Woman
# 2                                (She's) Sexy + 17
# 3                 (You Gotta) Fight For Your Right
# 4                                     19 Somethin'
# 5                                 1st Of Tha Month
# 6                                          21 Guns
# 7                                                3
# 8                          4 Seasons Of Loneliness
# 9                                        5 O'Clock
# 10                          50 Ways To Say Goodbye
# 11                                        634-5789
# 12                                        7 Things
# 13                              A Different Corner
# 14                             A Fool Never Learns
# 15                                  A Love Bizarre
# 16                                     A Love Song
# ...

# %%
# create a function to color multiple rows in red
def color_rows_red(row, red_rows=[2, 17, 27, 60, 65, 69, 74, 88, 89, 91, 94, 116, 128, 130, 136, 139, 146, 149, 151, 156, 165, 172, 184, 198, 209, 255, 281, 283, 308, 310, 337, 346, 354, 358, 366, 379, 400, 415, 434, 464, 476, 493, 508, 533, 550, 561, 567, 571, 572, 601, 608, 617, 620, 663, 666, 692, 703, 715, 716, 725, 727, 741, 746, 772, 797, 813, 818, 829, 831, 857, 884]):
    color = 'red' if row.name in red_rows else 'black'
    return ['color: %s' % color] * len(row)

# apply the function to the DataFrame using Styler.apply()
styled_df1 = checkup_no_hits.style.apply(color_rows_red, axis=1)

# display the styled DataFrame
styled_df1
# Out:
# <style type="text/css">
# ...
