# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
data_ML = pd.read_csv("../data/CSV/ML_Datasets/dataset_ML.csv")

# %%
df.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
df.shape
# Out:
# (1801, 45)

# %%
from collections import Counter

Counter(df.Hit)
# Out:
# Counter({'Yes': 912, 'No': 889})

# %% [markdown]
# # Dataframe with only None-Songs

# %%
df1 = pd.read_csv("../data/old_datasets/CSV/dataset_complete.csv")

# %%
df1.shape
# Out:
# (3669, 26)

# %%
df1.head(5)
# Out:
#                                               lyrics  \
# 0   here she comes  mmm  just like an angelseems ...
# 1  look into my eyes  you will seewhat you mean t...
# 2  i can't get no satisfactioni can't get no sati...
# 3  oh  i  i just died in your arms tonightit must...
# 4  your love is fadin'  i feel it fadeah  your lo...
#
#                                                genre  num_syllables  pos  \
# 0    ['alternative rock', 'glam metal', 'hard rock']          405.0   27
# 1  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 2  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 3                           ['classic pop and rock']          372.6   32
# 4  ['american', 'psychedelic rock', 'psychedelic ...          251.1   55
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8         89.75         43
# 1  1991        4.4        107.69         36
# 2  1965        4.8        106.67         37
# ...

# %%
from collections import Counter

Counter(df1.Hit)
# Out:
# Counter({'None': 1866, 'Yes': 912, 'No': 891})

# %% [markdown]
# # Delete Songs, because not on Spotify

# %%
df1[df1['title'] == 'Do I Make you Proud']
# Out:
#                                                 lyrics  \
# 716  i've never beenthe one to raise my handthat wa...
#
#                                                  genre  num_syllables  pos  \
# 716  ['american', 'american idol', 'blue-eyed soul'...          376.2   99
#
#      year  fog_index  flesch_index  num_lines  \
# 716  2006        4.0        100.24         55
#
#                                              sentiment                title  \
# 716  {'neg': 0.01, 'neu': 0.803, 'pos': 0.187, 'com...  Do I Make you Proud
#
#      ...  decades                                       stemmed_text  \
# 716  ...    2000s   i 've never beenth one to rais my handthat wa...
#
#                                               POS_tags  \
# 716  ['PRP', 'VBP', 'RB', 'VB', 'CD', 'TO', 'VB', '...
#
#                                                    POS    values  pred  \
# 716  meand fullof endless beginningthis only nowis ...  0.010101     1
#
# ...

# %%
df1 = df1.drop(716)

# %%
df1[df1['title'] == 'Do I Make you Proud']
# Out:
# Empty DataFrame
# Columns: [lyrics, genre, num_syllables, pos, year, fog_index, flesch_index, num_lines, sentiment, title, f_k_grade, artist, difficult_words, num_dupes, number_of_tokens, number_of_types, decades, stemmed_text, POS_tags, POS, values, pred, label, score, emotion_label, Hit]
# Index: []
#
# [0 rows x 26 columns]

# %%
df1[df1['title'] == 'The Beach Boys Medley']
# Out:
#                                                  lyrics  \
# 3004  i  i love the colorful clothes she wears and t...
#
#                                                   genre  num_syllables  pos  \
# 3004  ['american', 'américain', 'b7005bb9-fcd9-4d06-...          640.8   93
#
#       year  fog_index  flesch_index  num_lines  \
# 3004  1981        4.0        100.24         87
#
#                                               sentiment  \
# 3004  {'neg': 0.002, 'neu': 0.732, 'pos': 0.267, 'co...
#
#                       title  ...  decades  \
# 3004  The Beach Boys Medley  ...    1980s
#
#                                            stemmed_text  \
# 3004   i i love the color cloth she wear and the way...
#
#                                                POS_tags  \
# 3004  ['PRP', '_SP', 'PRP', 'VBP', 'DT', 'JJ', 'NNS'...
#
#                                                     POS    values  pred  \
# 3004  colorful gentle pickin good good good good goo...  0.010753     1
#
# ...

# %%
df1 = df1.drop(3004)

# %%
df1[df1['title'] == 'The Beach Boys Medley']
# Out:
# Empty DataFrame
# Columns: [lyrics, genre, num_syllables, pos, year, fog_index, flesch_index, num_lines, sentiment, title, f_k_grade, artist, difficult_words, num_dupes, number_of_tokens, number_of_types, decades, stemmed_text, POS_tags, POS, values, pred, label, score, emotion_label, Hit]
# Index: []
#
# [0 rows x 26 columns]

# %%
from collections import Counter

Counter(df1.Hit)
# Out:
# Counter({'None': 1866, 'Yes': 912, 'No': 889})

# %% [markdown]
# # Filter the none songs

# %%
neither = df1[df1['Hit'] == 'None']

# %%
neither
# Out:
#                                                  lyrics  \
# 0      here she comes  mmm  just like an angelseems ...
# 3     oh  i  i just died in your arms tonightit must...
# 4     your love is fadin'  i feel it fadeah  your lo...
# 5     as my life goes on  i believesomehow  somethin...
# 8     if it seems a little time is neededdecisions t...
# ...                                                 ...
# 3662  shawty  i'ma only tell you this once: you the ...
# 3664  maybe i need some rehabor maybe just need some...
# 3665  your mama don't dance andyour daddy don't rock...
# 3666  every day there's something newhoney  to keep ...
# 3668  just tell me what you've got to say to me i've...
#
#                                                   genre  num_syllables  pos  \
# 0       ['alternative rock', 'glam metal', 'hard rock']          405.0   27
# 3                              ['classic pop and rock']          372.6   32
# ...

# %% [markdown]
# # Again, delete songs, which are not on spotify

# %%
neither[neither['artist'] == 'Shanice']
# Out:
#                                                  lyrics  \
# 2591  i've never been so sure about anything beforeb...
#
#                                                   genre  num_syllables  pos  \
# 2591  ['80s', '90s', 'hip hop rnb and dance hall', '...          315.0   33
#
#       year  fog_index  flesch_index  num_lines  \
# 2591  1993        4.0         74.86         43
#
#                                               sentiment  \
# 2591  {'neg': 0.012, 'neu': 0.809, 'pos': 0.179, 'co...
#
#                        title  ...  decades  \
# 2591  Saving Forever For You  ...    1990s
#
#                                            stemmed_text  \
# 2591   i 've never been so sure about anyth beforebu...
#
#                                                POS_tags  \
# 2591  ['PRP', 'VBP', 'RB', 'VBN', 'RB', 'JJ', 'IN', ...
#
#                                                     POS    values  pred  \
# 2591  sure only tolove lifetimewon't only tolove you...  0.030303     1
#
# ...

# %%
neither = neither.drop(2591)

# %%
neither[neither['artist'] == 'Shanice']
# Out:
# Empty DataFrame
# Columns: [lyrics, genre, num_syllables, pos, year, fog_index, flesch_index, num_lines, sentiment, title, f_k_grade, artist, difficult_words, num_dupes, number_of_tokens, number_of_types, decades, stemmed_text, POS_tags, POS, values, pred, label, score, emotion_label, Hit]
# Index: []
#
# [0 rows x 26 columns]

# %%
neither[neither['artist'] == 'Dream']
# Out:
#                                                  lyrics genre  num_syllables  \
# 1169  give it your all girl  give it all ya gotyou c...   pop          549.0
#
#       pos  year  fog_index  flesch_index  num_lines  \
# 1169   28  2001        4.8        106.67         66
#
#                                               sentiment           title  ...  \
# 1169  {'neg': 0.046, 'neu': 0.743, 'pos': 0.212, 'co...  He Loves U Not  ...
#
#       decades                                       stemmed_text  \
# 1169    2000s   give it your all girl give it all ya gotyou c...
#
#                                                POS_tags  \
# 1169  ['VB', 'PRP', 'PRP$', 'DT', 'NN', '_SP', 'VBP'...
#
#                                                     POS    values  pred  \
# 1169  full open sweet sweet pretty free kinda new ot...  0.035714     0
#
#          label     score emotion_label   Hit
# 1169  NEGATIVE  0.700223           joy  None
#
# [1 rows x 26 columns]

# %%
neither = neither.drop(1169)

# %%
neither[neither['artist'] == 'Dream']
# Out:
# Empty DataFrame
# Columns: [lyrics, genre, num_syllables, pos, year, fog_index, flesch_index, num_lines, sentiment, title, f_k_grade, artist, difficult_words, num_dupes, number_of_tokens, number_of_types, decades, stemmed_text, POS_tags, POS, values, pred, label, score, emotion_label, Hit]
# Index: []
#
# [0 rows x 26 columns]

# %%
neither[neither['artist'] == 'Puff Daddy']
# Out:
#                                                  lyrics        genre  \
# 572   uh-huh yeah  2x uh uh-huh yeah  4x yeahhear my...  hip-hop/rnb
# 3334  intro: notorious b.i.g.one  one twocheck me ou...  hip-hop/rnb
#
#       num_syllables  pos  year  fog_index  flesch_index  num_lines  \
# 572           595.8   47  1998        4.0        100.24         87
# 3334         1089.0   68  1998        4.8         98.21        120
#
#                                               sentiment         title  ...  \
# 572   {'neg': 0.203, 'neu': 0.672, 'pos': 0.125, 'co...  Come With Me  ...
# 3334  {'neg': 0.21, 'neu': 0.714, 'pos': 0.076, 'com...       Victory  ...
#
#       decades                                       stemmed_text  \
# 572     1990s   uh-huh yeah 2x uh uh-huh yeah 4x yeahhear my ...
# 3334    1990s   intro : notori b.i.g.on one twocheck me out r...
#
#                                                POS_tags  \
# 572   ['UH', 'UH', 'UH', 'UH', '_SP', 'CD', 'UH', 'U...
# ...

# %%
neither = neither.drop(572)

# %%
neither[neither['title'] == 'Come With Me']
# Out:
# Empty DataFrame
# Columns: [lyrics, genre, num_syllables, pos, year, fog_index, flesch_index, num_lines, sentiment, title, f_k_grade, artist, difficult_words, num_dupes, number_of_tokens, number_of_types, decades, stemmed_text, POS_tags, POS, values, pred, label, score, emotion_label, Hit]
# Index: []
#
# [0 rows x 26 columns]

# %%
neither.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'values', 'pred', 'label', 'score', 'emotion_label', 'Hit'],
#       dtype='object')

# %%
neither.shape
# Out:
# (1863, 26)

# %%
neither
# Out:
#                                                  lyrics  \
# 0      here she comes  mmm  just like an angelseems ...
# 3     oh  i  i just died in your arms tonightit must...
# 4     your love is fadin'  i feel it fadeah  your lo...
# 5     as my life goes on  i believesomehow  somethin...
# 8     if it seems a little time is neededdecisions t...
# ...                                                 ...
# 3662  shawty  i'ma only tell you this once: you the ...
# 3664  maybe i need some rehabor maybe just need some...
# 3665  your mama don't dance andyour daddy don't rock...
# 3666  every day there's something newhoney  to keep ...
# 3668  just tell me what you've got to say to me i've...
#
#                                                   genre  num_syllables  pos  \
# 0       ['alternative rock', 'glam metal', 'hard rock']          405.0   27
# 3                              ['classic pop and rock']          372.6   32
# ...

# %%
df_sorted = neither.sort_values(by='artist', ascending=True)

# %%
df_sorted
# Out:
#                                                  lyrics  \
# 306   take me now  baby  here as i amhold me close  ...
# 1532  i'm not in love  so don't forget itit's just a...
# 3108  too many broken hearts have fallen in the rive...
# 2311   112 keep it real  yeeaahhhh keep it real  puf...
# 628   everybody put your hands togetherwhooo  mmmm  ...
# ...                                                 ...
# 1814  she's got legs  she knows how to use themshe n...
# 1614  in the year 2525if man is still aliveif woman ...
# 541   high dive into frozen waveswhere the past come...
# 1241  everybody move your body now do ithere is some...
# 1127  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 306   ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1532  ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# ...

# %%
list(df_sorted.artist)
# Out:
# ['10,000 Maniacs',
#  '10cc',
#  '10cc',
#  '112',
#  '112',
#  '112',
#  '112',
#  '2 Chainz',
#  '2Pac',
#  '2Pac',
#  '3 Doors Down',
#  '3 Doors Down',
#  '3LW',
#  '3t',
#  '4 Non Blondes',
#  '50 Cent',
#  '69 Boyz',
#  '702',
#  '98 Degrees',
#  '98 Degrees',
#  '98 Degrees',
#  'A Flock Of Seagulls',
#  'ABBA',
#  'ABBA',
#  'ABBA',
#  'AWOLNATION',
#  'Aaliyah',
#  'Aaliyah',
#  'Aaliyah',
#  'Aaliyah',
#  'Aaliyah',
#  'Ace',
#  'Ace Of Base',
#  'Adam Ant',
#  'Adam Lambert',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'Aerosmith',
#  'After The Fire',
#  'Air Supply',
#  'Air Supply',
#  'Air Supply',
#  'Air Supply',
#  'Air Supply',
#  'Air Supply',
#  'Akon',
#  'Akon',
#  'Akon',
#  'Akon',
#  'Al Green',
#  'Al Green',
#  'Al Green',
#  'Al Martino',
#  'Alabama',
#  'Alan Jackson',
#  'Alan Parsons Project',
#  'Alan Parsons Project',
#  'Alan Parsons Project',
#  'Alex Clare',
# ...

# %%
df_sorted.reset_index(drop=True, inplace=True)

# %%
list(df_sorted.title)
# Out:
# ['Because The Night',
#  "I'm Not In Love",
#  'The Things We Do For Love',
#  'Only You',
#  'Cupid',
#  'Anywhere',
#  "It's Over Now",
#  'No Lie',
#  'I Get Around',
#  'Keep Ya Head Up',
#  "It'S Not My Time",
#  'Let Me Go',
#  'No More',
#  'Anything',
#  "What's Up",
#  'Wanksta',
#  'Tootsee Roll',
#  'Get It Together',
#  'The Hardest Thing',
#  'Because Of You',
#  'Invisible Man',
#  'I Ran',
#  'The Winner Takes It All',
#  'Waterloo',
#  'Take A Chance On Me',
#  'Sail',
#  'At Your Best',
#  'Back and Forth',
#  'If Your Girl Only Knew',
#  'The One I Gave My Heart To',
#  'More than a Woman',
#  'How Long',
#  'Cruel Summer',
#  'Goody Two Shoes',
#  'Whataya Want From Me',
#  'Jaded',
#  "Janie's Got A Gun",
#  "I Don't Want To Miss A Thing",
#  'Dream On',
#  'Crazy',
#  'Angel',
#  'Amazing',
#  "Cryin'",
#  'Der Kommissar',
#  'Making Love Out Of Nothing At All',
#  'Even The Nights Are Better',
#  'All Out Of Love',
#  'Sweet Dreams',
# ...

# %%
df_sorted
# Out:
#                                                  lyrics  \
# 0     take me now  baby  here as i amhold me close  ...
# 1     i'm not in love  so don't forget itit's just a...
# 2     too many broken hearts have fallen in the rive...
# 3      112 keep it real  yeeaahhhh keep it real  puf...
# 4     everybody put your hands togetherwhooo  mmmm  ...
# ...                                                 ...
# 1858  she's got legs  she knows how to use themshe n...
# 1859  in the year 2525if man is still aliveif woman ...
# 1860  high dive into frozen waveswhere the past come...
# 1861  everybody move your body now do ithere is some...
# 1862  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 0     ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1     ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# ...

# %%
df_sorted.to_csv('../../predicting_hits_ML_MA/data/CSV/just_none_songs.csv')

# %% [markdown]
# # Last CheckUp

# %%
import pandas as pd

df_sorted = pd.read_csv('../../predicting_hits_ML_MA/data/CSV/just_none_songs.csv', index_col=0)

# %%
df_sorted
# Out:
#                                                  lyrics  \
# 0     take me now  baby  here as i amhold me close  ...
# 1     i'm not in love  so don't forget itit's just a...
# 2     too many broken hearts have fallen in the rive...
# 3      112 keep it real  yeeaahhhh keep it real  puf...
# 4     everybody put your hands togetherwhooo  mmmm  ...
# ...                                                 ...
# 1858  she's got legs  she knows how to use themshe n...
# 1859  in the year 2525if man is still aliveif woman ...
# 1860  high dive into frozen waveswhere the past come...
# 1861  everybody move your body now do ithere is some...
# 1862  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 0     ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1     ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# ...

# %%
selected_columns = ['artist', 'title']
df_filtered = df_sorted[selected_columns]

# %%
pd.set_option('display.max_rows', None)

df_filtered
# Out:
#                                          artist  \
# 0                                10,000 Maniacs
# 1                                          10cc
# 2                                          10cc
# 3                                           112
# 4                                           112
# 5                                           112
# 6                                           112
# 7                                      2 Chainz
# 8                                          2Pac
# 9                                          2Pac
# 10                                 3 Doors Down
# 11                                 3 Doors Down
# 12                                          3LW
# 13                                           3t
# 14                                4 Non Blondes
# 15                                      50 Cent
# 16                                      69 Boyz
# 17                                          702
# ...

# %%
df_filtered.to_csv('../data/CSV/artist_title_none2.0.csv')

# %%
df_filtered[df_filtered['title'] == "Signs"]
# Out:
#      artist  title
# 1729  Tesla  Signs

# %%
df_filtered.iloc[1851:1854]
# Out:
#                artist          title
# 1851  Ying Yang Twins           Wait
# 1852      Young Jeezy  Soul Survivor
# 1853      Young Jeezy         Put On

# %% [markdown]
# # Pickle to CSV

# %%
import pandas as pd
import pickle

# 1. Load the Pickle File
with open('../code/2_audio_features/Playlists/none.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data.head(5)
# Out:
#                playlistID                                          TrackName  \
# 0  1uebWA75dLHSkk7XavGMaB                                  Because the Night
# 1  1uebWA75dLHSkk7XavGMaB                                    I'm Not In Love
# 2  1uebWA75dLHSkk7XavGMaB                          The Things We Do For Love
# 3  1uebWA75dLHSkk7XavGMaB  Only You (feat. The Notorious B.I.G., Ma$e) - ...
# 4  1uebWA75dLHSkk7XavGMaB                                              Cupid
#
#                   TrackID                                          SampleURL  \
# 0  3huXBuHMJFygfIUbH6erg6  https://p.scdn.co/mp3-preview/21672fd56658df2b...
# 1  5HQEmiV2lKnSO6qa2fsR7x  https://p.scdn.co/mp3-preview/97b17a635a4cd0d0...
# 2  6KEWtSOGKpIXGw6l1uJgsR  https://p.scdn.co/mp3-preview/9753ed4bec17d170...
# 3  6zOg9gP62RJSsKFeOBAgvH  https://p.scdn.co/mp3-preview/f92c181372dff481...
# 4  3kVIFDE3G89I2RPVkiRaRj  https://p.scdn.co/mp3-preview/e56eaed5088739e8...
#
# ...

# %%
data.shape
# Out:
# (1863, 19)

# %%
data[data['TrackName'] == 'Groove Thang']
# Out:
#                   playlistID     TrackName                 TrackID  \
# 1862  1uebWA75dLHSkk7XavGMaB  Groove Thang  4au81WOeFQWUQvHh7WCGz2
#
#                                               SampleURL ReleaseYear  \
# 1862  https://p.scdn.co/mp3-preview/a3399cf39a2ffaa0...  1994-01-01
#
#                        Genres  danceability  energy  loudness  speechiness  \
# 1862  [contemporary r&b, r&b]         0.911    0.49    -7.208       0.0394
#
#       acousticness  instrumentalness  liveness  valence    tempo key mode  \
# 1862         0.029           0.00105    0.0751    0.842  102.046   9    0
#
#      duration_ms  Popularity
# 1862      235000        53.0

# %%
data.iloc[1861:1864]
# Out:
#                   playlistID     TrackName                 TrackID  \
# 1861  1uebWA75dLHSkk7XavGMaB  Hey Mr. D.J.  6eB35pgMXdfhz5Z0WjwF1O
# 1862  1uebWA75dLHSkk7XavGMaB  Groove Thang  4au81WOeFQWUQvHh7WCGz2
#
#                                               SampleURL ReleaseYear  \
# 1861  https://p.scdn.co/mp3-preview/2fd9137208be704d...  1994-01-01
# 1862  https://p.scdn.co/mp3-preview/a3399cf39a2ffaa0...  1994-01-01
#
#                        Genres  danceability  energy  loudness  speechiness  \
# 1861  [contemporary r&b, r&b]         0.865   0.557    -8.018       0.0612
# 1862  [contemporary r&b, r&b]         0.911   0.490    -7.208       0.0394
#
#       acousticness  instrumentalness  liveness  valence    tempo key mode  \
# 1861        0.0221           0.00353    0.0973    0.859  101.295   2    1
# 1862        0.0290           0.00105    0.0751    0.842  102.046   9    0
#
#      duration_ms  Popularity
# 1861      252400        64.0
# 1862      235000        53.0

# %%
# 2. Convert Data to a DataFrame (if needed)
# If your data is already a DataFrame, you can skip this step.

# Example: If it's a list of dictionaries, you can convert it to a DataFrame like this:
# df = pd.DataFrame(data)

# 3. Save the DataFrame to a CSV File
data.to_csv('../data/CSV/none_with_afs.csv', index=False)

# %%
jo = pd.read_csv('../data/CSV/none_with_afs.csv')

# %%
jo.head(5)
# Out:
#                playlistID                                          TrackName  \
# 0  1uebWA75dLHSkk7XavGMaB                                  Because the Night
# 1  1uebWA75dLHSkk7XavGMaB                                    I'm Not In Love
# 2  1uebWA75dLHSkk7XavGMaB                          The Things We Do For Love
# 3  1uebWA75dLHSkk7XavGMaB  Only You (feat. The Notorious B.I.G., Ma$e) - ...
# 4  1uebWA75dLHSkk7XavGMaB                                              Cupid
#
#                   TrackID                                          SampleURL  \
# 0  3huXBuHMJFygfIUbH6erg6  https://p.scdn.co/mp3-preview/21672fd56658df2b...
# 1  5HQEmiV2lKnSO6qa2fsR7x  https://p.scdn.co/mp3-preview/97b17a635a4cd0d0...
# 2  6KEWtSOGKpIXGw6l1uJgsR  https://p.scdn.co/mp3-preview/9753ed4bec17d170...
# 3  6zOg9gP62RJSsKFeOBAgvH  https://p.scdn.co/mp3-preview/f92c181372dff481...
# 4  3kVIFDE3G89I2RPVkiRaRj  https://p.scdn.co/mp3-preview/e56eaed5088739e8...
#
# ...

# %%
jo.shape
# Out:
# (1863, 19)

# %% [markdown]
# # Concat Datasets

# %%
import pandas as pd

data1 = pd.read_csv('../../predicting_hits_ML_MA/data/CSV/just_none_songs.csv', index_col=0)

# %%
data1.head(5)
# Out:
#                                               lyrics  \
# 0  take me now  baby  here as i amhold me close  ...
# 1  i'm not in love  so don't forget itit's just a...
# 2  too many broken hearts have fallen in the rive...
# 3   112 keep it real  yeeaahhhh keep it real  puf...
# 4  everybody put your hands togetherwhooo  mmmm  ...
#
#                                                genre  num_syllables  pos  \
# 0  ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1  ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# 2  ['art pop', 'art rock', 'british', 'classic po...          395.1   44
# 3                                        hip-hop/rnb          765.0   34
# 4                                        hip-hop/rnb          228.6   37
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1994        4.4         90.77         40
# 1  1975        4.8        106.67         31
# 2  1977        5.2         97.20         38
# ...

# %%
data1.shape
# Out:
# (1863, 26)

# %%
data1.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'values', 'pred', 'label', 'score', 'emotion_label', 'Hit'],
#       dtype='object')

# %%
data2 = pd.read_csv('../data/CSV/none_with_afs.csv')

# %%
data2.columns
# Out:
# Index(['playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'key', 'mode', 'duration_ms', 'Popularity'],
#       dtype='object')

# %%
data2.head(5)
# Out:
#                playlistID                                          TrackName  \
# 0  1uebWA75dLHSkk7XavGMaB                                  Because the Night
# 1  1uebWA75dLHSkk7XavGMaB                                    I'm Not In Love
# 2  1uebWA75dLHSkk7XavGMaB                          The Things We Do For Love
# 3  1uebWA75dLHSkk7XavGMaB  Only You (feat. The Notorious B.I.G., Ma$e) - ...
# 4  1uebWA75dLHSkk7XavGMaB                                              Cupid
#
#                   TrackID                                          SampleURL  \
# 0  3huXBuHMJFygfIUbH6erg6  https://p.scdn.co/mp3-preview/21672fd56658df2b...
# 1  5HQEmiV2lKnSO6qa2fsR7x  https://p.scdn.co/mp3-preview/97b17a635a4cd0d0...
# 2  6KEWtSOGKpIXGw6l1uJgsR  https://p.scdn.co/mp3-preview/9753ed4bec17d170...
# 3  6zOg9gP62RJSsKFeOBAgvH  https://p.scdn.co/mp3-preview/f92c181372dff481...
# 4  3kVIFDE3G89I2RPVkiRaRj  https://p.scdn.co/mp3-preview/e56eaed5088739e8...
#
# ...

# %%
data2.shape
# Out:
# (1863, 19)

# %%
result = pd.concat([data1, data2], axis=1)

# %%
result.head(5)
# Out:
#                                               lyrics  \
# 0  take me now  baby  here as i amhold me close  ...
# 1  i'm not in love  so don't forget itit's just a...
# 2  too many broken hearts have fallen in the rive...
# 3   112 keep it real  yeeaahhhh keep it real  puf...
# 4  everybody put your hands togetherwhooo  mmmm  ...
#
#                                                genre  num_syllables  pos  \
# 0  ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1  ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# 2  ['art pop', 'art rock', 'british', 'classic po...          395.1   44
# 3                                        hip-hop/rnb          765.0   34
# 4                                        hip-hop/rnb          228.6   37
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1994        4.4         90.77         40
# 1  1975        4.8        106.67         31
# 2  1977        5.2         97.20         38
# ...

# %%
selected_columns = result[['TrackName', 'title']]

# %%
selected_columns.iloc[1860:1863]
# Out:
#          TrackName         title
# 1860       Clarity       Clarity
# 1861  Hey Mr. D.J.  Hey Mr. D.J.
# 1862  Groove Thang  Groove Thang

# %%
result.shape
# Out:
# (1863, 45)

# %%
result.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'values', 'pred', 'label', 'score', 'emotion_label', 'Hit',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'key', 'mode', 'duration_ms', 'Popularity'],
#       dtype='object')

# %%
data_ML.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'key', 'mode', 'duration_ms', 'Popularity', 'values', 'pred', 'label',
#        'score', 'emotion_label', 'Hit'],
#       dtype='object')

# %%
data_ML.shape
# Out:
# (1801, 45)

# %%
# Define the desired column order
new_order = ['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
       'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
       'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
       'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
       'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
       'Genres', 'danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'key', 'mode', 'duration_ms', 'Popularity', 'values', 'pred', 'label',
       'score', 'emotion_label', 'Hit']

# Create a new DataFrame with the specified column order
result_reordered = result[new_order]

# %%
result_reordered.head(5)
# Out:
#                                               lyrics  \
# 0  take me now  baby  here as i amhold me close  ...
# 1  i'm not in love  so don't forget itit's just a...
# 2  too many broken hearts have fallen in the rive...
# 3   112 keep it real  yeeaahhhh keep it real  puf...
# 4  everybody put your hands togetherwhooo  mmmm  ...
#
#                                                genre  num_syllables  pos  \
# 0  ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1  ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# 2  ['art pop', 'art rock', 'british', 'classic po...          395.1   44
# 3                                        hip-hop/rnb          765.0   34
# 4                                        hip-hop/rnb          228.6   37
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1994        4.4         90.77         40
# 1  1975        4.8        106.67         31
# 2  1977        5.2         97.20         38
# ...

# %%
result_reordered.shape
# Out:
# (1863, 45)

# %%
result_reordered.to_csv('../data/CSV/none_songs_complete.csv', index=False)

# %% [markdown]
# ## Concat none hits with hits and no hits

# %%
bf = pd.read_csv('../data/CSV/none_songs_complete.csv')

# %%
bf.head(5)
# Out:
#                                               lyrics  \
# 0  take me now  baby  here as i amhold me close  ...
# 1  i'm not in love  so don't forget itit's just a...
# 2  too many broken hearts have fallen in the rive...
# 3   112 keep it real  yeeaahhhh keep it real  puf...
# 4  everybody put your hands togetherwhooo  mmmm  ...
#
#                                                genre  num_syllables  pos  \
# 0  ['+usa new york', 'acoustic rock', 'alternativ...          308.7   40
# 1  ['art pop', 'art rock', 'british', 'classic po...          236.7   42
# 2  ['art pop', 'art rock', 'british', 'classic po...          395.1   44
# 3                                        hip-hop/rnb          765.0   34
# 4                                        hip-hop/rnb          228.6   37
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1994        4.4         90.77         40
# 1  1975        4.8        106.67         31
# 2  1977        5.2         97.20         38
# ...

# %%
bf.shape
# Out:
# (1863, 45)

# %%
data_ML = pd.read_csv("../data/CSV/ML_Datasets/dataset_ML.csv")

# %%
data_ML.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
data_ML.shape
# Out:
# (1801, 45)

# %%
from collections import Counter

Counter(data_ML.Hit)
# Out:
# Counter({'Yes': 912, 'No': 889})

# %%
# Concatenate DataFrames by rows
final = pd.concat([data_ML, bf], axis=0)

# %%
final.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
final.shape
# Out:
# (3664, 45)

# %%
from collections import Counter

Counter(final.Hit)
# Out:
# Counter({'Yes': 912, 'No': 889, 'None': 1863})

# %%
final.iloc[3660:3664]
# Out:
#                                                  lyrics  \
# 1859  in the year 2525if man is still aliveif woman ...
# 1860  high dive into frozen waveswhere the past come...
# 1861  everybody move your body now do ithere is some...
# 1862  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 1859                                       ['american']          306.0   26
# 1860  ['complextro', 'dance-pop', 'electro house', '...          313.2   24
# 1861                                        hip-hop/rnb          576.0   64
# 1862                                        hip-hop/rnb          414.9   74
#
#       year  fog_index  flesch_index  num_lines  \
# 1859  1969        4.4        107.69         46
# 1860  2013        4.0         91.78         42
# 1861  1993        4.8         98.21         68
# 1862  1994        4.4         99.23         55
#
# ...

# %% [markdown]
# # Reindex dataframe

# %%
final_reindexed = final.reset_index(drop=True)

# %%
final_reindexed.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
final_reindexed.iloc[3660:3664]
# Out:
#                                                  lyrics  \
# 3660  in the year 2525if man is still aliveif woman ...
# 3661  high dive into frozen waveswhere the past come...
# 3662  everybody move your body now do ithere is some...
# 3663  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 3660                                       ['american']          306.0   26
# 3661  ['complextro', 'dance-pop', 'electro house', '...          313.2   24
# 3662                                        hip-hop/rnb          576.0   64
# 3663                                        hip-hop/rnb          414.9   74
#
#       year  fog_index  flesch_index  num_lines  \
# 3660  1969        4.4        107.69         46
# 3661  2013        4.0         91.78         42
# 3662  1993        4.8         98.21         68
# 3663  1994        4.4         99.23         55
#
# ...

# %% [markdown]
# # New hit classification

# %%
import pandas as pd
import numpy as np

# Create a new column 'Hit_2' based on the condition
final_reindexed['Hit_2'] = np.where(final_reindexed['values'] > 0.5, 'yes', 'no')

# %%
final_reindexed.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
Counter(final_reindexed.Hit_2)
# Out:
# Counter({'yes': 43, 'no': 3621})

# %%
uf = final_reindexed[final_reindexed['values'] >= 0.5]

# %%
uf
# Out:
#                                                 lyrics  \
# 0    look into my eyes  you will seewhat you mean t...
# 5    why do birds suddenly appeareverytime you are ...
# 41   i hear the ticking of the clocki'm lying here ...
# 42   in a little while from nowif i'm not feeling a...
# 60   oh my god  becky  look at her buttit is so big...
# ..                                                 ...
# 839  aw  ow!this hit  that ice coldmichelle pfeiffe...
# 846  all the old paintings on the tombthey do the s...
# 851  ooh  ooh  ooh  oohyeah  ooh  ooh  sweet love  ...
# 864  you must understandthat the touch of your hand...
# 893  peace up!a town down!yeah  yeah  okay! usher.l...
#
#                                                  genre  num_syllables  pos  \
# 0    ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 5    ['adult contemporary', 'baroque pop', 'classic...          236.7    2
# 41   ['aor', 'classic pop and rock', 'folk rock', '...          209.7    2
# ...

# %%
final_reindexed = final_reindexed.drop(['Hit_2'], axis=1)

# %%
final_reindexed.shape
# Out:
# (3664, 45)

# %%
# Create a new column 'Hit_2' based on the condition
final_reindexed['Hit_2'] = np.where(final_reindexed['values'] >= 0.5, 'yes', 'no')

# %%
final_reindexed.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
from collections import Counter

Counter(final_reindexed.Hit_2)
# Out:
# Counter({'yes': 85, 'no': 3579})

# %% [markdown]
# # Split the data for hit and no hit

# %%
median_value = final_reindexed['values'].median()

# %%
median_value
# Out:
# 0.0208333333333333

# %% [markdown]
# ## Split the dataframe with greater than or equal and lower

# %%
# Split the DataFrame based on the median
above_median = final_reindexed[final_reindexed['values'] >= median_value]
below_median = final_reindexed[final_reindexed['values'] < median_value]

# %%
above_median.shape
# Out:
# (1869, 46)

# %%
below_median.shape
# Out:
# (1795, 46)

# %% [markdown]
# ## Split the dataframe with greater than and lower

# %%
# Split the DataFrame based on the median
above_median1 = final_reindexed[final_reindexed['values'] > median_value]
below_median1 = final_reindexed[final_reindexed['values'] < median_value]

# %%
above_median1.shape
# Out:
# (1830, 46)

# %%
below_median1.shape
# Out:
# (1795, 46)

# %% [markdown]
# ## Split the dataframe with greater than and equal or lower

# %%
# Split the DataFrame based on the median
above_median2 = final_reindexed[final_reindexed['values'] > median_value]
below_median2 = final_reindexed[final_reindexed['values'] <= median_value]

# %%
above_median2.shape
# Out:
# (1830, 46)

# %%
below_median2.shape
# Out:
# (1834, 46)

# %%
final_reindexed['Hit_3'] = np.where(final_reindexed['values'] <= median_value, 'no', 'yes')

# %%
final_reindexed.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
from collections import Counter

Counter(final_reindexed.Hit_3)
# Out:
# Counter({'yes': 1830, 'no': 1834})

# %%
final_reindexed[final_reindexed['Hit_3'] == 'no']
# Out:
#                                                  lyrics  \
# 912   it ain't the clothes that you wearit ain't the...
# 913   woohpretty woman  walking down the streetprett...
# 914   hey  man  i don't feel like goin' to school no...
# 915   kick it!you wake up late for school  man  you ...
# 916   i saw star wars at least 8 timeshad the pac-ma...
# ...                                                 ...
# 3656  how can i be surein a world that's constantly ...
# 3657  i've been lonely too long  i've been lonely to...
# 3659  she's got legs  she knows how to use themshe n...
# 3662  everybody move your body now do ithere is some...
# 3663  well  its a groove thang  it's gotta funky swi...
#
#                                                   genre  num_syllables  pos  \
# 912                                                 pop          448.2   86
# 913   ['aor', 'classic pop and rock', 'glam metal', ...          198.0   88
# ...

# %%
Counter(final_reindexed.Hit_3)
# Out:
# Counter({'yes': 1830, 'no': 1834})

# %%
final_reindexed.to_csv('../data/CSV/dataset_ML_complete.csv', index=False)
