# %%
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs = pd.read_csv("../../data/CSV/sample_hits_no_hits.csv")
songs.head(5)
# Out:
#                                               lyrics  \
# 0  i know this pain  i know this pain why do you ...
# 1  must have been lovebut it's over nowlay a whis...
# 2  it's been seven hours and fifteen dayssince yo...
# 3  poison yeah spyderman & freeze in full effectp...
# 4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# 1  1990        5.2         97.20         35
# 2  1990        4.8         89.75         28
# 3  1990        4.4         99.23         65
# 4  1990        4.4         90.77         68
#
#                                            sentiment                   title  \
# 0  {'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'co...                 Hold On
# 1  {'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000...  It Must Have Been Love
# 2  {'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'co...    Nothing Compares 2 U
# 3  {'neg': 0.155, 'neu': 0.7030000000000001, 'pos...                  Poison
# 4  {'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'co...                   Vogue
#
#    ...           artist difficult_words  num_dupes  number_of_tokens  \
# 0  ...  Wilson Phillips              16         26             435.0
# 1  ...          Roxette              15         19             282.0
# 2  ...  Sinead O'Connor              14         16             210.0
# 3  ...   Bell Biv Devoe              52         26             435.0
# 4  ...          Madonna              47         29             433.0
#
#    number_of_types  decades  \
# 0            148.0    1990s
# 1             95.0    1990s
# 2            115.0    1990s
# 3            244.0    1990s
# 4            200.0    1990s
#
#                                         stemmed_text  \
# 0   i know thi pain i know thi pain whi do you lo...
# 1   must have been lovebut it 's over nowlay a wh...
# 2   it 's been seven hour and fifteen dayssinc yo...
# 3   poison yeah spyderman & freez in full effectp...
# 4   what are you lookin ' at ? strike a pose stri...
#
#                                             POS_tags  \
# 0  ['PRP', 'VBP', 'DT', 'NN', '_SP', 'PRP', 'VBP'...
# 1  ['MD', 'VB', 'VBN', 'NN', 'PRP', 'VBZ', 'IN', ...
# 2  ['PRP', 'VBZ', 'VBN', 'CD', 'NNS', 'CC', 'CD',...
# 3  ['NN', 'UH', 'NN', 'CC', 'VB', 'RP', 'JJ', 'NN...
# 4  ['WP', 'VBP', 'PRP', 'NNP', "''", 'IN', 'DT', ...
#
#                                                  POS   Hit
# 0  fair day?things'll comfortable own worth day?t...  True
# 1  lonely good hard good lovebut nowlay whisper p...  True
# 2  fancy lonely lonely fool'cause willing dayssin...  True
# 3  full ready ready ready ready youi strange dead...  True
# 4  long own black white new musical beautiful mag...  True
#
# [5 rows x 21 columns]

# %%
songs.shape
# Out:
# (1581, 21)

# %%
artists = np.unique(songs.artist)
print(len(np.unique(songs.artist)))
# np.unique(songs.decades)
# Out:
# 781

# %%
mean ={}
for a in artists:
    mean[a] = int(np.mean(songs.number_of_tokens[songs.artist==a]))

# %%
ax = sns.distplot(list(mean.values()), rug=True, kde=False)
ax.set_xlabel("song length")
ax.set_ylabel("occurence")
ax.set_title("Distribution of Songlength")
plt.savefig("../../images/dataexploration/songlength_hits_nonhits")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
c = Counter(songs.decades)
c
# Out:
# Counter({'1990s': 282,
#          '1980s': 316,
#          '1970s': 259,
#          '1960s': 216,
#          '2000s': 318,
#          '2010s': 190})

# %%
ax = sns.distplot(list(c.values()), hist=False)
ax.set_xlabel("decades")
ax.set_ylabel("occurence")
ax.set_title("Artists per decade")
x_ticks_labels = np.unique(songs.decades)
ax.set_xticklabels(x_ticks_labels)
plt.savefig("../../images/dataexploration/songnumber_per_artist_decades_hits_nonhits.png")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /var/folders/d9/1b92tl_13g32z4j72swk9lh40000gn/T/ipykernel_2617/633911729.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks_labels)

# %%
s = songs['decades'].value_counts().head(20)

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(12,5))

ax=s.plot.bar(width=.9, color=('blue', 'orange', 'green', 'red', 'purple', 'brown')) 
for i, v in s.reset_index().iterrows():
    ax.text(i, v.decades + 0.2 , v.decades, color='black')

ax.set_xlabel(len(songs.decades))
plt.title("Die Anzahl der Songs pro Dekade")
#plt.xlabel(len(df.Bemerkungen))
plt.ylabel('Anzahl')
#pltcountplotfig("songs_per_genre")
#plt.savefig('../Grafiken/Grafiken_SMS_2018_2019/Auswertung_SMS_2018_2019_BD.png', bbox_inches = "tight")
# Out:
# Text(0, 0.5, 'Anzahl')

# %%
s = songs['genre'].value_counts().head(20)

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(12,5))

ax=s.plot.bar(width=.9, color=('blue', 'orange', 'green', 'red', 'purple', 'brown')) 
for i, v in s.reset_index().iterrows():
    ax.text(i, v.genre + 0.2 , v.genre, color='black')

ax.set_xlabel(len(songs.decades))
plt.title("Die Anzahl der Songs pro Dekade")
#plt.xlabel(len(df.Bemerkungen))
plt.ylabel('Anzahl')
#pltcountplotfig("songs_per_genre")
#plt.savefig('../Grafiken/Grafiken_SMS_2018_2019/Auswertung_SMS_2018_2019_BD.png', bbox_inches = "tight")
# Out:
# Text(0, 0.5, 'Anzahl')

# %%
c = Counter(songs.genre)
c
# Out:
# Counter({"['adult contemporary', 'american', 'classic pop and rock', 'pop']": 5,
#          "['80s pop', 'classic pop and rock', 'european', 'pop', 'pop rock', 'rock', 'seen live', 'swedish']": 2,
#          "['alternative', 'alternative rock', 'folk', 'ireland', 'irish', 'irlandais', 'irlande', 'pop', 'pop and chart', 'rock']": 1,
#          'hip-hop/rnb': 172,
#          "['american', 'américain', 'arabic', 'art pop', 'chanteur', 'dance', 'dance-pop', 'downtempo', 'electronic', 'electropop', 'greatest hits', 'multiple ipi', 'pop', 'pop and chart', 'singer', 'tell me', 'usa']": 12,
#          "['american', 'girl', 'pop', 'pop and chart', 'rnb', 'whistle register']": 13,
#          "['adult contemporary', 'british', 'classic pop and rock', 'english', 'jazz', 'phil collins hits cd2', 'pop', 'pop rock', 'progressive rock', 'rock', 'soft rock', 'uk']": 5,
#          "['alternative dance', 'british', 'classic pop and rock', 'electronic', 'england', 'english', 'hard rock', 'new wave', 'pop rock', 'punk', 'rock', 'uk']": 3,
#          'rock': 64,
#          "['american', 'easy listening soundtracks and musicals', 'pop', 'pop rock', 'rock']": 4,
#          "['belgian', 'euro house', 'european']": 1,
#          'pop': 70,
#          "['aor', 'classic pop and rock', 'folk rock', 'hard rock', 'pop rock', 'pop/rock', 'rock', 'soft rock']": 5,
#          'reggae': 6,
#          "['aor', 'canadian', 'classic pop and rock', 'pop rock', 'rock']": 1,
#          "['american', 'classic pop and rock', 'country', 'folk', 'max']": 2,
#          "['adult contemporary', 'american', 'classic pop and rock', 'contemporary r&b', 'pop', 'pop rock', 'pop soul', 'rnb', 'rock', 'soul', 'tina-turner']": 2,
#          "['00s', '60s', '70s', '80s', '90s', 'british', 'classic pop and rock', 'classical', 'composer', 'english', 'folk', 'male vocalists', 'pop', 'pop rock', 'pop/rock', 'rock', 'rock & roll', 'rock and roll', 'singer-songwriter', 'singer/songwriter', 'standards', 'the beatles', 'uk', 'united kingdom', 'western classical music']": 6,
#          "['american', 'classic pop and rock', 'pop', 'rock']": 6,
#          "['aor', 'classic pop and rock', 'glam metal', 'hard rock', 'jump', 'pop rock', 'pop/rock', 'rock', 'van halen']": 5,
#          "['adult contemporary', 'contemporary r&b', 'funk', 'pop', 'pop soul', 'smooth soul', 'soul', 'soul and reggae']": 6,
#          "['2000s', '2010s', '60s', '70s', '7567826842', '80s', '90s', 'aor', 'art rock', 'british', 'classic pop and rock', 'electronic', 'english', 'folk', 'hard rock', 'male vocalists', 'mario939393', 'pop rock', 'pop-rock', 'pop/rock', 'progressive pop', 'progressive rock', 'rock', 'symphonic prog', 'symphonic rock', 'uk', 'yes']": 2,
#          "['blue-eyed soul', 'british', 'classic pop and rock', 'dance-pop', 'english', 'new romantic', 'new wave', 'pop', 'pop soul', 'uk']": 3,
#          "['classic pop and rock']": 116,
#          "['american', 'americana', 'américain', 'classic pop and rock', 'contemporary folk', 'cotm', 'folk', 'heartland rock', 'pop rock', 'pop/rock', 'rock', 'singer/songwriter', 'usa']": 4,
#          "['blues', 'classic pop and rock', 'dance-pop', 'new wave', 'pop', 'pop rock', 'synthpop']": 2,
#          "['american', 'death by brain aneurysm']": 1,
#          "['70s', '80s', 'classic pop and rock', 'male vocalists', 'rock']": 4,
#          "['blue-eyed soul', 'dance rock']": 8,
#          "['art pop', 'british', 'classic pop and rock', 'english', 'new wave', 'pop rock', 'psychedelic pop', 'sophisti-pop', 'synthpop', 'uk']": 2,
#          "['1970s', '1980s', '1990s', 'band', 'british', 'classic pop and rock', 'classic rock', 'country rock', 'english', 'group', 'id_artist', 'pop rock', 'pop/rock', 'pub rock', 'rock', 'rock & roll', 'soft rock', 'sophisti-pop', 'uk']": 1,
#          "['00s', '70s', '80s', '90s', 'blue-eyed soul', 'british', 'classic pop and rock', 'english', 'male vocalists', 'pop', 'pop rock', 'rock', 'soft rock', 'soulful', 'uk']": 2,
#          "['adult orientated rock', 'hard rock', 'rock', 'soft rock']": 2,
#          "['acid rock', 'american', 'aor', 'classic pop and rock', 'hard rock', 'pop', 'pop rock', 'psychedelic rock', 'rock']": 2,
#          "['classic pop and rock', 'fixme', 'fixme recordings merge']": 2,
#          "['00s', '70s', '80s', '90s', 'art rock', 'british', 'classic pop and rock', 'electronic', 'glasgow', 'male vocalists', 'new wave', 'pop', 'pop rock', 'post-punk', 'rock', 'scotland', 'scottish', 'soft rock', 'synthpop', 'uk']": 2,
#          'soul': 43,
#          "['acoustic rock', 'adult contemporary', 'album oriented rock', 'aor', 'arena rock', 'british', 'canadian', 'hard rock', 'pop rock', 'rock', 'rock and indie', 'soft rock']": 3,
#          'electronic/dance': 15,
#          "['british', 'english', 'grebo', 'rock and indie', 'uk']": 1,
#          "['acoustic rock', 'funk metal', 'glam metal', 'hard rock', 'pop and chart', 'rock', 'soft rock']": 1,
#          "['adult contemporary', 'contemporary r&b', 'dance-pop', 'death by drowning', 'new jack swing', 'o happy day', 'pop', 'pop soul', 'r&b', 'soul and reggae']": 9,
#          "['classic pop and rock', 'england', 'grebo']": 2,
#          "['classic pop and rock', 'death by myocarditis']": 4,
#          "['baroque pop', 'blue-eyed soul', 'british', 'classic pop and rock', 'dance', 'disco', 'english', 'pop', 'pop rock', 'psychedelic pop', 'soft rock', 'uk']": 9,
#          "['actor']": 3,
#          "['24 nights', 'acoustic blues', 'blues', 'blues rock', 'british', 'british blues', 'clapton', 'classic pop and rock', 'eric clapton', 'hard rock', 'has german audiobooks', 'pop', 'pop rock', 'pop/rock', 'psychedelic rock', 'reggae', 'rock']": 5,
#          "['blues', 'blues rock', 'britannique', 'british', 'british rhythm & blues', 'classic pop and rock', 'country', 'english', 'essentials', 'greatest hits', 'live', 'pop rock', 'psychedelic rock', 'reggae', 'rhythm & blues', 'rnb', 'rock', 'rock & roll', 'rock and roll', 'some girls', 'the-rolling-stones', 'uk']": 8,
#          "['american', 'classic pop and rock', 'classical', 'piano rock', 'pop', 'pop rock', 'rock', 'singer/songwriter', 'soft rock', 'this is the time']": 4,
#          "['classic pop and rock', 'r&b']": 3,
#          "['acoustic rock', 'american', 'classic pop and rock', 'jangle pop', 'new wave', 'paisley underground', 'pop', 'pop rock', 'power pop', 'rock']": 1,
#          "['70s', '80s', 'acoustic rock', 'aor', 'blues', 'blues rock', 'british', 'classic pop and rock', 'deep purple family', 'english', 'glam metal', 'hard rock', 'heavy metal', 'metal', 'pop rock', 'rock', 'uk']": 2,
#          "['classic pop and rock', 'classic rock heartland rock rock and roll']": 4,
#          "['acoustic rock', 'american', 'aor', 'band', 'glam metal', 'hard fm', 'hard rock', 'metal', 'pop and chart', 'pop rock', 'rock']": 4,
#          "['00s', '10s', '80s', '90s', 'blues', 'classic pop and rock', 'folk', 'latin', 'mexico', 'rock', 'usa']": 1,
#          "['british', 'classic pop and rock', 'dance', 'dance-pop', 'english', 'new wave', 'pop', 'rock', 'synthpop', 'uk']": 1,
#          "['australia', 'rock and indie']": 2,
#          "['adult contemporary', 'contemporary r&b', 'dance', 'hip hop', 'house', 'pop', 'soul']": 1,
#          "['birmingham', 'british', 'classic pop and rock', 'dub', 'english', 'pop', 'pop reggae', 'reggae', 'roots reggae', 'soul and reggae', 'uk']": 1,
#          "['canadian', 'canadian rap', 'dancehall', 'hip hop', 'pop and chart', 'reggae']": 1,
#          "['classic pop and rock', 'g-funk', 'gangsta rap', 'hardcore hip hop', 'hip hop', 'instrumental hip hop', 'pop rap', 'producer', 'rapper', 'west coast hip hop']": 1,
#          "['adult contemporary', 'rhythm and blues', 'soft rock', 'soul']": 2,
#          "['american', 'hip hop', 'hip-hop', 'pop and chart']": 1,
#          "['00s', '10s', '80s', '90s', 'alternative', 'alternative rock', 'american', 'crossover', 'dvd', 'funk', 'funk metal', 'funk rock', 'funk rock tributo', 'metal', 'pop and chart', 'rap', 'rock', 'usa']": 2,
#          "['80s', '90s', 'hip hop rnb and dance hall', 'one-hit wonder', 'pop', 'rnb', 'underrated']": 1,
#          "['classic pop and rock', 'mr. big']": 2,
#          "['british', 'dance-pop', 'english', 'novelty', 'pop', 'uk']": 1,
#          "['american', 'américain', 'chanteur', 'classic pop and rock', 'composer', 'compositeur', 'contemporary r&b', 'contemporary rnb', 'cool', 'dance-pop', 'disco', 'funk', 'lyricist', 'michael-jackson', 'new jack swing', 'parolier', 'pop', 'pop rock', 'pop soul', 'r&b', 'rnb', 'rock', 'singer', 'soul', 'united states', 'usa']": 9,
#          "['acoustic rock', 'american', 'band', 'classic pop and rock', 'glam metal', 'hard rock', 'heavy metal', 'industrial rock', 'metal', 'patience', 'piano rock', 'pop rock', 'pop/rock', 'rock']": 3,
#          "['canadian', 'country', 'rock']": 1,
#          "['90s', 'dance', 'female vocalists', 'pop', 'pop and chart']": 2,
#          'alternative/indie': 4,
#          "['classic pop and rock', 'soft rock']": 3,
#          "['comedy']": 1,
#          "['adult contemporary', 'aor', 'hard rock', 'pop and chart', 'pop rock']": 2,
#          "['blue-eyed soul', 'british', 'classic pop and rock', 'death by heart attack', 'england', 'english', 'funk rock', 'pop', 'pop rock', 'rock', 'synthpop', 'uk']": 1,
#          "['british', 'dance-pop', 'disco', 'electronic', 'electropop', 'english', 'house', 'pop', 'pop and chart', 'synth pop', 'synthpop', 'uk']": 2,
#          "['adult contemporary', 'british', 'caribbean queen', 'classic pop and rock', 'contemporary r&b', 'dance-pop', 'disco', 'english', 'pop', 'pop soul', 'trinidadian', 'uk']": 2,
#          "['blue-eyed soul', 'blues rock', 'classic pop and rock', 'pop', 'pop rock', 'rock', 'synthpop']": 4,
#          "['blues rock', 'british', 'easy listening soundtracks and musicals', 'english', 'folk rock', 'pop', 'pop rock', 'pop/rock', 'rock', 'roots rock', 'standards', 'uk']": 6,
#          'disco': 2,
#          "['classic pop and rock', 'disco', 'soul']": 1,
#          "['american']": 6,
#          "['australian', 'british', 'classic pop and rock']": 6,
#          "['american', 'classic pop and rock', 'disco', 'new wave', 'pop', 'pop reggae', 'pop rock', 'pop/rock', 'power pop', 'punk', 'punk rock', 'rock', 'usa']": 4,
#          "['american', 'contemporary r&b', 'funk', 'pop soul', 'psychedelic soul', 'rhythm & blues', 'rnb', 'soul', 'soul and reggae']": 6,
#          'funk': 13,
#          "['bubblegum pop', 'pop', 'rock and roll']": 1,
#          "['british', 'easy listening soundtracks and musicals', 'uk', 'wales', 'welsh']": 4,
#          "['classic pop and rock', 'never been to spain']": 3,
#          "['bubblegum pop', 'pop', 'psychedelic pop', 'rock and roll']": 1,
#          "['american', 'death by gun', 'death by murder', 'funk', 'multiple ipi', 'pop', 'pop soul', 'rhythm & blues', 'rnb', 'sexual', 'smooth soul', 'soul', 'soul and reggae', 'the very best of']": 6,
#          "['american', 'blue-eyed soul', 'blues', 'christmas music', 'classic pop and rock', 'country', 'flaming', 'gospel', 'if you talk in your sleep', 'love', 'oldies', 'party', 'pop', 'pop rock', 'pop/rock', 'rock', 'rock & roll', 'rock and roll', 'rockabilly', 'singer']": 7,
#          "['60s', 'american', 'blues rock', 'classic pop and rock', 'country rock', 'rock', 'rock & roll', 'rock and roll', 'roots rock', 'southern rock', 'swamp rock']": 1,
#          "['british', 'electronic', 'england', 'english', 'minimal synth', 'new romantic', 'new wave', 'pop', 'rock and indie', 'sheffield', 'synthpop', 'uk']": 1,
#          "['blues rock', 'country rock', 'pop', 'pop rock', 'pop/rock', 'psychedelic rock', 'rock', 'rock and indie']": 2,
#          "['american', 'aor', 'classic pop and rock', 'hard rock', 'jazz', 'jazz-rock', 'pop', 'pop rock', 'rock', 'soft rock']": 3,
#          "['british', 'electronic', 'english', 'minimal synth', 'new wave', 'rock and indie', 'synthpop', 'uk']": 1,
#          "['adult contemporary', 'canadian', 'christmas music', 'classic pop and rock', 'dance-pop', 'eurovision', 'eyes on me', 'french', 'french pop', 'pop']": 5,
#          "['acoustic', 'american', 'américain', 'blues rock', 'classic pop and rock', 'contemporary folk', 'folk', 'folk pop', 'folk rock', 'singer/songwriter', 'usa']": 1,
#          "['american', 'rnb', 'urban']": 5,
#          "['british', 'chill', 'dance', 'england', 'english', 'hull', 'jazz pop', 'pop and chart', 'sophisti-pop', 'uk']": 1,
#          "['acoustic rock', 'alternative', 'alternative rock', 'american', 'canada', 'canadian', 'dance-pop', 'down the alley', 'female vocalists', 'multiple ipi', 'pop', 'pop rock', 'pop-rock', 'post-grunge', 'rock', 'singer', 'singer-songwriter', 'singer/songwriter', 'soft rock']": 2,
#          "['american', 'contemporary r&b', 'hip hop rnb and dance hall', 'pop', 'r&b', 'rnb']": 6,
#          "['american', 'contemporary r&b', 'hip hop rnb and dance hall', 'hip-hop', 'neo soul', 'new jack swing', 'pop', 'pop rap', 'r&b', 'rnb', 'soul']": 10,
#          "['british', 'english', 'hip hop rnb and dance hall', 'uk']": 1,
#          "['classic pop and rock', 'country', 'pop']": 2,
#          "['band', 'british', 'english', 'girl group', 'pop', 'pop and chart', 'uk']": 2,
#          "['american', 'boy band', 'boy group', 'dance-pop', 'electropop', 'incomplete remix', 'pop', 'pop and chart', 'pop rock', 'teen pop']": 2,
#          "['alternative rock', 'meredith brooks', 'pop rock', 'singer/songwriter']": 1,
#          "['alternative', 'british', 'classic pop and rock', 'england', 'english', 'new wave', 'pop reggae', 'pop rock', 'pop/rock', 'post-punk', 'power pop', 'punk rock', 'rock', 'the police', 'uk']": 2,
#          "['australian', 'classic pop and rock', 'new wave', 'pop', 'pop reggae', 'pop rock', 'rock']": 1,
#          "['aor', 'arena rock', 'british', 'country pop', 'country rock', 'dance and electronica', 'pop', 'pop rock', 'rock', 'soft rock', 'uk', 'wagnerian rock', 'welsh']": 1,
#          "['art pop', 'british', 'classic pop and rock', 'electronic', 'new wave', 'pop', 'pop rock', 'rnb', 'rock', 'synthpop', 'uk']": 1,
#          "['classic pop and rock', 'country']": 4,
#          "['birmingham', 'blue eyed soul', 'blue-eyed soul', 'british', 'classic pop and rock', 'england', 'english', 'new wave', 'northern soul', 'pop rock', 'pop soul', 'uk']": 1,
#          "['bossa nova', 'rock and indie']": 1,
#          "['alternative rock', 'art pop', 'art rock', 'blue-eyed soul', 'britannique', 'british', 'classic pop and rock', 'english', 'experimental', 'experimental rock', 'glam rock', 'pop', 'pop rock', 'pop/rock', 'post-disco', 'psychedelic pop', 'rock', 'soul', 'uk']": 3,
#          "['1', '60s', '80s', 'a filk artist', 'adult alternative pop rock', 'art pop', 'art rock', 'bbc', 'beat music', 'blues rock', 'boys band', 'british', 'british invasion', 'british psychedelia', 'british rhythm & blues', 'britpop', 'classic pop and rock', 'classical pop', 'english', 'experimental', 'folk pop', 'folk rock', 'folk-rock', 'hair metal', 'hard rock', 'heavy metal', 'indie rock', 'instrumental pop', 'liverpool', 'male vocalists', 'merseybeat', 'one beatles', 'orchestral', 'orchestral pop', 'overrated', 'parlophone', 'pop', 'pop rock', 'pop-metal', 'pop-rock', 'pop/rock', 'progressive rock', 'psychedelic', 'psychedelic pop', 'psychedelic rock', 'rhythm & blues', 'rock', 'rock & roll', 'rock and roll', 'rock roll', 'singer songwriter', 'sunshine pop', 'the-beatles', 'tribute albums', 'uk', 'united kingdom']": 14,
#          "['american', 'blues', 'death by airplane', 'death by drowning', 'deep soul', 'dock of the bay', 'psychedelic rock', 'rhythm & blues', 'rock', 'soul', 'soul and reggae', 'southern soul']": 1,
#          "['american', 'classic pop and rock', 'contemporary folk', 'film soundtrack', 'folk', 'folk pop', 'folk rock', 'pop rock', 'rock', 'seven', 'simon-garfunkel', 'singer/songwriter']": 2,
#          "['acid rock', 'american', 'blues rock', 'classic pop and rock', 'hard rock', 'poetry', 'psychedelic pop', 'psychedelic rock', 'rock', 'true classics']": 4,
#          "['american', 'blues rock', 'jam', 'jam band', 'pop rock', 'psychedelic rock', 'rock']": 1,
#          "['adult contemporary', 'country pop', 'pop', 'pop rock', 'singer/songwriter', 'soft rock']": 1,
#          "['adult contemporary', 'american', 'classic pop and rock', 'contemporary r&b', 'disco', 'jazz', 'pop', 'pop soul', 'rnb', 'soul']": 9,
#          "['american', 'country', 'pop']": 3,
#          "['britannique', 'british', 'classic pop and rock', 'death by gun', 'death by murder', 'english', 'experimental', 'folk', 'murdered', 'pop', 'pop rock', 'rock', 'rock & roll', 'singer/songwriter', 'uk', 'united kingdom', 'wifebeater']": 3,
#          "['contemporary r&b', 'disco', 'fresh', 'funk', 'jazz-funk', 'pop soul', 'rock and indie', 'synth funk']": 5,
#          "['american', 'bluegrass', 'country', 'country pop', 'folk', 'nashville sound', 'pop']": 1,
#          "['adult contemporary', 'contemporary r&b', 'country', 'dance', 'pop']": 4,
#          "['american', 'classic pop and rock', 'motown', 'rnb', 'soul']": 3,
#          "['blues', 'blues rock', 'pop', 'pop rock', 'rhythm & blues', 'rock']": 1,
#          "['70s', 'classic pop and rock', 'disco', 'female vocalists', 'funk', 'jazz', 'pop']": 1,
#          "['british', 'classic pop and rock', 'dark wave', 'electronic', 'english', 'experimental', 'funk', 'gothic rock', 'industrial', 'industrial rock', 'jazz', 'new wave', 'post-punk', 'punk rock', 'rock', 'synth rock', 'synthesizer rock', 'synthpop', 'uk']": 1,
#          "['adult contemporary', 'australian', 'pop', 'pop rock', 'rock', 'soft rock']": 2,
#          "['adult contemporary', 'british', 'classic pop and rock', 'elton-john', 'english', 'glam rock', 'piano rock', 'pop', 'pop rock', 'pop/rock', 'rock', 'singer/songwriter', 'uk']": 9,
#          "['classic pop and rock', 'dance-pop', 'disco', 'funk', 'pop', 'pop soul']": 2,
#          "['american', 'aor', 'arena rock', 'hard rock', 'pop rock', 'progressive rock', 'rock', 'rock opera']": 1,
#          "['adult contemporary', 'dance-pop', 'electronic', 'eurodance', 'european', 'europop', 'pop', 'pop reggae', 'swedish']": 4,
#          "['american', 'heartland rock', 'pop', 'rock', 'roots rock']": 3,
#          "['a filk artist', 'dance-pop', 'electro', 'electropop', 'hip hop', 'hip hop rnb and dance hall', 'hip house', 'pop rap', 'southern hip hop']": 5,
#          "['british', 'contemporary r&b', 'dance-pop', 'electropop', 'english', 'pop', 'pop and chart', 'uk', 'x factor']": 1,
#          "['alternative rock', 'american', 'contemporary r&b', 'film soundtrack', 'hip hop rnb and dance hall', 'neo soul', 'neo-soul', 'pianist', 'pop', 'pop rap', 'r&b', 'rnb', 'singer', 'soul']": 3,
#          "['chopped and screwed', 'contemporary r&b', 'gangsta rap', 'hip hop', 'hip hop rnb and dance hall', 'lil wayne', 'pop rap', 'r&b', 'rap', 'rap rock', 'southern hip hop']": 5,
#          "['contemporary r&b', 'dance-pop', 'electropop', 'hip hop rnb and dance hall', 'pop', 'pop rap', 'pop rock']": 4,
#          "['american idol', 'hip hop rnb and dance hall', 'pop']": 1,
#          "['bobby brakens']": 2,
#          "['barbade', 'barbadian', 'barbadien', 'barbados', 'contemporary r b', 'contemporary r&b', 'dance', 'dance-pop', 'dancehall', 'electro house', 'electropop', 'hip hop', 'pop', 'pop and chart', 'pop soul', 'r&b', 'reggae', 'rehab', 'rnb']": 15,
#          "['alternative rock', 'ambient pop', 'britannique', 'british', 'britpop', 'chapel', 'english', 'parlophone', 'piano pop', 'piano rock', 'pop', 'pop rock', 'pop/rock', 'rock', 'rock and indie', 'uk']": 2,
#          '[\'"ur so fail"\', \'american\', \'américain\', \'bubblegum\', \'california gurls\', \'cute\', \'dance-pop\', \'electropop\', \'fail\', \'failfail\', \'her expression is like shes thinking something dumb\', \'house\', \'katy perry\', \'lame\', \'lolol trap?\', \'megafail\', \'multiple ipi\', \'nope still fail\', \'pop\', \'pop rock\', \'still fail\', \'trap\', \'united states\', \'ur so faaaail\', \'ur so fail\', \'usa\']': 10,
#          "['british', 'contemporary r b', 'english', 'pop', 'pop and chart', 'soul', 'uk']": 3,
#          "['a filk artist', 'conscious hip hop', 'dance-pop', 'electro house', 'electropop', 'fergie', 'pop', 'pop and chart', 'pop rap', 'united states', 'west coast hip hop', 'will i am']": 9,
#          "['american', 'américain', 'dance-pop', 'edge of glory', 'electronic', 'electropop', 'gata rahe mera dil', 'pop', 'pop rock', 'synthpop', 'the fame', 'united states', 'usa']": 6,
#          "['contemporary country', 'country', 'country pop', 'country-pop', 'dance-pop', 'electropop', 'female vocals', 'fixme label mess', 'pop', 'pop rock', 'singer/songwriter', 'taylor-swift', 'teen pop', 'top 40']": 10,
#          "['acoustic rock', 'adult contemporary', 'alternative rock', 'american', 'classic pop and rock', 'pop', 'pop rock', 'rock', 'singer/songwriter', 'united states']": 1,
#          "['contemporary r&b', 'dance-pop', 'electropop', 'hip hop rnb and dance hall', 'mbs-333', 'moombahton', 'pop', 'pop rap', 'r&b', 'rnb']": 10,
#          "['american', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'producer', 'rapper', 'us']": 3,
#          "['alternative', 'pop', 'pop and chart', 'pop punk', 'pop/rock']": 1,
#          "['alternative', 'alternative rock', 'american', 'américain', 'garage rock', 'garage rock revival', 'indie', 'indie rock', 'pop rock', 'rock', 'rock and indie', 'southern rock', 'united states', 'usa']": 2,
#          "['bhangra', 'british soul', 'contemporary r&b', 'electropop', 'hip hop', 'pop', 'pop and chart', 'r&b']": 1,
#          "['alternative', 'classic pop and rock', 'pop']": 4,
#          "['alternative rock', 'american', 'pop rock', 'post-grunge', 'rock', 'rock and indie']": 3,
#          "['american', 'classic pop and rock', 'funk rock', 'funk-rock', 'hard rock', 'neo-psychedelia', 'pop rock', 'pop soul', 'psychedelic rock', 'psychedelic soul', 'rock', 'soft rock', 'soul']": 1,
#          "['alternative metal', 'alternative rock', 'american', 'hard rock', 'metal', 'post-grunge', 'rock']": 1,
#          "['american', 'classic pop and rock', 'country', 'country rock', 'hip hop', 'pop', 'rap rock', 'rock']": 2,
#          "['alternative rock', 'dance', 'electropop', 'english', 'funk', 'hip-hop', 'jazz pop', 'pop', 'pop and chart', 'pop soul', 'rock', 'soul', 'synth funk', 'united kingdom']": 1,
#          "['adult contemporary', 'automod ng', 'dance', 'dance-pop', 'electropop', 'fixme label mess', 'funk rock', 'pop', 'pop rock', 'pop/rock', 'rock', 'rock and indie', 'slow pop']": 6,
#          "['a filk artist', 'chamber pop', 'drum and bass', 'electropop', 'film soundtrack', 'pop', 'synthpop']": 2,
#          "['blues', 'blues rock', 'chamber pop', 'indie rock', 'pop soul']": 1,
#          "['art pop', 'dancehall', 'downtempo', 'dub', 'electro', 'electronic', 'electropop', 'moombahcore', 'moombahton', 'pop rap', 'pop reggae', 'trap']": 1,
#          "['contemporary r&b', 'dance', 'dance-pop', 'electropop', 'pop', 'r&b']": 4,
#          "['american', 'américain', 'soul', 'soul and reggae', 'usa']": 3,
#          "['a filk artist', 'electropop', 'hip house', 'hyphy', 'pop rap', 'trap rap']": 1,
#          "['a filk artist', 'blue-eyed soul', 'dance-pop', 'doo-wop', 'female vocals', 'great songs', 'pop', 'pop rap', 'pop soul', 'top 40']": 1,
#          "['contemporary r&b', 'dance-pop', 'electro house', 'electropop', 'pop', 'r&b']": 1,
#          "['alternative r&b', 'blue-eyed soul', 'pop', 'pop soul', 'synth funk']": 2,
#          "['afrobeat', 'hip hop', 'pop', 'rhythm and blues']": 1,
#          "['alternative r&b', 'contemporary r&b', 'electropop', 'moombahton', 'trap']": 1,
#          "['8 mile', 'american', 'boom bap', 'comedy rap', 'detroit hip-hop', 'hardcore hip hop', 'hip hop', 'hip-hop', 'hiphop', 'horrorcore', 'midwest hip-hop', 'pop and chart', 'pop rap', 'rap', 'rapper', 'turkish', 'us', 'v']": 6,
#          "['alternative r&b', 'art pop', 'indietronica', 'pop', 'synthpop', 'uk garage']": 3,
#          "['adult contemporary', 'christmas music', 'contemporary country', 'country', 'country pop', 'pop']": 2,
#          "['australian', 'classic pop and rock', 'duo', 'melodic rock', 'pop', 'rock', 'soft rock']": 2,
#          "['american', 'hip hop rnb and dance hall', 'r&b']": 1,
#          "['acoustic rock', 'alternative rock', 'hard rock', 'pop rock', 'post-grunge', 'rock', 'southern rock']": 4,
#          "['adult contemporary', 'american', 'brian mcknight', 'contemporary r&b', 'hip hop rnb and dance hall', 'pop', 'quiet storm', 'r&b', 'rnb', 'soul']": 3,
#          "['alternative rock', 'canadian', 'death metal', 'electropop', 'funk rock', 'hard rock', 'music_for_people_who_dislike_music', 'pop and chart', 'pop rock', 'post-grunge', 'rock']": 3,
#          "['alternative rock', 'pop rock', 'rock and indie']": 1,
#          "['american', 'piano pop', 'pop', 'pop rock', 'rock']": 1,
#          "['alternative metal', 'alternative rock', 'american', 'américain', 'hip hop', 'industrial rock', 'metal', 'new metal', 'nu metal', 'nu-metal', 'pop rock', 'rap metal', 'rap rock', 'rapcore', 'rock', 'rock and indie', 'roxette', 'united states', 'usa']": 2,
#          "['alternative rock', 'pop and chart', 'post grunge']": 1,
#          "['alternative rock', 'bubblegum punk', 'mall punk', 'pop and chart', 'pop punk', 'pop rock', 'pop/rock', 'post-grunge', 'punk', 'punk rock', 'rock', 'teen pop', 'teen punk']": 5,
#          "['alternative rock', 'american', 'américain', 'rock and indie', 'usa']": 2,
#          'country': 46,
#          "['alternative metal', 'alternative rock', 'american', 'metal', 'n2', 'new metal', 'nu metal', 'piano rock', 'pop and chart', 'pop rock', 'rock', 'symphonic rock']": 2,
#          "['american', 'dirty rap', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop']": 2,
#          "['comedy rap', 'conscious hip hop', 'hip hop', 'pop rap', 'west coast hip hop']": 2,
#          "['alternative rock', 'indie pop', 'indietronica', 'pop rock']": 2,
#          "['bass', 'electronic', 'grime', 'hip hop', 'trap']": 1,
#          "['boogie', 'contemporary r&b', 'dance-pop', 'disco', 'electropop', 'pop', 'pop and chart', 'r&b', 'synth funk']": 4,
#          "['a filk artist', 'contemporary r&b', 'new wave', 'pop', 'pop rock', 'pop soul', 'r&b', 'synth funk']": 5,
#          "['bro-country']": 2,
#          "['americana', 'indie folk', 'indie pop']": 1,
#          "['american', 'dance-pop', 'new wave', 'no doubt', 'pop', 'pop and chart', 'pop rap', 'pop rock', 'rnb', 'rock', 'ska punk', 'united states']": 3,
#          "['american idol', 'contemporary country', 'country', 'country pop', 'country rock', 'pop', 'pop rock']": 2,
#          "['canada', 'canadian', 'folk', 'hip hop', 'hip hop rnb and dance hall', 'pop', 'pop and chart', 'r&b', 'rock']": 3,
#          "['alternative rock', 'hard rock', 'pop and chart']": 3,
#          "['british', 'english', 'folk rock', 'pop and chart', 'pop rock', 'rhyming slang', 'rock', 'uk']": 1,
#          "['alternative hip hop', 'experimental hip hop', 'hip hop', 'neo-soul', 'pop', 'pop and chart', 'pop rock', 'pop soul']": 1,
#          "['alternative rock', 'brendon urie', 'brent wilson', 'chamber pop', 'emo-pop', 'jon walker', 'pop and chart', 'pop punk', 'pop rock', 'pop/rock', 'power pop', 'ryan ross', 'spence smith', 'united states']": 1,
#          "['alternative', 'art pop', 'chamber pop', 'downtempo', 'electronic', 'indie pop', 'indie rock', 'indietronica', 'pop', 'rock', 'synthpop', 'trip hop']": 1,
#          "['chillwave', 'dance-pop', 'electropop', 'pop', 'synthpop', 'teen pop']": 1,
#          "['a filk artist', 'american idol', 'dance-pop', 'electropop', 'fixme label mess', 'pop', 'pop and chart', 'pop rock', 'rock', 'teen pop']": 6,
#          "['a filk artist', 'hip-hop', 'pop', 'rap']": 2,
#          "['boy band', 'dance-pop', 'folk pop', 'pop', 'pop rock', 'power pop']": 2,
#          "['alternative hip-hop', 'american', 'conscious hip hop', 'contemporary r&b', 'dirty south', 'experimental', 'funk', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'neo-soul', 'pop', 'pop rap', 'southern hip hop', 'southern hip-hop']": 3,
#          "['alternative metal', 'alternative rock', 'hard rock', 'nu metal', 'pop rock', 'post-grunge']": 1,
#          "['american', 'gospel', 'rnb']": 1,
#          "['contemporary r&b', 'crunk&b', 'dance', 'dance-pop', 'electropop', 'hip hop', 'pop', 'pop and chart', 'pop rap', 'r&b']": 4,
#          "['a filk artist', 'dance', 'dance-pop', 'electropop', 'indie pop', 'pop', 'pop rap', 'pop rock', 'singer/songwriter']": 2,
#          "['contemporary r&b', 'dance-pop', 'electropop', 'hip hop rnb and dance hall']": 2,
#          "['alternative', 'dance-pop', 'indie', 'indie pop', 'pop']": 1,
#          "['alternative rock', 'american', 'américain', 'bay area', 'bay area punk', 'california', 'california punk', 'classic pop punk', 'classic punk', 'pop', 'pop and chart', 'pop punk', 'pop rock', 'pop-punk', 'pop/rock', 'post-punk', 'power pop', 'punk', 'punk pop', 'punk rock', 'rock', 'ska punk', 'united states', 'usa']": 1,
#          "['british', 'british heavy metal', 'english', 'heavy metal', 'iron maiden', 'paul di anno', 'uk']": 1,
#          "['alternative rock', 'american', 'américain', 'geek rock', 'irvine', 'nerd rock', 'pop rock', 'power pop', 'rock', 'rock and indie', 'rock opera', 'usa', 'weezer']": 1,
#          "['american', 'folk', 'jazz', 'jazz and blues', 'pop', 'r&b', 'soul', 'tracks']": 2,
#          "['british', 'classic pop and rock', 'english', 'irish', 'uk']": 1,
#          "['classic pop and rock', 'folk']": 2,
#          'classical/soundtrack': 4,
#          "['classic pop and rock', 'deep soul', 'funk', 'pop soul', 'rhythm & blues', 'smooth soul', 'soul']": 1,
#          'folk': 8,
#          "['american', 'singer']": 1,
#          "['classic pop and rock', 'soul']": 1,
#          "['american', 'blues', 'blues rock', 'classic pop and rock', 'novelty', 'rhythm & blues', 'rock', 'rock & roll', 'rock and roll', 'rock n roll', 'usa']": 1,
#          "['canadian', 'classic pop and rock', 'classic rock', 'contemporary folk', 'country', 'country rock', 'folk', 'folk rock', 'hard rock', 'rock', 'shocking', 'singer/songwriter']": 1,
#          "['classic pop and rock', 'funk', 'pop soul', 'rhythm & blues', 'smooth soul', 'soul', 'vocal group']": 4,
#          "['american', 'blues rock', 'pop', 'pop/rock', 'psychedelic pop', 'psychedelic rock', 'rock', 'rock and indie', 'sunshine pop']": 3,
#          "['big band', 'chrismas', 'christmas', 'columbia', 'easy listening soundtracks and musicals', 'garland', 'jazz', 'pop', 'swing', 'swing; jazz; big band; christmas', 'vocal']": 1,
#          "['classic pop and rock', 'country soul', 'deep soul', 'rhythm & blues', 'soul', 'southern soul']": 1,
#          "['american', 'aor', 'baroque pop', 'classic pop and rock', 'dance', 'dance-pop', 'disco', 'folk', 'folk pop', 'pop', 'pop rock', 'rnb', 'rock']": 4,
#          "['american', 'américain', 'dance', 'dance-pop', 'electropop', 'if you seek amy', 'pop', 'pop and chart', 'urban pop', 'usa']": 6,
#          "['american', 'classic pop and rock', 'contemporary christian', 'pop', 'rock']": 1,
#          "['adult contemporary', 'british', 'canadian', 'christmas music', 'easy listening soundtracks and musicals', 'folk pop', 'piano pop', 'pop', 'singer/songwriter']": 2,
#          "['canadian', 'country', 'country pop', 'country-rock', 'pop', 'rock']": 1,
#          "['american', 'east coast hip-hop', 'hip hop', 'hip-hop', 'hiphop', 'mainstream rap', 'pop and chart', 'pop rap', 'urban', 'us']": 1,
#          "['brit award petition', 'british', 'classic pop and rock', 'scottish', 'uk']": 1,
#          "['baroque pop', 'blue-eyed soul', 'classic pop and rock', 'contemporary folk', 'country', 'country pop', 'country soul', 'delta blues']": 1,
#          "['american', 'deep soul', 'gospel', 'jazz', 'pop', 'pop soul', 'rhythm & blues', 'rnb', 'rock', 'smooth soul', 'soul', 'soul and reggae', 'southern soul']": 7,
#          "['classic pop and rock', 'death by intestinal cancer']": 1,
#          "['american', 'folk', 'singer/songwriter']": 2,
#          "['adult contemporary', 'classic pop and rock', 'film soundtrack', 'pop', 'pop rock', 'singer/songwriter', 'soft rock']": 2,
#          "['australian', 'pop']": 2,
#          "['american', 'classic pop and rock', 'pop']": 1,
#          "['british', 'easy listening soundtracks and musicals', 'english', 'uk']": 2,
#          "['british', 'england', 'english', 'manchester', 'rock and indie', 'uk']": 3,
#          "['american', 'américain', 'b7005bb9-fcd9-4d06-8c39-c5ef11275ef1', 'baroque pop', 'classic pop and rock', 'pop', 'pop rock', 'pop/rock', 'psychedelic pop', 'psychedelic rock', 'rock', 'rock and roll', 'sunshine pop', 'surf', 'surf rock', 'today', 'usa']": 7,
#          "['baroque pop', 'classic pop and rock', 'folk pop', 'pop', 'pop rock', 'pop soul', 'soft pop', 'sunshine pop']": 2,
#          "['american', 'country', 'country folk', 'death by airplane', 'folk', 'folk rock', 'pop', 'pop folk', 'rock', 'rock and roll']": 3,
#          "['black metal', 'death metal']": 2,
#          "['27 club', 'acid rock', 'acoustic blues', 'american', 'blues rock', 'classic pop and rock', 'death by heroin', 'death by overdose', 'folk', 'hard rock', 'psychedelic rock', 'rock']": 1,
#          "['acoustic', 'american', 'classic pop and rock', 'country', 'folk', 'folk pop', 'folk rock', 'pop rock', 'rnb', 'rock', 'singer/songwriter', 'soft rock', 'sweet baby james']": 1,
#          "['acoustic', 'american', 'americana', 'country', 'folk', 'gospel', 'pop', 'rock', 'roots rock', 'singer-songwriter']": 1,
#          "['adult contemporary', 'baroque pop', 'classic pop and rock', 'country pop', 'easy listening', 'pop']": 2,
#          "['contemporary christian', 'country', 'pop', 'rock', 'soft rock']": 3,
#          "['bubblegum', 'funk', 'pop', 'pop and chart', 'pop soul', 'soul', 'soul and reggae']": 5,
#          "['american', 'psychedelic rock', 'psychedelic soul', 'rock']": 1,
#          "['classic pop and rock', 'rock']": 2,
#          "['aa0003000', 'american', 'classic pop and rock', 'death by heart attack', 'dixieland', 'gospel', 'jazz', 'pop', 'sm', 'swing', 'traditional pop', 'vocal jazz']": 1,
#          "['american', 'baroque pop', 'classic pop and rock', 'country pop', 'death by heart attack', 'pop', 'pop rock', 'rock', 'rock & roll', 'rockabilly']": 3,
#          "['american', 'big band', 'christmas music', 'classic pop and rock', 'country pop', 'pop', 'standards', 'traditional pop', 'vocal jazz']": 1,
#          "['adult contemporary', 'american', 'easy listening soundtracks and musicals', 'pop', 'showtunes', 'vocal', 'yentle']": 3,
#          "['beat', 'beat music', 'british', 'british blues', 'british rhythm & blues', 'classic pop and rock', 'english', 'pop', 'pop rock', 'psychedelic pop', 'rnb', 'uk']": 2,
#          "['classic pop and rock', 'fixme ngs?']": 2,
#          "['british', 'english', 'liverpool', 'uk']": 2,
#          "['christmas music', 'classic pop and rock', 'country', 'country gospel', 'country pop', 'death by airplane', 'nashville sound']": 1,
#          "['american', 'classic pop and rock', 'country', 'pop', 'rock']": 4,
#          "['american', 'pop']": 6,
#          "['american', 'death by heart surgery']": 1,
#          "['canadian']": 1,
#          "['american', 'rock and indie']": 2,
#          "['american', 'blues rock', 'hard rock', 'heavy psych', 'pop rock', 'rock']": 1,
#          "['british', 'english', 'uk']": 4,
#          "['american', 'contemporary r&b', 'disco', 'funk', 'hip hop rnb and dance hall', 'jazz', 'pop soul', 'r&b', 'rnb', 'september', 'smooth soul', 'soul']": 2,
#          "['american', 'classic pop and rock', 'folk']": 2,
#          "['british', 'classic pop and rock', 'miss sun', 'scottish', 'uk']": 1,
#          "['american', 'country', 'death by airplane', 'gospel', 'honky tonk', 'nashville sound', 'pop', 'rock', 'rock and indie', 'rock roll', 'traditional country']": 1,
#          "['classic pop and rock', 'country', 'death by gun', 'death by suicide', 'del shannon greatest hits', 'pop', 'pop rock', 'psychedelic pop', 'rock & roll', 'teen pop']": 3,
#          "['american', 'blues', 'classic pop and rock', 'country', 'country blues', 'country soul', 'death by lung cancer', 'gospel', 'jazz', 'live in concert', 'piano blues', 'pop', 'rhythm & blues', 'rnb', 'soul', 'soul blues', 'soul jazz', 'the way i feel', 'vocal jazz']": 4,
#          "['classic pop and rock', 'disco', 'pop soul', 'smooth soul', 'soul']": 1,
#          "['adult contemporary', 'american', 'country', 'native american', 'pop']": 2,
#          "['a filk artist', 'christmas', 'classic pop and rock', 'disco', 'euro pop', 'euro-disco', 'european', 'europop', 'eurovision', 'gold', 'pop', 'pop rock', 'swedish', 'synthpop']": 3,
#          "['british', 'english', 'songs', 'uk']": 3,
#          "['american', 'beach', 'buffettinfo com', 'country', 'gulf and western', 'pop', 'rock', 'soft rock', 'tropical rock']": 1,
#          "['5099995588322', '70s', '80s', 'arena rock', 'art rock', 'british', 'classic pop and rock', 'electronic', 'electronica', 'english', 'pop', 'pop rock', 'pop/rock', 'progressive rock', 'rock', 'symphonic prog', 'symphonic rock', 'uk']": 5,
#          'religious': 1,
#          "['a filk artist', 'brill building', 'bubblegum', 'classic pop and rock', 'girl group', 'pop', 'sunshine pop', 'teen pop']": 2,
#          "['adult contemporary', 'blue-eyed soul', 'british', 'classic pop and rock', 'dance pop', 'dance-pop', 'english', 'pop', 'pop rock', 'pop soul', 'rhythm and blues', 'rock', 'smooth jazz', 'smooth soul', 'sophisti-pop', 'uk']": 5,
#          "['alternative rock', 'australia', 'australian', 'australie', 'australien', 'classic pop and rock', 'new wave', 'pop', 'pop rock', 'rock']": 3,
#          "['british', 'classic pop and rock', 'death by lung cancer', 'electronic', 'english', 'experimental', 'folk', 'folk pop', 'my sweet lord', 'pop', 'pop rock', 'pop/rock', 'psychedelic rock', 'rock', 'singer/songwriter', 'uk', 'united kingdom']": 1,
#          "['adult contemporary', 'blue-eyed soul', 'british', 'classic pop and rock', 'dance-pop', 'english', 'pop', 'uk']": 2,
#          "['adult contemporary', 'classic pop and rock', 'pop', 'pop rock']": 1,
#          "['adult contemporary', 'pop rock']": 1,
#          "['adult contemporary', 'american', 'christmas music', 'conga', 'cuban', 'dance', 'dance-pop', 'latin freestyle', 'latin pop', 'pop', 'pop and chart', 'pop rock', 'rock']": 4,
#          "['aor', 'classic pop and rock', 'hard rock', 'pop rock', 'power pop', 'rock', 'soft rock']": 1,
#          "['british', 'classic pop and rock', 'english', 'glam metal', 'hard rock', 'heavy metal', 'metal', 'nwobhm', 'pop rock', 'rock', 'uk']": 4,
#          "['adult contemporary', 'american', 'club dance', 'dance-pop', 'electronic', 'house', 'pop', 'urban']": 3,
#          "['contemporary r&b', 'dance-pop', 'hip hop rnb and dance hall', 'new jack swing', 'pop', 'rnb']": 4,
#          "['american', 'classic pop and rock', 'glam metal', 'hard rock', 'metal', 'rock']": 2,
#          "['adult contemporary', 'american', 'jazz', 'quiet storm', 'rnb', 'smooth jazz', 'soul', 'soul and reggae']": 2,
#          "['british', 'classic pop and rock', 'dance-pop', 'english', 'new wave', 'pop', 'pop rock', 'pop soul', 'sophisti-pop', 'uk']": 1,
#          "['american', 'classic', 'classic pop and rock', 'contemporary folk', 'folk', 'folk pop', 'folk rock', 'paul-simon', 'pop', 'pop rock', 'pop/rock', 'rock', 'singer/songwriter', 'various artists', 'world']": 1,
#          "['american', 'easy listening soundtracks and musicals', 'popular', 'rock', 'soft rock']": 5,
#          "['american', 'blues rock', 'classic pop and rock', 'classic rock. blues rock', 'hard rock', 'heavy metal', 'medley a b', 'metal', 'pop rock', 'rock', 'soft rock']": 4,
#          "['boom bap', 'east coast hip hop', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'pop rap']": 1,
#          "['classic pop and rock', 'new wave', 'pop', 'pop punk', 'pop rock', 'power pop', 'punk', 'surf rock', 'usa']": 2,
#          "['american', 'classic pop and rock']": 3,
#          "['beijing', 'seen live']": 2,
#          "['american', 'aor', 'hard rock', 'pop rock', 'rock']": 1,
#          "['british', 'classic pop and rock', 'english', 'uk']": 4,
#          "['adult contemporary', 'folk', 'pop rock', 'pop rock country rock', 'rock', 'rock and indie']": 2,
#          "['american', 'dance-pop', 'hip hop rnb and dance hall', 'pop', 'rnb', 'urban']": 2,
#          "['american', 'heavy metal', 'metal', 'progressive metal', 'rock and indie']": 1,
#          "['adult contemporary', 'country', 'deep soul', 'doo-wop', 'gospel', 'jazz', 'new orleans r&b', 'pop', 'r&b', 'soul']": 1,
#          "['british', 'english', 'pop and chart', 'uk']": 1,
#          "['classic pop and rock', 'folk', 'multiple ipi']": 3,
#          "['blues', 'british', 'british blues', 'classic pop and rock', 'pop', 'pop rock', 'rock', 'rock blues', 'soft rock']": 1,
#          "['70s', '80s', 'disco', 'funk', 'latin']": 1,
#          "['american', 'américain', 'composer', 'compositeur', 'guitarist', 'guitariste', 'rock and indie', 'usa']": 2,
#          "['aor', 'boston', 'classic pop and rock', 'hard rock', 'heavy metal', 'massachusetts', 'pop rock', 'pop/rock', 'progressive rock', 'rock']": 1,
#          "['classic pop and rock', 'jazz-rock', 'pop/rock']": 1,
#          "['american', 'band', 'blues', 'blues rock', 'british', 'british blues', 'classic pop and rock', 'fleetwood mac', 'jam band', 'pop', 'pop rock', 'pop/rock', 'rock', 'soft rock']": 4,
#          "['christian rock', 'glam metal', 'rock']": 1,
#          "['alternative rock', 'british', 'classic pop and rock', 'england', 'english', 'hereford', 'new wave', 'punk', 'punk rock', 'rock', 'uk']": 2,
#          "['alternative hip-hop', 'american', 'américain', 'east coast hip hop', 'electro', 'funk', 'hardcore punk', 'hip hop', 'hip-hop', 'hiphop', 'new york hardcore', 'ny', 'prank calls', 'punk', 'rap', 'rap rock', 'rock', 'rock and indie', 'us', 'usa']": 1,
#          "['american', 'gangsta rap', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'political rap', 'west coast hip-hop']": 2,
#          "['alternative rock', 'american', 'jangle pop', 'power pop', 'rock', 'usa']": 1,
#          "['acid house', 'ambient', 'ambient house', 'british', 'electronic', 'english', 'pop', 'rock and indie', 'uk']": 1,
#          "['adult contemporary', 'blue-eyed soul', 'blues rock', 'folk', 'pop rock', 'rock', 'rock and indie', 'singer/songwriter', 'soft rock']": 2,
#          "['american', 'blues rock', 'boogie rock', 'classic pop and rock', 'hard rock', 'rock', 'southern rock', 'stoner rock', 'texas']": 1,
#          "['boom bap', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'hip house', 'hip-hop', 'rap', 'rap rock', 'rock and indie', 'usa']": 1,
#          "['art rock', 'baroque pop', 'british', 'classic pop and rock', 'english', 'pop rock', 'pop/rock', 'progressive pop', 'progressive rock', 'symphonic prog', 'uk']": 1,
#          '[\'american\', \'amos lee\', \'classic pop and rock\', \'garage rock\', \'glam rock\', \'hard rock\', \'heavy metal\', "love\'s a loaded gun", \'metal\', \'new wave\', \'pop rock\', \'psychedelic rock\', \'rock\', \'shock rock\']': 3,
#          "['blue-eyed soul', 'country', 'soft rock']": 2,
#          "['british', 'dance and electronica', 'english', 'uk']": 1,
#          "['canadian', 'hard rock', 'loverboy', 'loverboy - big ones', 'rock']": 1,
#          "['american', 'pop', 'rock']": 1,
#          "['american', 'hip hop rnb and dance hall', 'pop', 'rnb']": 1,
#          "['adult contemporary', 'boy band', 'boy group', 'british', 'dance-pop', 'electropop', 'english', 'pop', 'pop and chart', 'pop rock', 'pop-rock', 'teen pop', 'uk']": 1,
#          "['columbia', 'south carolina']": 1,
#          "['alternative', 'american', 'classic pop and rock', 'dance', 'hip-hop', 'pop', 'rock']": 1,
#          "['adult contemporary', 'american', 'classic pop and rock', 'easy listening', 'pop', 'pop soul', 'quiet storm', 'rnb', 'rock', 'smooth soul', 'soft rock', 'soul', 'urban']": 4,
#          "['american', 'classic pop and rock', 'neo rockabilly', 'rock', 'rockabilly']": 1,
#          "['birmingham', 'british', 'classic pop and rock', 'english', 'uk']": 1,
#          "['blue-eyed soul', 'british', 'classic pop and rock', 'english', 'new romantic', 'new wave', 'pop', 'pop rock', 'sophisti-pop', 'uk']": 1,
#          "['acid rock', 'blues rock', 'psychedelic rock']": 1,
#          "['alternative rock', 'jangle pop', 'pop rock', 'post-grunge', 'southern rock']": 1,
#          "['alternative rock', 'american underground', 'classic pop and rock', 'jangle pop', 'pop rock', 'power pop', 'punk rock']": 1,
#          "['art pop', 'art rock', 'british', 'classic pop and rock', 'english', 'pop rock', 'pop/rock', 'progressive pop', 'progressive rock', 'rock', 'uk']": 1,
#          "['american', 'hip hop rnb and dance hall', 'jazz', 'jazz pop', 'jazz-funk', 'rnb', 'smooth jazz', 'smooth soul', 'soul jazz']": 1,
#          "['canadian', 'classic pop and rock', 'country', 'pop']": 2,
#          "['bluegrass', 'blues rock', 'country', 'country rock', 'outlaw country', 'rock', 'southern rock']": 1,
#          "['adult contemporary', 'contemporary country', 'country', 'country pop', 'neo-traditionalist country']": 5,
#          "['blues rock', 'folk rock', 'heartland rock']": 1,
#          "['british', 'grunge', 'post-grunge']": 1,
#          "['american', 'country']": 4,
#          "['contemporary country', 'country', 'country pop', 'country rock']": 1,
#          "['alternative rock', 'pop rock', 'power pop']": 1,
#          "['amazing', 'black metal', 'christmas music', 'contemporary r&b', 'dance-pop', 'electropop', 'gay', 'pop', 'teen pop', 'tropical house']": 1,
#          "['contemporary country', 'country', 'country pop']": 2,
#          "['classic pop and rock', 'hip hop rnb and dance hall']": 1,
#          "['american', 'contemporary r&b', 'doo wop', 'funk', 'rhythm & blues', 'rnb', 'rock', 'rock & roll', 'smooth soul', 'soul', 'soul and reggae']": 1,
#          "['contemporary country', 'country', 'country pop', 'singer/songwriter']": 7,
#          "['blues', 'folk', 'rock']": 1,
#          "['australian', 'chamber pop', 'dance-pop', 'downtempo', 'electropop', 'indie pop', 'mbs-333', 'pop', 'pop and chart']": 1,
#          "['contemporary r&b', 'dance-pop', 'pop', 'pop rock', 'pop soul']": 1,
#          "['ballad', 'contemporary r&b', 'deep house', 'hip hop', 'pop', 'pop rap']": 1,
#          "['complextro', 'contemporary r&b', 'dance', 'dance and electronica', 'dance-pop', 'disco', 'electro house', 'electro-disco', 'electronic', 'electropop', 'hip house', 'house', 'ibiza trance', 'nu-disco', 'progressive house', 'uk hip hop']": 1,
#          "['boy band', 'pop', 'pop punk', 'pop rock', 'power pop']": 2,
#          "['complextro', 'dance-pop', 'electro house', 'electropop', 'progressive house']": 1,
#          "['american', 'contemporary country', 'country', 'country pop', 'rockabilly']": 3,
#          "['bluegrass', 'contemporary country', 'country', 'country pop', 'folk', 'pop rock', 'traditional country']": 2,
#          "['bluegrass', 'christmas music', 'contemporary country', 'country', 'country gospel']": 3,
#          "['american', 'contemporary r&b', 'r&b']": 1,
#          "['contemporary r&b', 'dance-pop', 'pop', 'r&b']": 1,
#          "['2 pac', 'above the rim', 'conscious hip hop', 'death by gun', 'death by murder', 'g-funk', 'gangsta rap', 'hip hop', 'hip hop rnb and dance hall', 'political hip hop', 'pop rap', 'temor a la muerte', 'unil the end of time', 'west coast hip hop']": 2,
#          "['contemporary country', 'country']": 1,
#          "['american idol']": 1,
#          "['alternative metal', 'alternative rock', 'american', 'fixme label mess', 'hard rock', 'post-grunge', 'rock', 'rock and indie', 'supergroup']": 1,
#          "['adult contemporary', 'americana', 'country pop', 'folk', 'jazz and blues', 'jazz pop', 'singer/songwriter', 'vocal jazz']": 1,
#          "['british', 'english', 'hip hop rnb and dance hall', 'hip-hop', 'neo soul', 'rnb', 'soul', 'spoken word soul']": 1,
#          "['american', 'contemporary country', 'country', 'country pop']": 2,
#          "['american', 'dirty south', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'pop rap', 'rap', 'southern hip hop', 'trap rap']": 2,
#          "['alternative', 'alternative metal', 'alternative rock', 'hard rock']": 1,
#          "['alternative metal', 'canadian', 'hard rock', 'metal', 'pop rock', 'post-grunge', 'rock']": 1,
#          "['american', 'g-funk', 'gangsta rap', 'hip hop', 'hip hop rnb and dance hall', 'hip-hop', 'reggae', 'west coast hip hop', 'west coast hip-hop']": 1,
#          "['alternative rock', 'dance', 'pop', 'synthpop']": 1,
#          "['alternative dance', 'alternative hip-hop', 'alternative rock', 'british', 'electronic', 'electronica', 'electropop', 'english', 'fictional', 'hip hop', 'hip-hop', 'parlophone', 'producer', 'producteur', 'rock', 'rock and indie', 'trip hop', 'trip rock', 'trip-hop', 'uk']": 1,
#          "['american', 'american idol', 'blue-eyed soul', 'blues', 'blues rock', 'pop', 'rock']": 1,
#          "['alternative', 'pop']": 1,
#          "['contemporary country', 'country', 'country pop', 'pop rock']": 1,
#          "['american', 'chicago soul', 'death by diabetes', 'funk', 'rnb', 'soul', 'soul and reggae']": 1,
#          "['american', 'contemporary folk', 'folk', 'folk rock', 'singer/songwriter']": 1,
#          "['00s', '10s', '70s', '80s', '90s', 'classic pop and rock', 'experimental', 'guitar', 'male vocalists', 'producer', 'rock', 'singer-songwriter']": 2,
#          "['70s', 'country rock', 'folk', 'male vocalists', 'pete carr', 'progressive rock', 'rock', 'southern rock', 'usa']": 1,
#          "['1 13 165900 150 7672 22647 34612 48720 59280 74602 87545 95495 107182 131087 141522 153710', '1960s', '1970s', '1980s', '1990s', '2000s', 'american', 'blues', 'blues rock', 'classic pop and rock', 'contemporary folk', 'country', 'country rock', 'dylan bootleg series', 'folk', 'folk rock', 'icon', 'pledging my time', 'pop rock', 'pop/rock', 'rare', 'rock', 'singer/songwriter', 'siple twist of fate', 'teater konsert']": 1,
#          'blues': 1,
#          "['blues rock', 'british', 'british blues', 'british rhythm & blues', 'classic pop and rock', 'english', 'garage rock', 'hard rock', 'mod', 'psychedelic rock', 'rhythm & blues', 'rhythm and blues', 'rock', 'rock and roll', 'uk']": 1,
#          "['adult contemporary', 'american', 'beach', 'country', 'country rock', 'rock']": 1,
#          "['adult contemporary', 'american', 'pop', 'rnb', 'soul', 'urban']": 1,
#          "['canada', 'canadian', 'canadien', 'celtic', 'celtique', 'ethereal', 'folk', 'new age', 'world']": 1,
#          "['acid rock', 'american', 'folk', 'folk rock', 'hard rock', 'psychedelic pop', 'psychedelic rock', 'rock', 'rock and indie', 'west coast rock']": 1,
#          "['classic pop and rock', 'garage rock', 'psychedelic rock']": 1,
#          "['60s', '70s', '80s', '90s', 'art rock', 'band', 'britannique', 'british', 'classic pop and rock', 'classic rock', 'defacing', 'english', 'progressive', 'progressive rock', 'psychedelic pop', 'psychedelic rock', 'rock', 'rock opera', 'roger waters', 'space rock', 'uk']": 1,
#          "['blues rock', 'hard rock', 'rock']": 1,
#          "['canción melódica', 'classic pop and rock', 'folk pop', 'pop', 'pop rock', 'singer/songwriter']": 1,
#          "['british', 'classic pop and rock', 'uk', 'wales', 'welsh']": 1,
#          "['british', 'english']": 1,
#          "['american', 'folk', 'folk rock', 'rock']": 1,
#          "['adult contemporary', 'american', 'big band', 'classic pop and rock', 'country', 'easy listening', 'jazz', 'latin', 'pop', 'rock', 'rock and roll', 'swing']": 1,
#          "['blue eyed soul', 'blues', 'british', 'english', 'pop', 'pop/rock', 'rock', 'uk']": 1,
#          "['british', 'english', 'pop rock', 'rock & roll', 'sunshine pop', 'uk']": 1,
#          "['acoustic rock', 'classic pop and rock', 'country rock', 'folk rock', 'pop rock', 'rock', 'singer/songwriter']": 1,
#          "['blues', 'blues rock', 'electric blues', 'filmore', 'jazz and blues', 'live', 'rhythm & blues', 'urban blues']": 1,
#          "['british', 'classic pop and rock', 'english', 'liverpool', 'uk']": 2,
#          "['all-time greatest hits', 'death by airplane']": 1,
#          "['adult contemporary', 'folk pop', 'folk rock', 'pop rock', 'soft rock', 'west coast rock']": 1,
#          "['blues rock', 'british', 'classic pop and rock', 'english', 'folk', 'folk rock', 'hard rock', 'progressive rock', 'rock', 'uk']": 1,
#          "['british', 'classic pop and rock', 'english', 'uk', 'united kingdom']": 1,
#          "['boogie-woogie', 'new orleans r b', 'new orleans r&b', 'piano blues', 'rhythm & blues', 'rnb', 'rock', 'rock & roll', 'rock and indie', 'rock and roll']": 1,
#          "['classic pop and rock', 'death by liver cancer']": 1,
#          "['canadian', 'easy listening soundtracks and musicals']": 1,
#          "['big band', 'brill building', 'death by blood poisoning', 'easy listening soundtracks and musicals', 'folk', 'pop', 'rock', 'rock & roll', 'rock and roll', 'standards', 'teen pop', 'traditional pop']": 1,
#          "['classic pop and rock', 'disco', 'film score', 'funk', 'pop soul', 'smooth soul', 'soul']": 1,
#          "['classic pop and rock', 'contemporary folk', 'folk', 'folk pop', 'folk rock', 'pop rock', 'singer/songwriter', 'soft rock']": 1,
#          "['american', 'americana', 'blues', 'contemporary folk', 'country', 'country gospel', 'death by diabetes', 'favorite', 'folk', 'gospel', 'osteraker', 'outlaw country', 'rock', 'rock and roll', 'rockabilly', 'spoken word', 'traditional country']": 1,
#          "['australian']": 1,
#          "['american', 'death by lung cancer', 'easy listening soundtracks and musicals', 'jazz', 'jump blues', 'pop', 'swing', 'usa', 'vocal jazz']": 1,
#          "['big band', 'swing', 'traditional pop']": 1,
#          "['blue-eyed soul', 'pop rock', 'soft rock']": 1,
#          "['british', 'english', 'rock and indie', 'uk']": 1,
#          "['b00138f5lm', 'classic pop and rock']": 1,
#          "['blues rock', 'boogie rock', 'hard rock']": 1,
#          "['british', 'bubblegum', 'classic pop and rock', 'pop', 'pop rock', 'power pop', 'scottish', 'soft rock', 'teen pop', 'uk']": 1,
#          "['celtic rock', 'classic pop and rock', 'hard rock', 'heavy metal', 'pop rock', 'rock']": 1})

# %%
s = songs['Hit'].value_counts().head(20)

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(12,5))

ax=s.plot.bar(width=.9, color=('blue', 'orange', 'green', 'red', 'purple', 'brown')) 
for i, v in s.reset_index().iterrows():
    ax.text(i, v.Hit + 0.2 , v.Hit, color='black')

ax.set_xlabel(len(songs.decades))
plt.title("Die Anzahl der Songs pro Dekade")
#plt.xlabel(len(df.Bemerkungen))
plt.ylabel('Anzahl')
#pltcountplotfig("songs_per_genre")
#plt.savefig('../Grafiken/Grafiken_SMS_2018_2019/Auswertung_SMS_2018_2019_BD.png', bbox_inches = "tight")
# Out:
# Text(0, 0.5, 'Anzahl')

# %%
import os
import glob
import csv
from xlsxwriter.workbook import Workbook


for csvfile in glob.glob(os.path.join('.', '../../data/CSV/sample_hits_no_hits.csv')):
    workbook = Workbook(csvfile[:-4] + '.xlsx')
    worksheet = workbook.add_worksheet()
    with open(csvfile, 'rt', encoding='utf8') as f:
        reader = csv.reader(f)
        for r, row in enumerate(reader):
            for c, col in enumerate(row):
                worksheet.write(r, c, col)
    workbook.close()
