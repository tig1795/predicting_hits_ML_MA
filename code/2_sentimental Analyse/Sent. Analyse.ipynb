# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/CSV/dataset_lyrics_hits_non_hits_none.csv", index_col=0)

# %%
df.head(5)
# Out:
#                                               lyrics  \
# 0  i know this pain  i know this pain why do you ...
# 1  must have been lovebut it's over nowlay a whis...
# 2  it's been seven hours and fifteen dayssince yo...
# 3  poison yeah spyderman & freeze in full effectp...
# 4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# 1  1990        5.2         97.20         35
# 2  1990        4.8         89.75         28
# ...

# %%
type(df.sentiment)
# Out:
# pandas.core.series.Series

# %%
df.sentiment.max()
# Out:
# "{'neg': 0.614, 'neu': 0.34600000000000003, 'pos': 0.04, 'compound': -0.9999}"

# %%
sa = df.sentiment

# %%
sa.iloc[:5]
# Out:
# 0    {'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'co...
# 1    {'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000...
# 2    {'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'co...
# 3    {'neg': 0.155, 'neu': 0.7030000000000001, 'pos...
# 4    {'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'co...
# Name: sentiment, dtype: object

# %%
test = df.iloc[2]['sentiment']

# %%
test
# Out:
# "{'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'compound': -0.8173}"

# %%
type(test)
# Out:
# str

# %%
import ast
hi = ast.literal_eval(test)

# %%
hi
# Out:
# {'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'compound': -0.8173}

# %%
type(hi)
# Out:
# dict

# %%
#df = {'key1' : 5, 'key2': 35, 'key3': 25}
 
max_value = max(hi.values())

# %%
max_value
# Out:
# 0.798

# %%
df.shape
# Out:
# (3807, 21)

# %%
dfs = list(df.sentiment)

# %%
dicts = df.sentiment.to_dict()

# %%
print(dicts)
# Out:
# {0: "{'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'compound': 0.8335}", 1: "{'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000000000002, 'compound': 0.9959}", 2: "{'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'compound': -0.8173}", 3: "{'neg': 0.155, 'neu': 0.7030000000000001, 'pos': 0.14200000000000002, 'compound': -0.877}", 4: "{'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'compound': 0.9753000000000001}", 5: "{'neg': 0.044, 'neu': 0.673, 'pos': 0.28300000000000003, 'compound': 0.9959}", 6: "{'neg': 0.024, 'neu': 0.753, 'pos': 0.223, 'compound': 0.9974000000000001}", 7: "{'neg': 0.085, 'neu': 0.681, 'pos': 0.234, 'compound': 0.9941000000000001}", 8: "{'neg': 0.077, 'neu': 0.496, 'pos': 0.427, 'compound': 0.9995}", 9: "{'neg': 0.117, 'neu': 0.652, 'pos': 0.231, 'compound': 0.9939}", 10: "{'neg': 0.007, 'neu': 0.915, 'pos': 0.077, 'compound': 0.9848}", 11: "{'neg': 0.017, 'neu': 0.902, 'pos': 0.081, 'compound': 0.9643}", 12: "{'neg': 0.018000000000000002, 'neu': 0.9560000000000001, 'pos': 0.025,
# ...

# %%
df.head(5)
# Out:
#                                               lyrics  \
# 0  i know this pain  i know this pain why do you ...
# 1  must have been lovebut it's over nowlay a whis...
# 2  it's been seven hours and fifteen dayssince yo...
# 3  poison yeah spyderman & freeze in full effectp...
# 4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# 1  1990        5.2         97.20         35
# 2  1990        4.8         89.75         28
# ...

# %%
df.columns
# Out:
# Index([       'lyrics',         'genre', 'num_syllables',           'pos',
#                 'year',     'fog_index',  'flesch_index',     'num_lines',
#            'sentiment',         'title',
#        ...
#                   3797,            3798,            3799,            3800,
#                   3801,            3802,            3803,            3804,
#                   3805,            3806],
#       dtype='object', length=3828)

# %%
max(dicts)
# Out:
# 3806

# %%
dicts
# Out:
# {0: "{'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'compound': 0.8335}",
#  1: "{'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000000000002, 'compound': 0.9959}",
#  2: "{'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'compound': -0.8173}",
#  3: "{'neg': 0.155, 'neu': 0.7030000000000001, 'pos': 0.14200000000000002, 'compound': -0.877}",
#  4: "{'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'compound': 0.9753000000000001}",
#  5: "{'neg': 0.044, 'neu': 0.673, 'pos': 0.28300000000000003, 'compound': 0.9959}",
#  6: "{'neg': 0.024, 'neu': 0.753, 'pos': 0.223, 'compound': 0.9974000000000001}",
#  7: "{'neg': 0.085, 'neu': 0.681, 'pos': 0.234, 'compound': 0.9941000000000001}",
#  8: "{'neg': 0.077, 'neu': 0.496, 'pos': 0.427, 'compound': 0.9995}",
#  9: "{'neg': 0.117, 'neu': 0.652, 'pos': 0.231, 'compound': 0.9939}",
#  10: "{'neg': 0.007, 'neu': 0.915, 'pos': 0.077, 'compound': 0.9848}",
#  11: "{'neg': 0.017, 'neu': 0.902, 'pos': 0.081, 'compound': 0.9643}",
# ...

# %%
type(dicts)
# Out:
# dict

# %%
for key in dicts.keys():
    print(value)
# Out:
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.9538000000000001}
# ...

# %%
result = [e for e in re.split("[^0-9]", "I saw 3 dogs, 17 cats, and 14 cows!") if e != '']

# list 'result' elements are strings: ['3', '17', '14'], so we use map(int, list) to get integers
print max(map(int, result))

# %%
hihi = df.sentiment

# %%
hihi
# Out:
# 0       {'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'co...
# 1       {'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000...
# 2       {'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'co...
# 3       {'neg': 0.155, 'neu': 0.7030000000000001, 'pos...
# 4       {'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'co...
#                               ...
# 3802    {'neg': 0.041, 'neu': 0.86, 'pos': 0.098, 'com...
# 3803    {'neg': 0.033, 'neu': 0.8180000000000001, 'pos...
# 3804    {'neg': 0.046, 'neu': 0.93, 'pos': 0.024, 'com...
# 3805    {'neg': 0.023, 'neu': 0.897, 'pos': 0.08, 'com...
# 3806    {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# Name: sentiment, Length: 3807, dtype: object

# %%
type(hihi)
# Out:
# pandas.core.series.Series

# %%
df.sentiment
# Out:
# 0       {'neg': 0.046, 'neu': 0.892, 'pos': 0.061, 'co...
# 1       {'neg': 0.056, 'neu': 0.737, 'pos': 0.20700000...
# 2       {'neg': 0.125, 'neu': 0.798, 'pos': 0.077, 'co...
# 3       {'neg': 0.155, 'neu': 0.7030000000000001, 'pos...
# 4       {'neg': 0.028, 'neu': 0.894, 'pos': 0.077, 'co...
#                               ...
# 3802    {'neg': 0.041, 'neu': 0.86, 'pos': 0.098, 'com...
# 3803    {'neg': 0.033, 'neu': 0.8180000000000001, 'pos...
# 3804    {'neg': 0.046, 'neu': 0.93, 'pos': 0.024, 'com...
# 3805    {'neg': 0.023, 'neu': 0.897, 'pos': 0.08, 'com...
# 3806    {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# Name: sentiment, Length: 3807, dtype: object

# %%
type(df.sentiment)
# Out:
# pandas.core.series.Series

# %%
result = df.sentiment.str.split(',', expand=True)

# %%
result
# Out:
#                   0                           1                            2  \
# 0     {'neg': 0.046                'neu': 0.892                 'pos': 0.061
# 1     {'neg': 0.056                'neu': 0.737   'pos': 0.20700000000000002
# 2     {'neg': 0.125                'neu': 0.798                 'pos': 0.077
# 3     {'neg': 0.155   'neu': 0.7030000000000001   'pos': 0.14200000000000002
# 4     {'neg': 0.028                'neu': 0.894                 'pos': 0.077
# ...             ...                         ...                          ...
# 3802  {'neg': 0.041                 'neu': 0.86                 'pos': 0.098
# 3803  {'neg': 0.033   'neu': 0.8180000000000001                 'pos': 0.149
# 3804  {'neg': 0.046                 'neu': 0.93                 'pos': 0.024
# 3805  {'neg': 0.023                'neu': 0.897                  'pos': 0.08
# 3806    {'neg': 0.0                'neu': 0.936                 'pos': 0.064
#
#                                      3
# ...

# %%
result = result.rename({0: 'negative', 1: 'neutral', 2: 'positive', 3: 'compound'}, axis=1)

# %%
result
# Out:
#            negative                     neutral                     positive  \
# 0     {'neg': 0.046                'neu': 0.892                 'pos': 0.061
# 1     {'neg': 0.056                'neu': 0.737   'pos': 0.20700000000000002
# 2     {'neg': 0.125                'neu': 0.798                 'pos': 0.077
# 3     {'neg': 0.155   'neu': 0.7030000000000001   'pos': 0.14200000000000002
# 4     {'neg': 0.028                'neu': 0.894                 'pos': 0.077
# ...             ...                         ...                          ...
# 3802  {'neg': 0.041                 'neu': 0.86                 'pos': 0.098
# 3803  {'neg': 0.033   'neu': 0.8180000000000001                 'pos': 0.149
# 3804  {'neg': 0.046                 'neu': 0.93                 'pos': 0.024
# 3805  {'neg': 0.023                'neu': 0.897                  'pos': 0.08
# 3806    {'neg': 0.0                'neu': 0.936                 'pos': 0.064
#
#                               compound
# ...

# %%
for i, row in result.iterrows():
    result.at[i, 'negative'] = row.negative.replace('{',' ').replace(' '' ',' ').replace(':',' ').lower()
result
# Out:
#           negative                     neutral                     positive  \
# 0      'neg' 0.046                'neu': 0.892                 'pos': 0.061
# 1      'neg' 0.056                'neu': 0.737   'pos': 0.20700000000000002
# 2      'neg' 0.125                'neu': 0.798                 'pos': 0.077
# 3      'neg' 0.155   'neu': 0.7030000000000001   'pos': 0.14200000000000002
# 4      'neg' 0.028                'neu': 0.894                 'pos': 0.077
# ...            ...                         ...                          ...
# 3802   'neg' 0.041                 'neu': 0.86                 'pos': 0.098
# 3803   'neg' 0.033   'neu': 0.8180000000000001                 'pos': 0.149
# 3804   'neg' 0.046                 'neu': 0.93                 'pos': 0.024
# 3805   'neg' 0.023                'neu': 0.897                  'pos': 0.08
# 3806     'neg' 0.0                'neu': 0.936                 'pos': 0.064
#
#                               compound
# ...

# %%
result['positive'] = result['positive'].str.replace('pos',' ')

# %%
result['positive'] = result['positive'].str.replace(':',' ')

# %%
result['positive'] = result['positive'].str.replace(" ' ", " ")

# %%
result['positive'] = result['positive'].str.replace(" ' ", " ")

# %%
result.head(5)
# Out:
#   negative               neutral               positive  \
# 0    0.046                 0.892                  0.061
# 1    0.056                 0.737    0.20700000000000002
# 2    0.125                 0.798                  0.077
# 3    0.155    0.7030000000000001    0.14200000000000002
# 4    0.028                 0.894                  0.077
#
#                            compound
# 0               'compound': 0.8335}
# 1               'compound': 0.9959}
# 2              'compound': -0.8173}
# 3               'compound': -0.877}
# 4   'compound': 0.9753000000000001}

# %%
result = result.drop(["compound"], axis=1)

# %%
result
# Out:
#      negative               neutral               positive
# 0       0.046                 0.892                  0.061
# 1       0.056                 0.737    0.20700000000000002
# 2       0.125                 0.798                  0.077
# 3       0.155    0.7030000000000001    0.14200000000000002
# 4       0.028                 0.894                  0.077
# ...       ...                   ...                    ...
# 3802    0.041                  0.86                  0.098
# 3803    0.033    0.8180000000000001                  0.149
# 3804    0.046                  0.93                  0.024
# 3805    0.023                 0.897                   0.08
# 3806      0.0                 0.936                  0.064
#
# [3807 rows x 3 columns]

# %%
result['max_value'] = result.max(axis=1)

# %%
result.drop(['max_value'], axis=1)
# Out:
#      negative               neutral               positive
# 0       0.046                 0.892                  0.061
# 1       0.056                 0.737    0.20700000000000002
# 2       0.125                 0.798                  0.077
# 3       0.155    0.7030000000000001    0.14200000000000002
# 4       0.028                 0.894                  0.077
# ...       ...                   ...                    ...
# 3802    0.041                  0.86                  0.098
# 3803    0.033    0.8180000000000001                  0.149
# 3804    0.046                  0.93                  0.024
# 3805    0.023                 0.897                   0.08
# 3806      0.0                 0.936                  0.064
#
# [3807 rows x 3 columns]

# %%
result['negative'] = result['negative'].astype('float')

# %%
result['neutral'] = result['neutral'].astype('float')

# %%
result['positive'] = result['positive'].astype('float')

# %%
result['max_value'] = result.max(axis=1)

# %%
result
# Out:
#       negative  neutral  positive  max_value
# 0        0.046    0.892     0.061      0.892
# 1        0.056    0.737     0.207      0.737
# 2        0.125    0.798     0.077      0.798
# 3        0.155    0.703     0.142      0.703
# 4        0.028    0.894     0.077      0.894
# ...        ...      ...       ...        ...
# 3802     0.041    0.860     0.098      0.860
# 3803     0.033    0.818     0.149      0.818
# 3804     0.046    0.930     0.024      0.930
# 3805     0.023    0.897     0.080      0.897
# 3806     0.000    0.936     0.064      0.936
#
# [3807 rows x 4 columns]

# %%
step = df.join(result)

# %%
step.head(5)
# Out:
#                                               lyrics  \
# 0  i know this pain  i know this pain why do you ...
# 1  must have been lovebut it's over nowlay a whis...
# 2  it's been seven hours and fifteen dayssince yo...
# 3  poison yeah spyderman & freeze in full effectp...
# 4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# 1  1990        5.2         97.20         35
# 2  1990        4.8         89.75         28
# ...

# %%
step.shape
# Out:
# (3807, 25)

# %%
data1 = step[step['Hit'] == 'True']
data2 = step[step['Hit'] == 'False']

excel = pd.concat([data1, data2], axis=0)

# %%
excel.shape
# Out:
# (1581, 25)

# %%
excel
# Out:
#                                                  lyrics  \
# 0     i know this pain  i know this pain why do you ...
# 1     must have been lovebut it's over nowlay a whis...
# 2     it's been seven hours and fifteen dayssince yo...
# 3     poison yeah spyderman & freeze in full effectp...
# 4     what are you lookin' at?strike a pose strike a...
# ...                                                 ...
# 3802  doctor  my woman is comin' back home late toda...
# 3803  you show us everything you've gotyou keep on d...
# 3804  guess who just got back todaythem wild-eyed bo...
# 3805  this here's a story 'bout billy joe and bobbie...
# 3806  living in the cityain't never been my ideaof g...
#
#                                                   genre  num_syllables  pos  \
# 0     ['adult contemporary', 'american', 'classic po...          496.8    1
# 1     ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# ...

# %%
excel.to_excel("next try.xlsx")

# %%
excel2 = pd.read_excel("next try.xlsx")

# %%
excel2.head(5)
# Out:
#    Unnamed: 0                                             lyrics  \
# 0           0  i know this pain  i know this pain why do you ...
# 1           1  must have been lovebut it's over nowlay a whis...
# 2           2  it's been seven hours and fifteen dayssince yo...
# 3           3  poison yeah spyderman & freeze in full effectp...
# 4           4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# ...

# %%
excel2 = excel2.loc[:, ~excel2.columns.str.contains('^Unnamed')]

# %%
excel2.head(5)
# Out:
#                                               lyrics  \
# 0  i know this pain  i know this pain why do you ...
# 1  must have been lovebut it's over nowlay a whis...
# 2  it's been seven hours and fifteen dayssince yo...
# 3  poison yeah spyderman & freeze in full effectp...
# 4  what are you lookin' at?strike a pose strike a...
#
#                                                genre  num_syllables  pos  \
# 0  ['adult contemporary', 'american', 'classic po...          496.8    1
# 1  ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# 2  ['alternative', 'alternative rock', 'folk', 'i...          272.7    3
# 3                                        hip-hop/rnb          500.4    4
# 4  ['american', 'américain', 'arabic', 'art pop',...          554.4    5
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1990        4.8        106.67         61
# 1  1990        5.2         97.20         35
# 2  1990        4.8         89.75         28
# ...

# %%
excel2.shape
# Out:
# (1581, 26)

# %%
excel2.to_csv("../../data/CSV/hit_nohit_sentimental_mit_duplikaten",index=False)

# %%
pd.read_csv("../../data/CSV/hit_nohit_sentimental_mit_duplikaten")
# Out:
#                                                  lyrics  \
# 0     i know this pain  i know this pain why do you ...
# 1     must have been lovebut it's over nowlay a whis...
# 2     it's been seven hours and fifteen dayssince yo...
# 3     poison yeah spyderman & freeze in full effectp...
# 4     what are you lookin' at?strike a pose strike a...
# ...                                                 ...
# 1576  doctor  my woman is comin' back home late toda...
# 1577  you show us everything you've gotyou keep on d...
# 1578  guess who just got back todaythem wild-eyed bo...
# 1579  this here's a story 'bout billy joe and bobbie...
# 1580  living in the cityain't never been my ideaof g...
#
#                                                   genre  num_syllables  pos  \
# 0     ['adult contemporary', 'american', 'classic po...          496.8    1
# 1     ['80s pop', 'classic pop and rock', 'european'...          343.8    2
# ...
