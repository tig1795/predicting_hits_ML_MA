# %% [markdown]
# # Imports

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()

# The device name should look like the following:
if device_name == '/device:GPU:0':
    print('Found GPU at: {}'.format(device_name))
else:
    raise SystemError('GPU device not found')
# Out:
# Found GPU at: /device:GPU:0

# %%
import pandas as pd

df1 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset_ML.csv')

# %%
df1.shape
# Out:
# (1801, 45)

# %%
df1.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %% [markdown]
# # Create One Big dataset

# %%
data1 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-60s.csv')

# %%
data2 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-70s.csv')

# %%
data3 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-80s.csv')

# %%
data4 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-90s.csv')

# %%
data5 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-00s.csv')

# %%
data6 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/dataset-of-10s.csv')

# %%
# Concatenate dataframes row-wise
merged_df = pd.concat([data1, data2, data3, data4, data5, data6], axis=0)

# Reset the index of the merged dataframe
df2 = merged_df.reset_index(drop=True)

# Print the merged dataframe
df2
# Out:
#                        track            artist  \
# 0      Jealous Kind Of Fella     Garland Green
# 1              Initials B.B.  Serge Gainsbourg
# 2               Melody Twist       Lord Melody
# 3              Mi Bomba Sonó        Celia Cruz
# 4                Uravu Solla       P. Susheela
# ...                      ...               ...
# 41101          Lotus Flowers             Yolta
# 41102      Calling My Spirit       Kodak Black
# 41103          Teenage Dream        Katy Perry
# 41104         Stormy Weather    Oscar Peterson
# 41105                   Dust       Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3
# 1      spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3
# 2      spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5
# 3      spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7
# ...

# %%
df2.to_csv('/content/gdrive/My Drive/Colab Datasets/big_dataset.csv', index=False)

# %%
import pandas as pd

df2 = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/big_dataset.csv')

# %%
df2.head(5)
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# ...

# %%
Counter(sample_df.Hit)
# Out:
# Counter({'Yes': 578, 'No': 584})

# %%
Counter(sample_df.target)
# Out:
# Counter({1: 1159, 0: 3})

# %%
sample_df.to_csv('/content/gdrive/My Drive/Colab Datasets/sample_two_datasets_hit_column.csv', index=False)

# %%
sample_df.head(5)
# Out:
#                               track          artist  \
# 0                I Love You Because      Al Martino
# 1                 Let's Twist Again  Chubby Checker
# 2  I Heard It Through The Grapevine     Marvin Gaye
# 3                             Dizzy       Tommy Roe
# 4                           El Paso   Marty Robbins
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:5ggafYsNyKhTR9bISS3OPj         0.290   0.200    8   -12.748
# 1  spotify:track:1INWPr855fwWdAOeecbu0W         0.604   0.709    8    -6.377
# 2  spotify:track:1tqT6DhmsrtQgyCKUwotiw         0.711   0.362    3   -10.851
# 3  spotify:track:3jJKKhg0t4HpdfNDyGiZDy         0.802   0.407    6   -10.857
# 4  spotify:track:4f8hBeMXMvssn6HtFAtblo         0.654   0.452    2    -9.709
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0275       0.89400          0.000569    0.2210    0.233
# ...

# %%
sample_df.shape
# Out:
# (1162, 20)

# %% [markdown]
# # Which songs are in df1 but not in df2

# %%
df2 = df2.rename(columns={"track": "title"})

# %%
df2.shape
# Out:
# (40686, 19)

# %%
import pandas as pd

# Assuming you have a dataframe named df

# Drop duplicate rows
df2 = df2.drop_duplicates()

# Display the updated dataframe
df2
# Out:
#                        title            artist  \
# 0      Jealous Kind Of Fella     Garland Green
# 1              Initials B.B.  Serge Gainsbourg
# 2               Melody Twist       Lord Melody
# 3              Mi Bomba Sonó        Celia Cruz
# 4                Uravu Solla       P. Susheela
# ...                      ...               ...
# 41101          Lotus Flowers             Yolta
# 41102      Calling My Spirit       Kodak Black
# 41103          Teenage Dream        Katy Perry
# 41104         Stormy Weather    Oscar Peterson
# 41105                   Dust       Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3
# 1      spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3
# 2      spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5
# 3      spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7
# ...

# %%
df2.head()
# Out:
#                    title            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# ...

# %%
df1.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  i can't get no satisfactioni can't get no sati...
# 2  our life together is so precious togetherwe ha...
# 3  love is higher than a mountain love is thicker...
# 4  sittin' in the morning suni'll be sittin' when...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 2  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 3   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 4  ['american', 'blues', 'death by airplane', 'de...          223.2    4
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1965        4.8        106.67         37
# 2  1981        4.8         81.29         28
# ...

# %%
import pandas as pd

# Assuming you have two dataframes: df1 and df2

# Merge the dataframes on the title and artist columns
merged = pd.merge(df1, df2, on=['title', 'artist'], how='inner')

# Display the matching entries
print("Matching Entries:")
merged
# Out:
# Matching Entries:
#                                                  lyrics  \
# 0     look into my eyes  you will seewhat you mean t...
# 1     our life together is so precious togetherwe ha...
# 2     love is higher than a mountain love is thicker...
# 3     sittin' in the morning suni'll be sittin' when...
# 4     why do birds suddenly appeareverytime you are ...
# ...                                                 ...
# 1112  i remember the way  you used to love mei remem...
# 1113  she was staring out the window of that suvcomp...
# 1114  young emotions are mixed emotionsfor it's a wo...
# 1115  what's the sense in sharing this one and only ...
# 1116  i don't mindwhen you act your ageit suits me f...
#
#                                                   genre  num_syllables  pos  \
# 0     ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1     ['britannique', 'british', 'classic pop and ro...          288.0    4
# ...

# %%
merged.shape
# Out:
# (1117, 62)

# %%
# Merge the dataframes on the title and artist columns
merged = pd.merge(df1, df2, on=['title', 'artist'], how='inner')

# Add the "Hit" column from df1 to the merged dataframe
merged = merged.merge(df1[['title', 'artist', 'Hit']], on=['title', 'artist'], how='left')

# Display the updated merged dataframe
print("Updated Merged DataFrame:")
merged
# Out:
# Updated Merged DataFrame:
#                                                  lyrics  \
# 0     look into my eyes  you will seewhat you mean t...
# 1     our life together is so precious togetherwe ha...
# 2     love is higher than a mountain love is thicker...
# 3     sittin' in the morning suni'll be sittin' when...
# 4     why do birds suddenly appeareverytime you are ...
# ...                                                 ...
# 1112  i remember the way  you used to love mei remem...
# 1113  she was staring out the window of that suvcomp...
# 1114  young emotions are mixed emotionsfor it's a wo...
# 1115  what's the sense in sharing this one and only ...
# 1116  i don't mindwhen you act your ageit suits me f...
#
#                                                   genre  num_syllables  pos  \
# 0     ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1     ['britannique', 'british', 'classic pop and ro...          288.0    4
# ...

# %%
import pandas as pd

# Assuming you have two dataframes: df1 and df2

# Merge the dataframes on the title and artist columns
merged1 = pd.merge(df1, df2, on=['title', 'artist'], how='left', indicator=True)

# Filter for rows where the merge indicator is 'left_only'
non_matching_entries = merged1[merged1['_merge'] == 'left_only']

# Select only the desired columns from df1
#desired_columns = df1['title', 'artist']
#non_matching_entries = non_matching_entries[desired_columns]

# Display the non-matching entries
print("Non-Matching Entries:")
non_matching_entries
# Out:
# Non-Matching Entries:
#                                                  lyrics  \
# 1     i can't get no satisfactioni can't get no sati...
# 6     your love is liftin' me higherthan i've ever b...
# 8     ladies and gentlemen  ladies and gentlemen  oo...
# 9     new york city you are now ridingwith 50 centyo...
# 12    fetty wapyeah baby  1738ay  ay  lookbaby girl ...
# ...                                                 ...
# 1791  mase  and brian mcknight  bad boyc'monbad boy ...
# 1794  i woke up early this morning around 4a.m.with ...
# 1795  you're all i need to get by.like the sweet mor...
# 1797  you never close your eyes anymore when i kiss ...
# 1801  once upon a timeonce when you were minei remem...
#
#                                                   genre  num_syllables  pos  \
# 1     ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 6     ['adult contemporary', 'american', 'country', ...          235.8    8
# ...

# %%
non_matching_entries.shape
# Out:
# (685, 63)

# %% [markdown]
# One song too many, find out which one is missing.

# %%
selected_columns = ['title', 'artist']
merged_selected = merged[selected_columns]

#merged_selected

# %%
non_matching_entries_selected = non_matching_entries[selected_columns]
#non_matching_entries_selected

# %%
non_matching_entries_selected.isna().sum()
# Out:
# title     0
# artist    0
# dtype: int64

# %%
merged_selected.isna().sum()
# Out:
# title     0
# artist    0
# dtype: int64

# %%
# Find the common entry using inner merge
common_entry = pd.merge(merged_selected, non_matching_entries_selected, on=['title', 'artist'], how='inner')

# %%
common_entry
# Out:
# Empty DataFrame
# Columns: [title, artist]
# Index: []

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
#merged_selected

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
#non_matching_entries_selected

# %%
import pandas as pd

# Assuming you have two dataframes named 'df1' and 'df2' with the same columns
# Concatenate the dataframes and reset the index
concatenated_df = pd.concat([merged_selected, non_matching_entries_selected], ignore_index=True)

# %%
# Display the concatenated dataframe
#concatenated_df

# %%
concatenated_df = concatenated_df.rename(columns={"title": "Titel"})

# %%
concatenated_df.shape
# Out:
# (1802, 2)

# %%
df1.shape
# Out:
# (1801, 48)

# %%
selected_columns = ['title', 'artist']
df1_short = df1[selected_columns]

# %%
sorted_df1_short = df1_short.sort_values(by='title', ascending=True)
#sorted_df1_short

# %%
concatenated_df = concatenated_df.sort_values(by='Titel', ascending=True)
#concatenated_df

# %%
import pandas as pd

# Assuming you have two dataframes named 'df1' and 'df2' with the same columns
combined_df = pd.concat([sorted_df1_short, concatenated_df], axis=1)

# Display the combined dataframe
#combined_df

# %%
import pandas as pd

# Assuming you have a dataframe named 'df' with columns 'column1' and 'column2'
sorted_df = combined_df.sort_values(by=['title', 'Titel'], ascending=True)

# Display the sorted dataframe
sorted_df

sorted_df.to_excel('/content/gdrive/My Drive/Colab Datasets/output.xlsx', index=False)

# %%
sorted_df1_short.shape
# Out:
# (1801, 2)

# %%
sorted_df1_short.head(5)
# Out:
#                                     title          artist
# 0       (everything i do) i do it for you     bryan adams
# 1           (i can't get no) satisfaction  rolling stones
# 912  (it's just) the way that you love me     paula abdul
# 2               (just like) starting over     john lennon
# 3            (love is) thicker than water       andy gibb

# %%
sorted_df1_short[sorted_df1_short['title'] == 'drive']
# Out:
#       title        artist
# 1097  drive  alan jackson
# 214   drive       incubus

# %%
concatenated_df.shape
# Out:
# (1802, 2)

# %%
concatenated_df.head(5)
# Out:
#                                      Titel          artist
# 0        (everything i do) i do it for you     bryan adams
# 1117         (i can't get no) satisfaction  rolling stones
# 551   (it's just) the way that you love me     paula abdul
# 1                (just like) starting over     john lennon
# 2             (love is) thicker than water       andy gibb

# %%
concatenated_df[concatenated_df['Titel'] == 'drive']
# Out:
#       Titel        artist
# 1544  drive  alan jackson
# 125   drive       incubus
# 124   drive       incubus

# %% [markdown]
# ## Result

# %% [markdown]
# ## Concordance

# %%
merged.shape
# Out:
# (1117, 63)

# %%
merged.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  our life together is so precious togetherwe ha...
# 2  love is higher than a mountain love is thicker...
# 3  sittin' in the morning suni'll be sittin' when...
# 4  why do birds suddenly appeareverytime you are ...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 2   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 3  ['american', 'blues', 'death by airplane', 'de...          223.2    4
# 4  ['adult contemporary', 'baroque pop', 'classic...          236.7    2
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1981        4.8         81.29         28
# 2  1978        4.0         91.78         30
# ...

# %%
merged[merged['title'] == 'Drive']
# Out:
#                                                 lyrics  \
# 124  sometimesi feel the fear of uncertainty stingi...
# 125  sometimesi feel the fear of uncertainty stingi...
#
#                                                  genre  num_syllables  pos  \
# 124  ['alternative metal', 'alternative rock', 'ame...          281.7   21
# 125  ['alternative metal', 'alternative rock', 'ame...          281.7   21
#
#      year  fog_index  flesch_index  num_lines  \
# 124  2001        4.4         82.31         32
# 125  2001        4.4         82.31         32
#
#                                              sentiment  title  ...  \
# 124  {'neg': 0.062, 'neu': 0.879, 'pos': 0.05900000...  Drive  ...
# 125  {'neg': 0.062, 'neu': 0.879, 'pos': 0.05900000...  Drive  ...
#
#      instrumentalness_y liveness_y  valence_y  tempo_y  duration_ms_y  \
# 124              0.0121      0.119      0.666   90.565         232453
# 125              0.0121      0.119      0.666   90.565         232453
#
# ...

# %%
merged = merged.drop([124])

# %%
merged.shape
# Out:
# (1116, 63)

# %%
merged[merged['title'] == 'Drive']
# Out:
#                                                 lyrics  \
# 125  sometimesi feel the fear of uncertainty stingi...
#
#                                                  genre  num_syllables  pos  \
# 125  ['alternative metal', 'alternative rock', 'ame...          281.7   21
#
#      year  fog_index  flesch_index  num_lines  \
# 125  2001        4.4         82.31         32
#
#                                              sentiment  title  ...  \
# 125  {'neg': 0.062, 'neu': 0.879, 'pos': 0.05900000...  Drive  ...
#
#      instrumentalness_y liveness_y  valence_y  tempo_y  duration_ms_y  \
# 125              0.0121      0.119      0.666   90.565         232453
#
#      time_signature chorus_hit sections target Hit_y
# 125               4   22.93655       10      1   Yes
#
# [1 rows x 63 columns]

# %%
merged.to_csv('/content/gdrive/My Drive/Colab Datasets/sample_two_datasets_hit_column.csv', index=False)

# %%
ho = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/sample_two_datasets_hit_column.csv')

# %%
ho.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  our life together is so precious togetherwe ha...
# 2  love is higher than a mountain love is thicker...
# 3  sittin' in the morning suni'll be sittin' when...
# 4  why do birds suddenly appeareverytime you are ...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 2   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 3  ['american', 'blues', 'death by airplane', 'de...          223.2    4
# 4  ['adult contemporary', 'baroque pop', 'classic...          236.7    2
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1981        4.8         81.29         28
# 2  1978        4.0         91.78         30
# ...

# %%
ho.shape
# Out:
# (1116, 63)

# %% [markdown]
# ## No match

# %%
non_matching_entries.shape
# Out:
# (685, 63)

# %%
non_matching_entries.head(5)
# Out:
#                                                lyrics  \
# 1   i can't get no satisfactioni can't get no sati...
# 6   your love is liftin' me higherthan i've ever b...
# 8   ladies and gentlemen  ladies and gentlemen  oo...
# 9   new york city you are now ridingwith 50 centyo...
# 12  fetty wapyeah baby  1738ay  ay  lookbaby girl ...
#
#                                                 genre  num_syllables  pos  \
# 1   ['blues', 'blues rock', 'britannique', 'britis...          296.1    3
# 6   ['adult contemporary', 'american', 'country', ...          235.8    8
# 8   ['contemporary r&b', 'crunk&b', 'dance', 'danc...          584.1    5
# 9                                         hip-hop/rnb          711.0   14
# 12                                        hip-hop/rnb          568.8   21
#
#     year  fog_index  flesch_index  num_lines  \
# 1   1965        4.8        106.67         37
# 6   1977        4.4         82.31         26
# 8   2005        5.6         96.18         51
# ...

# %%
non_matching_entries[non_matching_entries['title'] == 'Drive']
# Out:
#                                                  lyrics  \
# 1098  it was painted red the stripe was whiteit was ...
#
#                                                   genre  num_syllables  pos  \
# 1098  ['bluegrass', 'christmas music', 'contemporary...          493.2   86
#
#       year  fog_index  flesch_index  num_lines  \
# 1098  2002        4.8        106.67         60
#
#                                               sentiment  title  ...  \
# 1098  {'neg': 0.051000000000000004, 'neu': 0.889, 'p...  Drive  ...
#
#       instrumentalness_y liveness_y  valence_y  tempo_y  duration_ms_y  \
# 1098                 NaN        NaN        NaN      NaN            NaN
#
#       time_signature chorus_hit sections target     _merge
# 1098             NaN        NaN      NaN    NaN  left_only
#
# [1 rows x 63 columns]

# %% [markdown]
# # XGBoost

# %%
sample_df = pd.read_csv('/content/gdrive/My Drive/Colab Datasets/sample_two_datasets_hit_column.csv')

# %%
sample_df.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'danceability_x', 'energy_x', 'loudness_x', 'speechiness_x',
#        'acousticness_x', 'instrumentalness_x', 'liveness_x', 'valence_x',
#        'tempo_x', 'key_x', 'mode_x', 'duration_ms_x', 'Popularity', 'values',
#        'pred', 'label', 'score', 'emotion_label', 'Hit_x', 'uri',
#        'danceability_y', 'energy_y', 'key_y', 'loudness_y', 'mode_y',
#        'speechiness_y', 'acousticness_y', 'instrumentalness_y', 'liveness_y',
#        'valence_y', 'tempo_y', 'duration_ms_y', 'time_signature', 'chorus_hit',
#        'sections', 'target', 'Hit_y'],
#       dtype='object')

# %%
sample_df = sample_df.drop(['danceability_x', 'energy_x', 'loudness_x', 'speechiness_x',
       'acousticness_x', 'instrumentalness_x', 'liveness_x', 'valence_x',
       'tempo_x', 'key_x', 'mode_x', 'duration_ms_x', 'Popularity'], axis=1)

# %%
sample_df.columns
# Out:
# Index(['lyrics', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
#        'flesch_index', 'num_lines', 'sentiment', 'title', 'f_k_grade',
#        'artist', 'difficult_words', 'num_dupes', 'number_of_tokens',
#        'number_of_types', 'decades', 'stemmed_text', 'POS_tags', 'POS',
#        'playlistID', 'TrackName', 'TrackID', 'SampleURL', 'ReleaseYear',
#        'Genres', 'values', 'pred', 'label', 'score', 'emotion_label', 'Hit_x',
#        'uri', 'danceability_y', 'energy_y', 'key_y', 'loudness_y', 'mode_y',
#        'speechiness_y', 'acousticness_y', 'instrumentalness_y', 'liveness_y',
#        'valence_y', 'tempo_y', 'duration_ms_y', 'time_signature', 'chorus_hit',
#        'sections', 'target', 'Hit_y'],
#       dtype='object')

# %%
sample_df.Hit_y = sample_df.Hit_y.replace({'Yes': 1, 'No': 0})

# %%
sample_df.head(5)
# Out:
#                                               lyrics  \
# 0  look into my eyes  you will seewhat you mean t...
# 1  our life together is so precious togetherwe ha...
# 2  love is higher than a mountain love is thicker...
# 3  sittin' in the morning suni'll be sittin' when...
# 4  why do birds suddenly appeareverytime you are ...
#
#                                                genre  num_syllables  pos  \
# 0  ['acoustic rock', 'adult contemporary', 'album...          258.3    1
# 1  ['britannique', 'british', 'classic pop and ro...          288.0    4
# 2   ['classic pop and rock', 'death by myocarditis']          224.1    8
# 3  ['american', 'blues', 'death by airplane', 'de...          223.2    4
# 4  ['adult contemporary', 'baroque pop', 'classic...          236.7    2
#
#    year  fog_index  flesch_index  num_lines  \
# 0  1991        4.4        107.69         36
# 1  1981        4.8         81.29         28
# 2  1978        4.0         91.78         30
# ...

# %%
from collections import Counter

Counter(sample_df.Hit_y)
# Out:
# Counter({1: 550, 0: 566})

# %%
df = sample_df.copy()

# %%
df.isna().sum()
# Out:
# lyrics                0
# genre                 0
# num_syllables         0
# pos                   0
# year                  0
# fog_index             0
# flesch_index          0
# num_lines             0
# sentiment             0
# title                 0
# f_k_grade             0
# artist                0
# difficult_words       0
# num_dupes             0
# number_of_tokens      0
# number_of_types       0
# decades               0
# stemmed_text          0
# POS_tags              0
# POS                   0
# playlistID            0
# TrackName             0
# TrackID               0
# SampleURL             0
# ReleaseYear           0
# Genres                0
# values                0
# pred                  0
# label                 0
# score                 0
# emotion_label         0
# Hit_x                 0
# uri                   0
# danceability_y        0
# energy_y              0
# key_y                 0
# loudness_y            0
# mode_y                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1116 entries, 0 to 1115
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lyrics              1116 non-null   object
#  1   genre               1116 non-null   object
#  2   num_syllables       1116 non-null   float64
#  3   pos                 1116 non-null   int64
#  4   year                1116 non-null   int64
#  5   fog_index           1116 non-null   float64
#  6   flesch_index        1116 non-null   float64
#  7   num_lines           1116 non-null   int64
#  8   sentiment           1116 non-null   object
#  9   title               1116 non-null   object
#  10  f_k_grade           1116 non-null   float64
#  11  artist              1116 non-null   object
#  12  difficult_words     1116 non-null   int64
#  13  num_dupes           1116 non-null   int64
#  14  number_of_tokens    1116 non-null   float64
# ...

# %%
df.describe()
# Out:
#        num_syllables          pos         year    fog_index  flesch_index  \
# count    1116.000000  1116.000000  1116.000000  1116.000000   1116.000000
# mean      372.854839    51.276882  1989.207885     4.600000     98.871658
# std       165.710021    38.422310    14.942574     0.545146      7.669084
# min        45.900000     1.000000  1960.000000     3.600000     28.500000
# 25%       259.875000    12.000000  1978.000000     4.400000     96.180000
# 50%       348.300000    75.000000  1989.000000     4.400000     99.230000
# 75%       441.900000    88.000000  2002.000000     4.800000    105.660000
# max      1797.300000   100.000000  2015.000000     6.800000    118.180000
#
#          num_lines    f_k_grade  difficult_words    num_dupes  \
# count  1116.000000  1116.000000      1116.000000  1116.000000
# mean     45.241039     1.079211        21.027778    24.972222
# std      19.129864     1.151197        13.723279    15.738620
# ...

# %%
df.nunique()
# Out:
# lyrics                1116
# genre                  368
# num_syllables          516
# pos                     63
# year                    56
# fog_index                9
# flesch_index            45
# num_lines              102
# sentiment             1116
# title                 1092
# f_k_grade               26
# artist                 593
# difficult_words         76
# num_dupes               80
# number_of_tokens       439
# number_of_types        211
# decades                  6
# stemmed_text          1116
# POS_tags              1116
# POS                   1116
# playlistID               2
# TrackName             1098
# TrackID               1116
# SampleURL             1116
# ReleaseYear            649
# Genres                 479
# values                 102
# pred                     2
# label                    2
# score                 1110
# emotion_label            6
# Hit_x                    2
# uri                   1114
# danceability_y         492
# ...

# %%
df.Hit_y.value_counts()
# Out:
# 0    566
# 1    550
# Name: Hit_y, dtype: int64

# %%
df = df.drop(['genre', 'num_syllables', 'pos', 'year', 'fog_index', 'flesch_index', 'num_lines', 'sentiment', 'f_k_grade', 'genre', 'num_syllables', 'pos', 'year', 'fog_index',
       'flesch_index', 'num_lines', 'sentiment', 'f_k_grade', 'target'], axis=1)

# %%
#df = df.drop(['Hit_y'], axis=1)

# %% [markdown]
# ## With sample from the self created and the spotify data set, with hit as labels

# %%
df = df.drop(['lyrics', 'difficult_words', 'num_dupes',
       'number_of_tokens', 'number_of_types', 'decades', 'stemmed_text',
       'POS_tags', 'POS', 'playlistID', 'TrackName', 'TrackID', 'SampleURL',
       'ReleaseYear', 'Genres', 'values', 'pred', 'label', 'score',
       'emotion_label', 'Hit_x' ], axis=1)

# %%
df.columns
# Out:
# Index(['title', 'artist', 'uri', 'danceability_y', 'energy_y', 'key_y',
#        'loudness_y', 'mode_y', 'speechiness_y', 'acousticness_y',
#        'instrumentalness_y', 'liveness_y', 'valence_y', 'tempo_y',
#        'duration_ms_y', 'time_signature', 'chorus_hit', 'sections', 'Hit_y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,14))
correl = df.corr()
sns.heatmap(correl,annot=True)
# Out:
# <ipython-input-134-88ef941973b5>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correl = df.corr()
# <Axes: >

# %%
correl
# Out:
#                     danceability_y  energy_y     key_y  loudness_y    mode_y  \
# danceability_y            1.000000  0.199428  0.047873    0.057443 -0.168925
# energy_y                  0.199428  1.000000  0.015060    0.703956 -0.149858
# key_y                     0.047873  0.015060  1.000000    0.028691 -0.066507
# loudness_y                0.057443  0.703956  0.028691    1.000000 -0.109480
# mode_y                   -0.168925 -0.149858 -0.066507   -0.109480  1.000000
# speechiness_y             0.185438  0.156236  0.047347    0.122824 -0.072065
# acousticness_y           -0.275179 -0.634217 -0.007230   -0.414396  0.145575
# instrumentalness_y        0.067261  0.019879  0.006506   -0.095651 -0.024008
# liveness_y               -0.107560  0.134872  0.011595    0.077625  0.030051
# valence_y                 0.516302  0.401448  0.044472    0.079129 -0.121867
# tempo_y                  -0.220788  0.147332 -0.041719    0.091860  0.047315
# ...

# %%
#df = df.drop(['lyrics'], axis=1)

# %%
df.nunique()
# Out:
# title                 1092
# artist                 593
# uri                   1114
# danceability_y         492
# energy_y               577
# key_y                   12
# loudness_y            1070
# mode_y                   2
# speechiness_y          483
# acousticness_y         821
# instrumentalness_y     592
# liveness_y             589
# valence_y              619
# tempo_y               1106
# duration_ms_y         1069
# time_signature           4
# chorus_hit            1114
# sections                21
# Hit_y                    2
# dtype: int64

# %%
categorical = [x for x in df.columns if df[x].nunique()< 15]

# %%
categorical
# Out:
# ['key_y', 'mode_y', 'time_signature', 'Hit_y']

# %%
df = df.drop(['title','artist','uri'],axis=1)

# %%
numeric = [x for x in df.columns if df[x].nunique() > 15]

# %%
numeric
# Out:
# ['danceability_y',
#  'energy_y',
#  'loudness_y',
#  'speechiness_y',
#  'acousticness_y',
#  'instrumentalness_y',
#  'liveness_y',
#  'valence_y',
#  'tempo_y',
#  'duration_ms_y',
#  'chorus_hit',
#  'sections']

# %%
Counter(df.Hit_y)
# Out:
# Counter({1: 550, 0: 566})

# %%
plt.figure(figsize=(18,20))
i = 1
for features in categorical[:-1]:
    plt.subplot(2,2,i)
    sns.countplot(x=df[features],hue=sample_df.Hit_y).set_title(features)
    i=i+1
plt.show()

# %%
plt.figure(figsize=(18,20))
i = 1
for features in numeric:
    plt.subplot(3,4,i)
    sns.histplot(x=df[features],hue= df.Hit_y, bins=10).set_title(features)
    i=i+1
plt.show()

# %%
plt.figure(figsize=(18,20))
i = 1
for features in numeric:
    plt.subplot(3,4,i)
    sns.boxplot(x=df[features]).set_title(features)
    i=i+1
plt.show()

# %%
X = df.drop('Hit_y',axis=1)

# %%
X.columns
# Out:
# Index(['danceability_y', 'energy_y', 'key_y', 'loudness_y', 'mode_y',
#        'speechiness_y', 'acousticness_y', 'instrumentalness_y', 'liveness_y',
#        'valence_y', 'tempo_y', 'duration_ms_y', 'time_signature', 'chorus_hit',
#        'sections'],
#       dtype='object')

# %%
y = df["Hit_y"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

# %%
from xgboost import XGBClassifier

# %%
classifier = XGBClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {
    'learning_rate':[0.05,0.10,0.15,0.20,0.25,0.30],
    'max_depth': [3,4,5,6,8,10,12,15],
    'min_child_weight':[1,3,5,7],
    'gamma':[0.0, 0.1, 0.2, 0.3, 0.4],
    'colsample_bytree': [0.3, 0.4, 0.5, 0.7]
}

# %%
random_search = RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring="roc_auc",n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
# ...

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.3, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.2, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
classifier= XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.7,
              enable_categorical=False, gamma=0.2, gpu_id=-1,
              importance_type=None, interaction_constraints='',
              learning_rate=0.1, max_delta_step=0, max_depth=5,
              min_child_weight=1, monotone_constraints='()',
              n_estimators=100, n_jobs=8, num_parallel_tree=1, predictor='auto',
              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
              subsample=1, tree_method='exact', validate_parameters=1,
              verbosity=None)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,classification_report

# %%
cross = cross_val_score(classifier,x_train,y_train,cv=10,verbose=0)

# %%
print("Accuracy after cross validation is: {}".format(cross.mean()*100))
# Out:
# Accuracy after cross validation is: 53.24594257178528

# %%
classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.2, gpu_id=-1,
#               grow_policy=None, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=0,
#               max_depth=5, max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_pred = classifier.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.46      0.50       121
#            1       0.46      0.53      0.49       103
#
#     accuracy                           0.50       224
#    macro avg       0.50      0.50      0.50       224
# weighted avg       0.50      0.50      0.50       224

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt="g")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %% [markdown]
# ## Feature Importance

# %%
import xgboost as xgb

xgb.plot_importance(classifier)
plt.rcParams['figure.figsize'] = [6, 4]
plt.show()
